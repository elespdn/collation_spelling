# %% [markdown]
# ## 0. Normal

# %%
from collatex import *
collation = Collation()
TO = open( "text/TO1.txt", encoding='utf-8' ).read()
RI = open( "text/RI1.txt", encoding='utf-8' ).read()
CH = open( "text/CH1.txt", encoding='utf-8' ).read()
collation.add_plain_witness( "TO", TO )
collation.add_plain_witness( "RI", RI )
collation.add_plain_witness( "CH", CH )
table = collate(collation, output='html2', segmentation=False)
print(table)
# Out:
# <TABLE style="border: 1px solid #000000; border-collapse: collapse;" border="1" cellpadding="4">
#  <TR>
#   <TH>TO</TH>
#   <TH>RI</TH>
#   <TH>CH</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">NEl</TD>
#   <TD bgcolor="00FFFF">NEl</TD>
#   <TD bgcolor="00FFFF">NEl</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">mezzo</TD>
#   <TD bgcolor="FF0000">mezzo</TD>
#   <TD bgcolor="FF0000">mezo</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">del</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">cammin</TD>
#   <TD bgcolor="FF0000">camin</TD>
#   <TD bgcolor="FF0000">cammin</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">di</TD>
#   <TD bgcolor="00FFFF">di</TD>
#   <TD bgcolor="00FFFF">di</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">nostra</TD>
#   <TD bgcolor="00FFFF">nostra</TD>
#   <TD bgcolor="00FFFF">nostra</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">vita</TD>
#   <TD bgcolor="00FFFF">vita</TD>
#   <TD bgcolor="00FFFF">vita</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">mi</TD>
#   <TD bgcolor="00FFFF">mi</TD>
#   <TD bgcolor="00FFFF">mi</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ritrovai</TD>
#   <TD bgcolor="00FFFF">ritrovai</TD>
#   <TD bgcolor="00FFFF">ritrovai</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">per</TD>
#   <TD bgcolor="00FFFF">per</TD>
#   <TD bgcolor="00FFFF">per</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">una</TD>
#   <TD bgcolor="00FFFF">una</TD>
#   <TD bgcolor="00FFFF">una</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">selva</TD>
#   <TD bgcolor="00FFFF">selva</TD>
#   <TD bgcolor="00FFFF">selva</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">obscura</TD>
#   <TD bgcolor="00FFFF">obscura</TD>
#   <TD bgcolor="00FFFF">obscura</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">che</TD>
#   <TD bgcolor="00FFFF">che</TD>
#   <TD bgcolor="00FFFF">che</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">diricta</TD>
#   <TD bgcolor="00FFFF">diricta</TD>
#   <TD bgcolor="00FFFF">diricta</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">via</TD>
#   <TD bgcolor="00FFFF">via</TD>
#   <TD bgcolor="00FFFF">via</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">era</TD>
#   <TD bgcolor="00FFFF">era</TD>
#   <TD bgcolor="00FFFF">era</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">smarrita</TD>
#   <TD bgcolor="00FFFF">smarrita</TD>
#   <TD bgcolor="00FFFF">smarrita</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">Et</TD>
#   <TD bgcolor="00FFFF">Et</TD>
#   <TD bgcolor="00FFFF">Et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">quanto</TD>
#   <TD bgcolor="00FFFF">quanto</TD>
#   <TD bgcolor="00FFFF">quanto</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">ad</TD>
#   <TD bgcolor="FF0000">a</TD>
#   <TD bgcolor="FF0000">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">dir</TD>
#   <TD bgcolor="FF0000">dir</TD>
#   <TD bgcolor="FF0000">ddir</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">quale</TD>
#   <TD bgcolor="FF0000">qual</TD>
#   <TD bgcolor="FF0000">qual</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">'</TD>
#   <TD bgcolor="FF0000">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">era</TD>
#   <TD bgcolor="00FFFF">era</TD>
#   <TD bgcolor="00FFFF">era</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">e</TD>
#   <TD bgcolor="00FFFF">e</TD>
#   <TD bgcolor="00FFFF">e</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">cosa</TD>
#   <TD bgcolor="00FFFF">cosa</TD>
#   <TD bgcolor="00FFFF">cosa</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">dura</TD>
#   <TD bgcolor="00FFFF">dura</TD>
#   <TD bgcolor="00FFFF">dura</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">esta</TD>
#   <TD bgcolor="00FFFF">esta</TD>
#   <TD bgcolor="00FFFF">esta</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">selva</TD>
#   <TD bgcolor="00FFFF">selva</TD>
#   <TD bgcolor="00FFFF">selva</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">selvaggia</TD>
#   <TD bgcolor="00FFFF">selvaggia</TD>
#   <TD bgcolor="00FFFF">selvaggia</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">aspra</TD>
#   <TD bgcolor="00FFFF">aspra</TD>
#   <TD bgcolor="00FFFF">aspra</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">forte</TD>
#   <TD bgcolor="00FFFF">forte</TD>
#   <TD bgcolor="00FFFF">forte</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">che</TD>
#   <TD bgcolor="00FFFF">che</TD>
#   <TD bgcolor="00FFFF">che</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">nel</TD>
#   <TD bgcolor="00FFFF">nel</TD>
#   <TD bgcolor="00FFFF">nel</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">pensier</TD>
#   <TD bgcolor="00FFFF">pensier</TD>
#   <TD bgcolor="00FFFF">pensier</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">rinnova</TD>
#   <TD bgcolor="FF0000">rinnova</TD>
#   <TD bgcolor="FF0000">rinnuova</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">paura</TD>
#   <TD bgcolor="00FFFF">paura</TD>
#   <TD bgcolor="00FFFF">paura</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">Tanto</TD>
#   <TD bgcolor="FF0000">Tant</TD>
#   <TD bgcolor="FF0000">Tanto</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">'</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">e</TD>
#   <TD bgcolor="00FFFF">e</TD>
#   <TD bgcolor="00FFFF">e</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">amara</TD>
#   <TD bgcolor="00FFFF">amara</TD>
#   <TD bgcolor="00FFFF">amara</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">che</TD>
#   <TD bgcolor="00FFFF">che</TD>
#   <TD bgcolor="00FFFF">che</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">poco</TD>
#   <TD bgcolor="00FFFF">poco</TD>
#   <TD bgcolor="00FFFF">poco</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">e</TD>
#   <TD bgcolor="00FFFF">e</TD>
#   <TD bgcolor="00FFFF">e</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">piu</TD>
#   <TD bgcolor="00FFFF">piu</TD>
#   <TD bgcolor="00FFFF">piu</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">morte</TD>
#   <TD bgcolor="00FFFF">morte</TD>
#   <TD bgcolor="00FFFF">morte</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ma</TD>
#   <TD bgcolor="00FFFF">ma</TD>
#   <TD bgcolor="00FFFF">ma</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">per</TD>
#   <TD bgcolor="00FFFF">per</TD>
#   <TD bgcolor="00FFFF">per</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">tractar</TD>
#   <TD bgcolor="00FFFF">tractar</TD>
#   <TD bgcolor="00FFFF">tractar</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">del</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ben</TD>
#   <TD bgcolor="00FFFF">ben</TD>
#   <TD bgcolor="00FFFF">ben</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ch</TD>
#   <TD bgcolor="00FFFF">ch</TD>
#   <TD bgcolor="00FFFF">ch</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">io</TD>
#   <TD bgcolor="00FFFF">io</TD>
#   <TD bgcolor="00FFFF">io</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">vi</TD>
#   <TD bgcolor="00FFFF">vi</TD>
#   <TD bgcolor="00FFFF">vi</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">trovai</TD>
#   <TD bgcolor="00FFFF">trovai</TD>
#   <TD bgcolor="00FFFF">trovai</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">diro</TD>
#   <TD bgcolor="00FFFF">diro</TD>
#   <TD bgcolor="00FFFF">diro</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">dell</TD>
#   <TD bgcolor="00FFFF">dell</TD>
#   <TD bgcolor="00FFFF">dell</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">altre</TD>
#   <TD bgcolor="00FFFF">altre</TD>
#   <TD bgcolor="00FFFF">altre</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">cose</TD>
#   <TD bgcolor="00FFFF">cose</TD>
#   <TD bgcolor="00FFFF">cose</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ch</TD>
#   <TD bgcolor="00FFFF">ch</TD>
#   <TD bgcolor="00FFFF">ch</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">io</TD>
#   <TD bgcolor="00FFFF">io</TD>
#   <TD bgcolor="00FFFF">io</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">v</TD>
#   <TD bgcolor="00FFFF">v</TD>
#   <TD bgcolor="00FFFF">v</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FF
# None

# %% [markdown]
# ## 1. Near match

# %%
from collatex import *
collation = Collation()
TO = open( "text/TO1.txt", encoding='utf-8' ).read()
RI = open( "text/RI1.txt", encoding='utf-8' ).read()
CH = open( "text/CH1.txt", encoding='utf-8' ).read()
collation.add_plain_witness( "TO", TO )
collation.add_plain_witness( "RI", RI )
collation.add_plain_witness( "CH", CH )
table = collate(collation, output='html2', near_match=True, segmentation=False)
print(table)
# Out:
# <TABLE style="border: 1px solid #000000; border-collapse: collapse;" border="1" cellpadding="4">
#  <TR>
#   <TH>TO</TH>
#   <TH>RI</TH>
#   <TH>CH</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">NEl</TD>
#   <TD bgcolor="00FFFF">NEl</TD>
#   <TD bgcolor="00FFFF">NEl</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">mezzo</TD>
#   <TD bgcolor="FF0000">mezzo</TD>
#   <TD bgcolor="FF0000">mezo</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">del</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">cammin</TD>
#   <TD bgcolor="FF0000">camin</TD>
#   <TD bgcolor="FF0000">cammin</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">di</TD>
#   <TD bgcolor="00FFFF">di</TD>
#   <TD bgcolor="00FFFF">di</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">nostra</TD>
#   <TD bgcolor="00FFFF">nostra</TD>
#   <TD bgcolor="00FFFF">nostra</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">vita</TD>
#   <TD bgcolor="00FFFF">vita</TD>
#   <TD bgcolor="00FFFF">vita</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">mi</TD>
#   <TD bgcolor="00FFFF">mi</TD>
#   <TD bgcolor="00FFFF">mi</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ritrovai</TD>
#   <TD bgcolor="00FFFF">ritrovai</TD>
#   <TD bgcolor="00FFFF">ritrovai</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">per</TD>
#   <TD bgcolor="00FFFF">per</TD>
#   <TD bgcolor="00FFFF">per</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">una</TD>
#   <TD bgcolor="00FFFF">una</TD>
#   <TD bgcolor="00FFFF">una</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">selva</TD>
#   <TD bgcolor="00FFFF">selva</TD>
#   <TD bgcolor="00FFFF">selva</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">obscura</TD>
#   <TD bgcolor="00FFFF">obscura</TD>
#   <TD bgcolor="00FFFF">obscura</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">che</TD>
#   <TD bgcolor="00FFFF">che</TD>
#   <TD bgcolor="00FFFF">che</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">diricta</TD>
#   <TD bgcolor="00FFFF">diricta</TD>
#   <TD bgcolor="00FFFF">diricta</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">via</TD>
#   <TD bgcolor="00FFFF">via</TD>
#   <TD bgcolor="00FFFF">via</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">era</TD>
#   <TD bgcolor="00FFFF">era</TD>
#   <TD bgcolor="00FFFF">era</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">smarrita</TD>
#   <TD bgcolor="00FFFF">smarrita</TD>
#   <TD bgcolor="00FFFF">smarrita</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">Et</TD>
#   <TD bgcolor="00FFFF">Et</TD>
#   <TD bgcolor="00FFFF">Et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">quanto</TD>
#   <TD bgcolor="00FFFF">quanto</TD>
#   <TD bgcolor="00FFFF">quanto</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">ad</TD>
#   <TD bgcolor="FF0000">a</TD>
#   <TD bgcolor="FF0000">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">dir</TD>
#   <TD bgcolor="FF0000">dir</TD>
#   <TD bgcolor="FF0000">ddir</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">quale</TD>
#   <TD bgcolor="FF0000">qual</TD>
#   <TD bgcolor="FF0000">qual</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">'</TD>
#   <TD bgcolor="FF0000">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">era</TD>
#   <TD bgcolor="00FFFF">era</TD>
#   <TD bgcolor="00FFFF">era</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">e</TD>
#   <TD bgcolor="00FFFF">e</TD>
#   <TD bgcolor="00FFFF">e</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">cosa</TD>
#   <TD bgcolor="00FFFF">cosa</TD>
#   <TD bgcolor="00FFFF">cosa</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">dura</TD>
#   <TD bgcolor="00FFFF">dura</TD>
#   <TD bgcolor="00FFFF">dura</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">esta</TD>
#   <TD bgcolor="00FFFF">esta</TD>
#   <TD bgcolor="00FFFF">esta</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">selva</TD>
#   <TD bgcolor="00FFFF">selva</TD>
#   <TD bgcolor="00FFFF">selva</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">selvaggia</TD>
#   <TD bgcolor="00FFFF">selvaggia</TD>
#   <TD bgcolor="00FFFF">selvaggia</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">aspra</TD>
#   <TD bgcolor="00FFFF">aspra</TD>
#   <TD bgcolor="00FFFF">aspra</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">forte</TD>
#   <TD bgcolor="00FFFF">forte</TD>
#   <TD bgcolor="00FFFF">forte</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">che</TD>
#   <TD bgcolor="00FFFF">che</TD>
#   <TD bgcolor="00FFFF">che</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">nel</TD>
#   <TD bgcolor="00FFFF">nel</TD>
#   <TD bgcolor="00FFFF">nel</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">pensier</TD>
#   <TD bgcolor="00FFFF">pensier</TD>
#   <TD bgcolor="00FFFF">pensier</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">rinnova</TD>
#   <TD bgcolor="FF0000">rinnova</TD>
#   <TD bgcolor="FF0000">rinnuova</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">paura</TD>
#   <TD bgcolor="00FFFF">paura</TD>
#   <TD bgcolor="00FFFF">paura</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">Tanto</TD>
#   <TD bgcolor="FF0000">Tant</TD>
#   <TD bgcolor="FF0000">Tanto</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">'</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">e</TD>
#   <TD bgcolor="00FFFF">e</TD>
#   <TD bgcolor="00FFFF">e</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">amara</TD>
#   <TD bgcolor="00FFFF">amara</TD>
#   <TD bgcolor="00FFFF">amara</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">che</TD>
#   <TD bgcolor="00FFFF">che</TD>
#   <TD bgcolor="00FFFF">che</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">poco</TD>
#   <TD bgcolor="00FFFF">poco</TD>
#   <TD bgcolor="00FFFF">poco</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">e</TD>
#   <TD bgcolor="00FFFF">e</TD>
#   <TD bgcolor="00FFFF">e</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">piu</TD>
#   <TD bgcolor="00FFFF">piu</TD>
#   <TD bgcolor="00FFFF">piu</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">morte</TD>
#   <TD bgcolor="00FFFF">morte</TD>
#   <TD bgcolor="00FFFF">morte</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ma</TD>
#   <TD bgcolor="00FFFF">ma</TD>
#   <TD bgcolor="00FFFF">ma</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">per</TD>
#   <TD bgcolor="00FFFF">per</TD>
#   <TD bgcolor="00FFFF">per</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">tractar</TD>
#   <TD bgcolor="00FFFF">tractar</TD>
#   <TD bgcolor="00FFFF">tractar</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">del</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ben</TD>
#   <TD bgcolor="00FFFF">ben</TD>
#   <TD bgcolor="00FFFF">ben</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ch</TD>
#   <TD bgcolor="00FFFF">ch</TD>
#   <TD bgcolor="00FFFF">ch</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">io</TD>
#   <TD bgcolor="00FFFF">io</TD>
#   <TD bgcolor="00FFFF">io</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">vi</TD>
#   <TD bgcolor="00FFFF">vi</TD>
#   <TD bgcolor="00FFFF">vi</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">trovai</TD>
#   <TD bgcolor="00FFFF">trovai</TD>
#   <TD bgcolor="00FFFF">trovai</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">diro</TD>
#   <TD bgcolor="00FFFF">diro</TD>
#   <TD bgcolor="00FFFF">diro</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">dell</TD>
#   <TD bgcolor="00FFFF">dell</TD>
#   <TD bgcolor="00FFFF">dell</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">altre</TD>
#   <TD bgcolor="00FFFF">altre</TD>
#   <TD bgcolor="00FFFF">altre</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">cose</TD>
#   <TD bgcolor="00FFFF">cose</TD>
#   <TD bgcolor="00FFFF">cose</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ch</TD>
#   <TD bgcolor="00FFFF">ch</TD>
#   <TD bgcolor="00FFFF">ch</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">io</TD>
#   <TD bgcolor="00FFFF">io</TD>
#   <TD bgcolor="00FFFF">io</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">v</TD>
#   <TD bgcolor="00FFFF">v</TD>
#   <TD bgcolor="00FFFF">v</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FF
# None

# %% [markdown]
# ## 2a. Dictionary (table)

# %%
import csv
import re

#create the dictionary (here: Dictionary.csv consisting in two columns, separated by a comma. The first Column 'Original' are the strings as found in the text, the second column 'Normalised' contains the strings you want to replace them with. No whitespaces behind the strings.) 
Normit = {}
with open('dictionary.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'],  dialect='excel')
    for row in reader:
        Normit[row['Original']]= row['Normalised']

#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()
#testimone_P4 = open( "lettere/T196-part1-clean-P4.txt", encoding='utf-8' ).read()
#testimone_S2 = open( "lettere/T196-part1-clean-S2.txt", encoding='utf-8' ).read()
#testimone_S4 = open( "lettere/T196-part1-clean-S4.txt", encoding='utf-8' ).read()

# build a function to tokenize and to normalize by replace keys to be found in the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

#collate
tokens_TO = tokennormalizer(TO) 
tokens_RI = tokennormalizer(RI) 
tokens_CH = tokennormalizer(CH) 


witness_TO = { "id": "TO", "tokens":tokens_TO }
witness_RI = { "id": "RI", "tokens":tokens_RI }
witness_CH = { "id": "CH", "tokens":tokens_CH }


input = { "witnesses": [ witness_TO, witness_RI, witness_CH ] }

table = collate(input, output='html2', segmentation=False)
# Out:
# <TABLE style="border: 1px solid #000000; border-collapse: collapse;" border="1" cellpadding="4">
#  <TR>
#   <TH>TO</TH>
#   <TH>RI</TH>
#   <TH>CH</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">NEl</TD>
#   <TD bgcolor="00FFFF">NEl</TD>
#   <TD bgcolor="00FFFF">NEl</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">mezzo</TD>
#   <TD bgcolor="00FFFF">mezzo</TD>
#   <TD bgcolor="00FFFF">mezo</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">del</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">cammin</TD>
#   <TD bgcolor="00FFFF">camin</TD>
#   <TD bgcolor="00FFFF">cammin</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">di</TD>
#   <TD bgcolor="00FFFF">di</TD>
#   <TD bgcolor="00FFFF">di</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">nostra</TD>
#   <TD bgcolor="00FFFF">nostra</TD>
#   <TD bgcolor="00FFFF">nostra</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">vita</TD>
#   <TD bgcolor="00FFFF">vita</TD>
#   <TD bgcolor="00FFFF">vita</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">mi</TD>
#   <TD bgcolor="00FFFF">mi</TD>
#   <TD bgcolor="00FFFF">mi</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ritrovai</TD>
#   <TD bgcolor="00FFFF">ritrovai</TD>
#   <TD bgcolor="00FFFF">ritrovai</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">per</TD>
#   <TD bgcolor="00FFFF">per</TD>
#   <TD bgcolor="00FFFF">per</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">una</TD>
#   <TD bgcolor="00FFFF">una</TD>
#   <TD bgcolor="00FFFF">una</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">selva</TD>
#   <TD bgcolor="00FFFF">selva</TD>
#   <TD bgcolor="00FFFF">selva</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">obscura</TD>
#   <TD bgcolor="00FFFF">obscura</TD>
#   <TD bgcolor="00FFFF">obscura</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">che</TD>
#   <TD bgcolor="00FFFF">che</TD>
#   <TD bgcolor="00FFFF">che</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">diricta</TD>
#   <TD bgcolor="00FFFF">diricta</TD>
#   <TD bgcolor="00FFFF">diricta</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">via</TD>
#   <TD bgcolor="00FFFF">via</TD>
#   <TD bgcolor="00FFFF">via</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">era</TD>
#   <TD bgcolor="00FFFF">era</TD>
#   <TD bgcolor="00FFFF">era</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">smarrita</TD>
#   <TD bgcolor="00FFFF">smarrita</TD>
#   <TD bgcolor="00FFFF">smarrita</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">Et</TD>
#   <TD bgcolor="00FFFF">Et</TD>
#   <TD bgcolor="00FFFF">Et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">quanto</TD>
#   <TD bgcolor="00FFFF">quanto</TD>
#   <TD bgcolor="00FFFF">quanto</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">ad</TD>
#   <TD bgcolor="FF0000">a</TD>
#   <TD bgcolor="FF0000">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">dir</TD>
#   <TD bgcolor="FF0000">dir</TD>
#   <TD bgcolor="FF0000">ddir</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">quale</TD>
#   <TD bgcolor="FF0000">qual</TD>
#   <TD bgcolor="FF0000">qual</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">'</TD>
#   <TD bgcolor="FF0000">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">era</TD>
#   <TD bgcolor="00FFFF">era</TD>
#   <TD bgcolor="00FFFF">era</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">e</TD>
#   <TD bgcolor="00FFFF">e</TD>
#   <TD bgcolor="00FFFF">e</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">cosa</TD>
#   <TD bgcolor="00FFFF">cosa</TD>
#   <TD bgcolor="00FFFF">cosa</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">dura</TD>
#   <TD bgcolor="00FFFF">dura</TD>
#   <TD bgcolor="00FFFF">dura</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">esta</TD>
#   <TD bgcolor="00FFFF">esta</TD>
#   <TD bgcolor="00FFFF">esta</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">selva</TD>
#   <TD bgcolor="00FFFF">selva</TD>
#   <TD bgcolor="00FFFF">selva</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">selvaggia</TD>
#   <TD bgcolor="00FFFF">selvaggia</TD>
#   <TD bgcolor="00FFFF">selvaggia</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">aspra</TD>
#   <TD bgcolor="00FFFF">aspra</TD>
#   <TD bgcolor="00FFFF">aspra</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">forte</TD>
#   <TD bgcolor="00FFFF">forte</TD>
#   <TD bgcolor="00FFFF">forte</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">che</TD>
#   <TD bgcolor="00FFFF">che</TD>
#   <TD bgcolor="00FFFF">che</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">nel</TD>
#   <TD bgcolor="00FFFF">nel</TD>
#   <TD bgcolor="00FFFF">nel</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">pensier</TD>
#   <TD bgcolor="00FFFF">pensier</TD>
#   <TD bgcolor="00FFFF">pensier</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">rinnova</TD>
#   <TD bgcolor="00FFFF">rinnova</TD>
#   <TD bgcolor="00FFFF">rinnuova</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">paura</TD>
#   <TD bgcolor="00FFFF">paura</TD>
#   <TD bgcolor="00FFFF">paura</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">Tanto</TD>
#   <TD bgcolor="FF0000">Tant</TD>
#   <TD bgcolor="FF0000">Tanto</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">'</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">e</TD>
#   <TD bgcolor="00FFFF">e</TD>
#   <TD bgcolor="00FFFF">e</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">amara</TD>
#   <TD bgcolor="00FFFF">amara</TD>
#   <TD bgcolor="00FFFF">amara</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">che</TD>
#   <TD bgcolor="00FFFF">che</TD>
#   <TD bgcolor="00FFFF">che</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">poco</TD>
#   <TD bgcolor="00FFFF">poco</TD>
#   <TD bgcolor="00FFFF">poco</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">e</TD>
#   <TD bgcolor="00FFFF">e</TD>
#   <TD bgcolor="00FFFF">e</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">piu</TD>
#   <TD bgcolor="00FFFF">piu</TD>
#   <TD bgcolor="00FFFF">piu</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">morte</TD>
#   <TD bgcolor="00FFFF">morte</TD>
#   <TD bgcolor="00FFFF">morte</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ma</TD>
#   <TD bgcolor="00FFFF">ma</TD>
#   <TD bgcolor="00FFFF">ma</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">per</TD>
#   <TD bgcolor="00FFFF">per</TD>
#   <TD bgcolor="00FFFF">per</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">tractar</TD>
#   <TD bgcolor="00FFFF">tractar</TD>
#   <TD bgcolor="00FFFF">tractar</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">del</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ben</TD>
#   <TD bgcolor="00FFFF">ben</TD>
#   <TD bgcolor="00FFFF">ben</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ch</TD>
#   <TD bgcolor="00FFFF">ch</TD>
#   <TD bgcolor="00FFFF">ch</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">io</TD>
#   <TD bgcolor="00FFFF">io</TD>
#   <TD bgcolor="00FFFF">io</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">vi</TD>
#   <TD bgcolor="00FFFF">vi</TD>
#   <TD bgcolor="00FFFF">vi</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">trovai</TD>
#   <TD bgcolor="00FFFF">trovai</TD>
#   <TD bgcolor="00FFFF">trovai</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">diro</TD>
#   <TD bgcolor="00FFFF">diro</TD>
#   <TD bgcolor="00FFFF">diro</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">dell</TD>
#   <TD bgcolor="00FFFF">dell</TD>
#   <TD bgcolor="00FFFF">dell</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">altre</TD>
#   <TD bgcolor="00FFFF">altre</TD>
#   <TD bgcolor="00FFFF">altre</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">cose</TD>
#   <TD bgcolor="00FFFF">cose</TD>
#   <TD bgcolor="00FFFF">cose</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ch</TD>
#   <TD bgcolor="00FFFF">ch</TD>
#   <TD bgcolor="00FFFF">ch</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">io</TD>
#   <TD bgcolor="00FFFF">io</TD>
#   <TD bgcolor="00FFFF">io</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">v</TD>
#   <TD bgcolor="00FFFF">v</TD>
#   <TD bgcolor="00FFFF">v</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FF

# %% [markdown]
# ## 2a. Dictionary (graph)

# %%
import csv
import re

#create the dictionary (here: Dictionary.csv consisting in two columns, separated by a comma. The first Column 'Original' are the strings as found in the text, the second column 'Normalised' contains the strings you want to replace them with. No whitespaces behind the strings.) 
Normit = {}
with open('dictionary.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'],  dialect='excel')
    for row in reader:
        Normit[row['Original']]= row['Normalised']

#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()
#testimone_P4 = open( "lettere/T196-part1-clean-P4.txt", encoding='utf-8' ).read()
#testimone_S2 = open( "lettere/T196-part1-clean-S2.txt", encoding='utf-8' ).read()
#testimone_S4 = open( "lettere/T196-part1-clean-S4.txt", encoding='utf-8' ).read()

# build a function to tokenize and to normalize by replace keys to be found in the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

#collate
tokens_TO = tokennormalizer(TO) 
tokens_RI = tokennormalizer(RI) 
tokens_CH = tokennormalizer(CH) 


witness_TO = { "id": "TO", "tokens":tokens_TO }
witness_RI = { "id": "RI", "tokens":tokens_RI }
witness_CH = { "id": "CH", "tokens":tokens_CH }


input = { "witnesses": [ witness_TO, witness_RI, witness_CH ] }

graph = collate(input, output='svg', segmentation=False)
print(graph)
# Out:
# None

# %% [markdown]
# ## 2b. NLP (table)

# %%
import csv
import re

#create the dictionary (here: lemma.csv consisting in two columns, separated by a comma. The first Column 'Original' are the strings as found in the text, the second column 'Normalised' contains the strings you want to replace them with. No whitespaces behind the strings.) 
Normit = {}
with open('pos_lemma.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'],  dialect='excel')
    for row in reader:
        Normit[row['Original']]= row['Normalised']

#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()
#testimone_P4 = open( "lettere/T196-part1-clean-P4.txt", encoding='utf-8' ).read()
#testimone_S2 = open( "lettere/T196-part1-clean-S2.txt", encoding='utf-8' ).read()
#testimone_S4 = open( "lettere/T196-part1-clean-S4.txt", encoding='utf-8' ).read()

# build a function to tokenize and to normalize by replace keys to be found in the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

#collate
tokens_TO = tokennormalizer(TO) 
tokens_RI = tokennormalizer(RI) 
tokens_CH = tokennormalizer(CH) 


witness_TO = { "id": "TO", "tokens":tokens_TO }
witness_RI = { "id": "RI", "tokens":tokens_RI }
witness_CH = { "id": "CH", "tokens":tokens_CH }


input = { "witnesses": [ witness_TO, witness_RI, witness_CH ] }

table = collate(input, output='html2', segmentation=False)
print(table)
# Out:
# <TABLE style="border: 1px solid #000000; border-collapse: collapse;" border="1" cellpadding="4">
#  <TR>
#   <TH>TO</TH>
#   <TH>RI</TH>
#   <TH>CH</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">NEl</TD>
#   <TD bgcolor="00FFFF">NEl</TD>
#   <TD bgcolor="00FFFF">NEl</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">mezzo</TD>
#   <TD bgcolor="00FFFF">mezzo</TD>
#   <TD bgcolor="00FFFF">mezo</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">del</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">cammin</TD>
#   <TD bgcolor="00FFFF">camin</TD>
#   <TD bgcolor="00FFFF">cammin</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">di</TD>
#   <TD bgcolor="00FFFF">di</TD>
#   <TD bgcolor="00FFFF">di</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">nostra</TD>
#   <TD bgcolor="00FFFF">nostra</TD>
#   <TD bgcolor="00FFFF">nostra</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">vita</TD>
#   <TD bgcolor="00FFFF">vita</TD>
#   <TD bgcolor="00FFFF">vita</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">mi</TD>
#   <TD bgcolor="00FFFF">mi</TD>
#   <TD bgcolor="00FFFF">mi</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ritrovai</TD>
#   <TD bgcolor="00FFFF">ritrovai</TD>
#   <TD bgcolor="00FFFF">ritrovai</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">per</TD>
#   <TD bgcolor="00FFFF">per</TD>
#   <TD bgcolor="00FFFF">per</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">una</TD>
#   <TD bgcolor="00FFFF">una</TD>
#   <TD bgcolor="00FFFF">una</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">selva</TD>
#   <TD bgcolor="00FFFF">selva</TD>
#   <TD bgcolor="00FFFF">selva</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">obscura</TD>
#   <TD bgcolor="00FFFF">obscura</TD>
#   <TD bgcolor="00FFFF">obscura</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">che</TD>
#   <TD bgcolor="00FFFF">che</TD>
#   <TD bgcolor="00FFFF">che</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">diricta</TD>
#   <TD bgcolor="00FFFF">diricta</TD>
#   <TD bgcolor="00FFFF">diricta</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">via</TD>
#   <TD bgcolor="00FFFF">via</TD>
#   <TD bgcolor="00FFFF">via</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">era</TD>
#   <TD bgcolor="00FFFF">era</TD>
#   <TD bgcolor="00FFFF">era</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">smarrita</TD>
#   <TD bgcolor="00FFFF">smarrita</TD>
#   <TD bgcolor="00FFFF">smarrita</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">Et</TD>
#   <TD bgcolor="00FFFF">Et</TD>
#   <TD bgcolor="00FFFF">Et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">quanto</TD>
#   <TD bgcolor="00FFFF">quanto</TD>
#   <TD bgcolor="00FFFF">quanto</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">ad</TD>
#   <TD bgcolor="FF0000">a</TD>
#   <TD bgcolor="FF0000">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">dir</TD>
#   <TD bgcolor="FF0000">dir</TD>
#   <TD bgcolor="FF0000">ddir</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">quale</TD>
#   <TD bgcolor="FF0000">qual</TD>
#   <TD bgcolor="FF0000">qual</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">'</TD>
#   <TD bgcolor="FF0000">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">era</TD>
#   <TD bgcolor="00FFFF">era</TD>
#   <TD bgcolor="00FFFF">era</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">e</TD>
#   <TD bgcolor="00FFFF">e</TD>
#   <TD bgcolor="00FFFF">e</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">cosa</TD>
#   <TD bgcolor="00FFFF">cosa</TD>
#   <TD bgcolor="00FFFF">cosa</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">dura</TD>
#   <TD bgcolor="00FFFF">dura</TD>
#   <TD bgcolor="00FFFF">dura</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">esta</TD>
#   <TD bgcolor="00FFFF">esta</TD>
#   <TD bgcolor="00FFFF">esta</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">selva</TD>
#   <TD bgcolor="00FFFF">selva</TD>
#   <TD bgcolor="00FFFF">selva</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">selvaggia</TD>
#   <TD bgcolor="00FFFF">selvaggia</TD>
#   <TD bgcolor="00FFFF">selvaggia</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">aspra</TD>
#   <TD bgcolor="00FFFF">aspra</TD>
#   <TD bgcolor="00FFFF">aspra</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">forte</TD>
#   <TD bgcolor="00FFFF">forte</TD>
#   <TD bgcolor="00FFFF">forte</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">che</TD>
#   <TD bgcolor="00FFFF">che</TD>
#   <TD bgcolor="00FFFF">che</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">nel</TD>
#   <TD bgcolor="00FFFF">nel</TD>
#   <TD bgcolor="00FFFF">nel</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">pensier</TD>
#   <TD bgcolor="00FFFF">pensier</TD>
#   <TD bgcolor="00FFFF">pensier</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">rinnova</TD>
#   <TD bgcolor="00FFFF">rinnova</TD>
#   <TD bgcolor="00FFFF">rinnuova</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">paura</TD>
#   <TD bgcolor="00FFFF">paura</TD>
#   <TD bgcolor="00FFFF">paura</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">Tanto</TD>
#   <TD bgcolor="FF0000">Tant</TD>
#   <TD bgcolor="FF0000">Tanto</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">'</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">e</TD>
#   <TD bgcolor="00FFFF">e</TD>
#   <TD bgcolor="00FFFF">e</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">amara</TD>
#   <TD bgcolor="00FFFF">amara</TD>
#   <TD bgcolor="00FFFF">amara</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">che</TD>
#   <TD bgcolor="00FFFF">che</TD>
#   <TD bgcolor="00FFFF">che</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">poco</TD>
#   <TD bgcolor="00FFFF">poco</TD>
#   <TD bgcolor="00FFFF">poco</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">e</TD>
#   <TD bgcolor="00FFFF">e</TD>
#   <TD bgcolor="00FFFF">e</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">piu</TD>
#   <TD bgcolor="00FFFF">piu</TD>
#   <TD bgcolor="00FFFF">piu</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">morte</TD>
#   <TD bgcolor="00FFFF">morte</TD>
#   <TD bgcolor="00FFFF">morte</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ma</TD>
#   <TD bgcolor="00FFFF">ma</TD>
#   <TD bgcolor="00FFFF">ma</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">per</TD>
#   <TD bgcolor="00FFFF">per</TD>
#   <TD bgcolor="00FFFF">per</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">tractar</TD>
#   <TD bgcolor="00FFFF">tractar</TD>
#   <TD bgcolor="00FFFF">tractar</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">del</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ben</TD>
#   <TD bgcolor="00FFFF">ben</TD>
#   <TD bgcolor="00FFFF">ben</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ch</TD>
#   <TD bgcolor="00FFFF">ch</TD>
#   <TD bgcolor="00FFFF">ch</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">io</TD>
#   <TD bgcolor="00FFFF">io</TD>
#   <TD bgcolor="00FFFF">io</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">vi</TD>
#   <TD bgcolor="00FFFF">vi</TD>
#   <TD bgcolor="00FFFF">vi</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">trovai</TD>
#   <TD bgcolor="00FFFF">trovai</TD>
#   <TD bgcolor="00FFFF">trovai</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">diro</TD>
#   <TD bgcolor="00FFFF">diro</TD>
#   <TD bgcolor="00FFFF">diro</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">dell</TD>
#   <TD bgcolor="00FFFF">dell</TD>
#   <TD bgcolor="00FFFF">dell</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">altre</TD>
#   <TD bgcolor="00FFFF">altre</TD>
#   <TD bgcolor="00FFFF">altre</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">cose</TD>
#   <TD bgcolor="00FFFF">cose</TD>
#   <TD bgcolor="00FFFF">cose</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ch</TD>
#   <TD bgcolor="00FFFF">ch</TD>
#   <TD bgcolor="00FFFF">ch</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">io</TD>
#   <TD bgcolor="00FFFF">io</TD>
#   <TD bgcolor="00FFFF">io</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">v</TD>
#   <TD bgcolor="00FFFF">v</TD>
#   <TD bgcolor="00FFFF">v</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FFFF">'</TD>
#   <TD bgcolor="00FF
# None

# %% [markdown]
# ## 2b. NLP (graph)

# %%
import csv
import re

#create the dictionary (here: lemma.csv consisting in two columns, separated by a comma. The first Column 'Original' are the strings as found in the text, the second column 'Normalised' contains the strings you want to replace them with. No whitespaces behind the strings.) 
Normit = {}
with open('pos_lemma.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'],  dialect='excel')
    for row in reader:
        Normit[row['Original']]= row['Normalised']

#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()
#testimone_P4 = open( "lettere/T196-part1-clean-P4.txt", encoding='utf-8' ).read()
#testimone_S2 = open( "lettere/T196-part1-clean-S2.txt", encoding='utf-8' ).read()
#testimone_S4 = open( "lettere/T196-part1-clean-S4.txt", encoding='utf-8' ).read()

# build a function to tokenize and to normalize by replace keys to be found in the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

#collate
tokens_TO = tokennormalizer(TO) 
tokens_RI = tokennormalizer(RI) 
tokens_CH = tokennormalizer(CH) 


witness_TO = { "id": "TO", "tokens":tokens_TO }
witness_RI = { "id": "RI", "tokens":tokens_RI }
witness_CH = { "id": "CH", "tokens":tokens_CH }


input = { "witnesses": [ witness_TO, witness_RI, witness_CH ] }

graph = collate(input, output='svg', segmentation=False)
print(graph)
# Out:
# None
