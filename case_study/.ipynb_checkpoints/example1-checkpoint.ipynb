# %% [markdown]
# ## 0. Normal

# %%
from collatex import *
collation = Collation()
W1 = open( "data/example1/W1.txt", encoding='utf-8' ).read()
W2 = open( "data/example1/W2.txt", encoding='utf-8' ).read()
W3 = open( "data/example1/W3.txt", encoding='utf-8' ).read()
W4 = open( "data/example1/W4.txt", encoding='utf-8' ).read()
collation.add_plain_witness( "W1", W1 )
collation.add_plain_witness( "W2", W2 )
collation.add_plain_witness( "W3", W3 )
collation.add_plain_witness( "W4", W4 )
table = collate(collation, output='html2', segmentation=False)
print(table)
# Out:
# <TABLE border="1" style="border: 1px solid #000000; border-collapse: collapse;" cellpadding="4">
#  <TR>
#   <TH>W1</TH>
#   <TH>W2</TH>
#   <TH>W3</TH>
#   <TH>W4</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">Lors</TD>
#   <TD bgcolor="FF5000">Lors</TD>
#   <TD bgcolor="FF5000">Lors</TD>
#   <TD bgcolor="FF5000">Adonc</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">li</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">conte</TD>
#   <TD bgcolor="00FFFF">conte</TD>
#   <TD bgcolor="00FFFF">conte</TD>
#   <TD bgcolor="00FFFF">conte</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">rois</TD>
#   <TD bgcolor="00FFFF">rois</TD>
#   <TD bgcolor="00FFFF">rois</TD>
#   <TD bgcolor="00FFFF">rois</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">a</TD>
#   <TD bgcolor="FF5000">a</TD>
#   <TD bgcolor="FF5000">a</TD>
#   <TD bgcolor="FF5000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">la</TD>
#   <TD bgcolor="FF5000">la</TD>
#   <TD bgcolor="FF5000">la</TD>
#   <TD bgcolor="FF5000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">reine</TD>
#   <TD bgcolor="FF5000">reine</TD>
#   <TD bgcolor="FF5000">roine</TD>
#   <TD bgcolor="FF5000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">coment</TD>
#   <TD bgcolor="FF5000">comment</TD>
#   <TD bgcolor="FF5000">coment</TD>
#   <TD bgcolor="FF5000">comment</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">dame</TD>
#   <TD bgcolor="00FFFF">dame</TD>
#   <TD bgcolor="00FFFF">dame</TD>
#   <TD bgcolor="00FFFF">dame</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">del</TD>
#   <TD bgcolor="FF5000">del</TD>
#   <TD bgcolor="FF5000">del</TD>
#   <TD bgcolor="FF5000">du</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">lac</TD>
#   <TD bgcolor="00FFFF">lac</TD>
#   <TD bgcolor="00FFFF">lac</TD>
#   <TD bgcolor="00FFFF">lac</TD>
#  </TR>
# </TABLE>
# None

# %% [markdown]
# ## 1. Near match

# %%
from collatex import *
collation = Collation()
W1 = open( "data/example1/W1.txt", encoding='utf-8' ).read()
W2 = open( "data/example1/W2.txt", encoding='utf-8' ).read()
W3 = open( "data/example1/W3.txt", encoding='utf-8' ).read()
W4 = open( "data/example1/W4.txt", encoding='utf-8' ).read()
collation.add_plain_witness( "W1", W1 )
collation.add_plain_witness( "W2", W2 )
collation.add_plain_witness( "W3", W3 )
collation.add_plain_witness( "W4", W4 )
table = collate(collation, output='html2', near_match=True, segmentation=False)
print(table)
# Out:
# <TABLE border="1" style="border: 1px solid #000000; border-collapse: collapse;" cellpadding="4">
#  <TR>
#   <TH>W1</TH>
#   <TH>W2</TH>
#   <TH>W3</TH>
#   <TH>W4</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">Lors</TD>
#   <TD bgcolor="FF5000">Lors</TD>
#   <TD bgcolor="FF5000">Lors</TD>
#   <TD bgcolor="FF5000">Adonc</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">li</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">conte</TD>
#   <TD bgcolor="00FFFF">conte</TD>
#   <TD bgcolor="00FFFF">conte</TD>
#   <TD bgcolor="00FFFF">conte</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">rois</TD>
#   <TD bgcolor="00FFFF">rois</TD>
#   <TD bgcolor="00FFFF">rois</TD>
#   <TD bgcolor="00FFFF">rois</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">a</TD>
#   <TD bgcolor="FF5000">a</TD>
#   <TD bgcolor="FF5000">a</TD>
#   <TD bgcolor="FF5000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">la</TD>
#   <TD bgcolor="FF5000">la</TD>
#   <TD bgcolor="FF5000">la</TD>
#   <TD bgcolor="FF5000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">reine</TD>
#   <TD bgcolor="FF5000">reine</TD>
#   <TD bgcolor="FF5000">roine</TD>
#   <TD bgcolor="FF5000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">coment</TD>
#   <TD bgcolor="FF5000">comment</TD>
#   <TD bgcolor="FF5000">coment</TD>
#   <TD bgcolor="FF5000">comment</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">dame</TD>
#   <TD bgcolor="00FFFF">dame</TD>
#   <TD bgcolor="00FFFF">dame</TD>
#   <TD bgcolor="00FFFF">dame</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">del</TD>
#   <TD bgcolor="FF5000">del</TD>
#   <TD bgcolor="FF5000">del</TD>
#   <TD bgcolor="FF5000">du</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">lac</TD>
#   <TD bgcolor="00FFFF">lac</TD>
#   <TD bgcolor="00FFFF">lac</TD>
#   <TD bgcolor="00FFFF">lac</TD>
#  </TR>
# </TABLE>
# None

# %% [markdown]
# **Comment:** nothing changed from the the previous method (0.Normal).

# %% [markdown]
# ## 2a. Dictionary (table)

# %%
import csv
import re

#create the dictionary (here: Dictionary.csv consisting in two columns, separated by a comma. The first Column 'Original' are the strings as found in the text, the second column 'Normalised' contains the strings you want to replace them with. No whitespaces behind the strings.) 
Normit = {}
with open('dictionary.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'],  dialect='excel')
    for row in reader:
        Normit[row['Original']]= row['Normalised']

#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()
#da lettere
#testimone_P4 = open( "lettere/T196-part1-clean-P4.txt", encoding='utf-8' ).read()
#testimone_S2 = open( "lettere/T196-part1-clean-S2.txt", encoding='utf-8' ).read()
#testimone_S4 = open( "lettere/T196-part1-clean-S4.txt", encoding='utf-8' ).read()

# build a function to tokenize and to normalize by replace keys to be found in the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

#collate
tokens_W1 = tokennormalizer(W1) 
tokens_W2 = tokennormalizer(W2) 
tokens_W3 = tokennormalizer(W3) 
tokens_W4 = tokennormalizer(W4) 

witness_W1 = { "id": "W1", "tokens":tokens_W1 }
witness_W2 = { "id": "W2", "tokens":tokens_W2 }
witness_W3 = { "id": "W3", "tokens":tokens_W3 }
witness_W4 = { "id": "W4", "tokens":tokens_W4 }


input = { "witnesses": [ witness_W1, witness_W2, witness_W3, witness_W4 ] }

table = collate(input, output='html2', segmentation=False)
# Out:
# <TABLE border="1" style="border: 1px solid #000000; border-collapse: collapse;" cellpadding="4">
#  <TR>
#   <TH>W1</TH>
#   <TH>W2</TH>
#   <TH>W3</TH>
#   <TH>W4</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">Lors</TD>
#   <TD bgcolor="FF5000">Lors</TD>
#   <TD bgcolor="FF5000">Lors</TD>
#   <TD bgcolor="FF5000">Adonc</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">li</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">conte</TD>
#   <TD bgcolor="00FFFF">conte</TD>
#   <TD bgcolor="00FFFF">conte</TD>
#   <TD bgcolor="00FFFF">conte</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">rois</TD>
#   <TD bgcolor="00FFFF">rois</TD>
#   <TD bgcolor="00FFFF">rois</TD>
#   <TD bgcolor="00FFFF">rois</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">a</TD>
#   <TD bgcolor="FF5000">a</TD>
#   <TD bgcolor="FF5000">a</TD>
#   <TD bgcolor="FF5000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">la</TD>
#   <TD bgcolor="FF5000">la</TD>
#   <TD bgcolor="FF5000">la</TD>
#   <TD bgcolor="FF5000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">reine</TD>
#   <TD bgcolor="FF5000">reine</TD>
#   <TD bgcolor="FF5000">roine</TD>
#   <TD bgcolor="FF5000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">coment</TD>
#   <TD bgcolor="00FFFF">comment</TD>
#   <TD bgcolor="00FFFF">coment</TD>
#   <TD bgcolor="00FFFF">comment</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">dame</TD>
#   <TD bgcolor="00FFFF">dame</TD>
#   <TD bgcolor="00FFFF">dame</TD>
#   <TD bgcolor="00FFFF">dame</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">du</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">lac</TD>
#   <TD bgcolor="00FFFF">lac</TD>
#   <TD bgcolor="00FFFF">lac</TD>
#   <TD bgcolor="00FFFF">lac</TD>
#  </TR>
# </TABLE>

# %% [markdown]
# **Comment:** this method requires a lot of manual work and leads to the best result.
#
# In the alignment table, however, the orthographic variation is completely lost. It would be great to have a way to differentiate, for example in   W1 W2 W3 *a la reine / roine*  vs  w4 NULL.

# %% [markdown]
# ## 2a. Dictionary  (graph)

# %%
import csv
import re

#create the dictionary (here: Dictionary.csv consisting in two columns, separated by a comma. The first Column 'Original' are the strings as found in the text, the second column 'Normalised' contains the strings you want to replace them with. No whitespaces behind the strings.) 
Normit = {}
with open('dictionary.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'],  dialect='excel')
    for row in reader:
        Normit[row['Original']]= row['Normalised']

#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()
#da lettere
#testimone_P4 = open( "lettere/T196-part1-clean-P4.txt", encoding='utf-8' ).read()
#testimone_S2 = open( "lettere/T196-part1-clean-S2.txt", encoding='utf-8' ).read()
#testimone_S4 = open( "lettere/T196-part1-clean-S4.txt", encoding='utf-8' ).read()

# build a function to tokenize and to normalize by replace keys to be found in the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

#collate
tokens_W1 = tokennormalizer(W1) 
tokens_W2 = tokennormalizer(W2) 
tokens_W3 = tokennormalizer(W3) 
tokens_W4 = tokennormalizer(W4) 

witness_W1 = { "id": "W1", "tokens":tokens_W1 }
witness_W2 = { "id": "W2", "tokens":tokens_W2 }
witness_W3 = { "id": "W3", "tokens":tokens_W3 }
witness_W4 = { "id": "W4", "tokens":tokens_W4 }


input = { "witnesses": [ witness_W1, witness_W2, witness_W3, witness_W4 ] }

graph = collate(input, output='svg', segmentation=False)
print(graph)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-9e8e1ab5ae1e> in <module>()
#      41 input = { "witnesses": [ witness_W1, witness_W2, witness_W3, witness_W4 ] }
#      42
# ---> 43 graph = collate(input, output='svg', segmentation=False)
#      44 print(graph)
#
# ~/anaconda3/lib/python3.6/site-packages/collatex/core_functions.py in collate(collation, output, layout, segmentation, near_match, astar, detect_transpositions, debug_scores, properties_filter, svg_output, indent, scheduler)
#      75     # check which output format is requested: graph or table
#      76     if output == "svg" or output == "svg_simple":
# ---> 77         return display_variant_graph_as_SVG(graph, svg_output, output)
#      78     if output == "graph":
#      79         return graph
#
# ~/anaconda3/lib/python3.6/site-packages/collatex/display_module.py in display_variant_graph_as_SVG(graph, svg_output, output)
#      70                 dot.node(mapping[n], '<<TABLE CELLSPACING="0">' + "".join(readings) + '</TABLE>>',{'shape': 'box'})
#      71         # add edges
# ---> 72         for u,v,edgedata in graph.graph.edges_iter(data=True):
#      73             dot.edge(str(mapping[u]), str(mapping[v]), edgedata["label"])
#      74         # render the dot graph to SVG
#
# AttributeError: 'DiGraph' object has no attribute 'edges_iter'

# %% [markdown]
# ## 2b. NLP (table)

# %% [markdown]
# This method requires the dictionary 'pos_lemma.csv', that can be created using 'create_pos_lemma.py'.

# %%
import csv
import re

Normit = {}
with open('pos_lemma.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'],  dialect='excel')
    for row in reader:
        Normit[row['Original']]= row['Normalised']

#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()
#da lettere
#testimone_P4 = open( "lettere/T196-part1-clean-P4.txt", encoding='utf-8' ).read()
#testimone_S2 = open( "lettere/T196-part1-clean-S2.txt", encoding='utf-8' ).read()
#testimone_S4 = open( "lettere/T196-part1-clean-S4.txt", encoding='utf-8' ).read()

# build a function to tokenize and to normalize by replace keys to be found in the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

#collate
tokens_W1 = tokennormalizer(W1) 
tokens_W2 = tokennormalizer(W2) 
tokens_W3 = tokennormalizer(W3) 
tokens_W4 = tokennormalizer(W4) 

witness_W1 = { "id": "W1", "tokens":tokens_W1 }
witness_W2 = { "id": "W2", "tokens":tokens_W2 }
witness_W3 = { "id": "W3", "tokens":tokens_W3 }
witness_W4 = { "id": "W4", "tokens":tokens_W4 }


input = { "witnesses": [ witness_W1, witness_W2, witness_W3, witness_W4 ] }

table = collate(input, output='html2', segmentation=False)
print(table)
# Out:
# <TABLE border="1" style="border: 1px solid #000000; border-collapse: collapse;" cellpadding="4">
#  <TR>
#   <TH>W1</TH>
#   <TH>W2</TH>
#   <TH>W3</TH>
#   <TH>W4</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">Lors</TD>
#   <TD bgcolor="FF5000">Lors</TD>
#   <TD bgcolor="FF5000">Lors</TD>
#   <TD bgcolor="FF5000">Adonc</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">li</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">conte</TD>
#   <TD bgcolor="00FFFF">conte</TD>
#   <TD bgcolor="00FFFF">conte</TD>
#   <TD bgcolor="00FFFF">conte</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">rois</TD>
#   <TD bgcolor="00FFFF">rois</TD>
#   <TD bgcolor="00FFFF">rois</TD>
#   <TD bgcolor="00FFFF">rois</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">a</TD>
#   <TD bgcolor="FF5000">a</TD>
#   <TD bgcolor="FF5000">a</TD>
#   <TD bgcolor="FF5000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">la</TD>
#   <TD bgcolor="FF5000">la</TD>
#   <TD bgcolor="FF5000">la</TD>
#   <TD bgcolor="FF5000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">reine</TD>
#   <TD bgcolor="FF5000">reine</TD>
#   <TD bgcolor="FF5000">roine</TD>
#   <TD bgcolor="FF5000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">coment</TD>
#   <TD bgcolor="00FFFF">comment</TD>
#   <TD bgcolor="00FFFF">coment</TD>
#   <TD bgcolor="00FFFF">comment</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">dame</TD>
#   <TD bgcolor="00FFFF">dame</TD>
#   <TD bgcolor="00FFFF">dame</TD>
#   <TD bgcolor="00FFFF">dame</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">du</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">lac</TD>
#   <TD bgcolor="00FFFF">lac</TD>
#   <TD bgcolor="00FFFF">lac</TD>
#   <TD bgcolor="00FFFF">lac</TD>
#  </TR>
# </TABLE>
# None

# %% [markdown]
# ## 2b. NLP (graph)

# %%
import csv
import re

#create the dictionary (here: Dictionary.csv consisting in two columns, separated by a comma. The first Column 'Original' are the strings as found in the text, the second column 'Normalised' contains the strings you want to replace them with. No whitespaces behind the strings.) 
Normit = {}
with open('pos_lemma.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'],  dialect='excel')
    for row in reader:
        Normit[row['Original']]= row['Normalised']

#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()
#da lettere
#testimone_P4 = open( "lettere/T196-part1-clean-P4.txt", encoding='utf-8' ).read()
#testimone_S2 = open( "lettere/T196-part1-clean-S2.txt", encoding='utf-8' ).read()
#testimone_S4 = open( "lettere/T196-part1-clean-S4.txt", encoding='utf-8' ).read()

# build a function to tokenize and to normalize by replace keys to be found in the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

#collate
tokens_W1 = tokennormalizer(W1) 
tokens_W2 = tokennormalizer(W2) 
tokens_W3 = tokennormalizer(W3) 
tokens_W4 = tokennormalizer(W4) 

witness_W1 = { "id": "W1", "tokens":tokens_W1 }
witness_W2 = { "id": "W2", "tokens":tokens_W2 }
witness_W3 = { "id": "W3", "tokens":tokens_W3 }
witness_W4 = { "id": "W4", "tokens":tokens_W4 }


input = { "witnesses": [ witness_W1, witness_W2, witness_W3, witness_W4 ] }

graph = collate(input, output='svg')
print(graph)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-5900bb26cfd9> in <module>()
#      41 input = { "witnesses": [ witness_W1, witness_W2, witness_W3, witness_W4 ] }
#      42
# ---> 43 graph = collate(input, output='svg')
#      44 print(graph)
#
# ~/anaconda3/lib/python3.6/site-packages/collatex/core_functions.py in collate(collation, output, layout, segmentation, near_match, astar, detect_transpositions, debug_scores, properties_filter, svg_output, indent, scheduler)
#      71     # join parallel segments
#      72     if segmentation:
# ---> 73         join(graph)
#      74         ranking = VariantGraphRanking.of(graph)
#      75     # check which output format is requested: graph or table
#
# ~/anaconda3/lib/python3.6/site-packages/collatex/core_classes.py in join(graph)
#     327         out_edges = graph.out_edges(vertex)
#     328         if len(out_edges) is 1:
# --> 329             (_, join_candidate) = out_edges[0]
#     330             can_join = join_candidate != end and len(graph.in_edges(join_candidate)) == 1
#     331             if can_join:
#
# TypeError: 'OutEdgeDataView' object does not support indexing
