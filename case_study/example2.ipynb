# %% [markdown]
# ## 0. Normal

# %%
from collatex import *
collation = Collation()
W1 = open( "data/example2/W1.txt", encoding='utf-8' ).read()
W2 = open( "data/example2/W2.txt", encoding='utf-8' ).read()
W3 = open( "data/example2/W3.txt", encoding='utf-8' ).read()
W4 = open( "data/example2/W4.txt", encoding='utf-8' ).read()
collation.add_plain_witness( "W1", W1 )
collation.add_plain_witness( "W2", W2 )
collation.add_plain_witness( "W3", W3 )
collation.add_plain_witness( "W4", W4 )
table = collate(collation, output='html2', segmentation=False)
print(table)
# Out:
# <TABLE border="1" style="border: 1px solid #000000; border-collapse: collapse;" cellpadding="4">
#  <TR>
#   <TH>W1</TH>
#   <TH>W2</TH>
#   <TH>W3</TH>
#   <TH>W4</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">car</TD>
#   <TD bgcolor="FF5000">car</TD>
#   <TD bgcolor="FF5000">quar</TD>
#   <TD bgcolor="FF5000">quar</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ou</TD>
#   <TD bgcolor="00FFFF">ou</TD>
#   <TD bgcolor="00FFFF">ou</TD>
#   <TD bgcolor="00FFFF">ou</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">vos</TD>
#   <TD bgcolor="00FFFF">vos</TD>
#   <TD bgcolor="00FFFF">vos</TD>
#   <TD bgcolor="00FFFF">vos</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">lairoiz</TD>
#   <TD bgcolor="FF5000">lairoiz</TD>
#   <TD bgcolor="FF5000">lesroiz</TD>
#   <TD bgcolor="FF5000">lerroiz</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">les</TD>
#   <TD bgcolor="FF5000">les</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">autres</TD>
#   <TD bgcolor="FF5000">autres</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">a</TD>
#   <TD bgcolor="00FFFF">a</TD>
#   <TD bgcolor="00FFFF">a</TD>
#   <TD bgcolor="00FFFF">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">achever</TD>
#   <TD bgcolor="00FFFF">achever</TD>
#   <TD bgcolor="00FFFF">achever</TD>
#   <TD bgcolor="00FFFF">achever</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">les</TD>
#   <TD bgcolor="FF5000">les</TD>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">aventures</TD>
#   <TD bgcolor="00FFFF">aventures</TD>
#   <TD bgcolor="00FFFF">aventures</TD>
#   <TD bgcolor="00FFFF">aventures</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">par</TD>
#   <TD bgcolor="00FFFF">par</TD>
#   <TD bgcolor="00FFFF">par</TD>
#   <TD bgcolor="00FFFF">par</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">proesce</TD>
#   <TD bgcolor="FF5000">proesce</TD>
#   <TD bgcolor="FF5000">proece</TD>
#   <TD bgcolor="FF5000">proece</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">que</TD>
#   <TD bgcolor="00FFFF">que</TD>
#   <TD bgcolor="00FFFF">que</TD>
#   <TD bgcolor="00FFFF">que</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">diex</TD>
#   <TD bgcolor="FF5000">dex</TD>
#   <TD bgcolor="FF5000">dex</TD>
#   <TD bgcolor="FF5000">dex</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">a</TD>
#   <TD bgcolor="FF5000">ait</TD>
#   <TD bgcolor="FF5000">ait</TD>
#   <TD bgcolor="FF5000">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">mise</TD>
#   <TD bgcolor="FF5000">mise</TD>
#   <TD bgcolor="FF5000">mise</TD>
#   <TD bgcolor="FF5000">mis</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">en</TD>
#   <TD bgcolor="00FFFF">en</TD>
#   <TD bgcolor="00FFFF">en</TD>
#   <TD bgcolor="00FFFF">en</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">chevalerie</TD>
#   <TD bgcolor="FF5000">chevalier</TD>
#   <TD bgcolor="FF5000">chevalerie</TD>
#   <TD bgcolor="FF5000">chevalier</TD>
#  </TR>
# </TABLE>
# None

# %% [markdown]
# ## 1. Near match

# %%
from collatex import *
collation = Collation()
W1 = open( "data/example2/W1.txt", encoding='utf-8' ).read()
W2 = open( "data/example2/W2.txt", encoding='utf-8' ).read()
W3 = open( "data/example2/W3.txt", encoding='utf-8' ).read()
W4 = open( "data/example2/W4.txt", encoding='utf-8' ).read()
collation.add_plain_witness( "W1", W1 )
collation.add_plain_witness( "W2", W2 )
collation.add_plain_witness( "W3", W3 )
collation.add_plain_witness( "W4", W4 )
table = collate(collation, output='html2', near_match=True, segmentation=False)
print(table)
# Out:
# <TABLE border="1" style="border: 1px solid #000000; border-collapse: collapse;" cellpadding="4">
#  <TR>
#   <TH>W1</TH>
#   <TH>W2</TH>
#   <TH>W3</TH>
#   <TH>W4</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">car</TD>
#   <TD bgcolor="FF5000">car</TD>
#   <TD bgcolor="FF5000">quar</TD>
#   <TD bgcolor="FF5000">quar</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ou</TD>
#   <TD bgcolor="00FFFF">ou</TD>
#   <TD bgcolor="00FFFF">ou</TD>
#   <TD bgcolor="00FFFF">ou</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">vos</TD>
#   <TD bgcolor="00FFFF">vos</TD>
#   <TD bgcolor="00FFFF">vos</TD>
#   <TD bgcolor="00FFFF">vos</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">lairoiz</TD>
#   <TD bgcolor="FF5000">lairoiz</TD>
#   <TD bgcolor="FF5000">lesroiz</TD>
#   <TD bgcolor="FF5000">lerroiz</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">les</TD>
#   <TD bgcolor="FF5000">les</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">autres</TD>
#   <TD bgcolor="FF5000">autres</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">a</TD>
#   <TD bgcolor="00FFFF">a</TD>
#   <TD bgcolor="00FFFF">a</TD>
#   <TD bgcolor="00FFFF">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">achever</TD>
#   <TD bgcolor="00FFFF">achever</TD>
#   <TD bgcolor="00FFFF">achever</TD>
#   <TD bgcolor="00FFFF">achever</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">les</TD>
#   <TD bgcolor="FF5000">les</TD>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">aventures</TD>
#   <TD bgcolor="00FFFF">aventures</TD>
#   <TD bgcolor="00FFFF">aventures</TD>
#   <TD bgcolor="00FFFF">aventures</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">par</TD>
#   <TD bgcolor="00FFFF">par</TD>
#   <TD bgcolor="00FFFF">par</TD>
#   <TD bgcolor="00FFFF">par</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">proesce</TD>
#   <TD bgcolor="FF5000">proesce</TD>
#   <TD bgcolor="FF5000">proece</TD>
#   <TD bgcolor="FF5000">proece</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">que</TD>
#   <TD bgcolor="00FFFF">que</TD>
#   <TD bgcolor="00FFFF">que</TD>
#   <TD bgcolor="00FFFF">que</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">diex</TD>
#   <TD bgcolor="FF5000">dex</TD>
#   <TD bgcolor="FF5000">dex</TD>
#   <TD bgcolor="FF5000">dex</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">a</TD>
#   <TD bgcolor="FF5000">ait</TD>
#   <TD bgcolor="FF5000">ait</TD>
#   <TD bgcolor="FF5000">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">mise</TD>
#   <TD bgcolor="FF5000">mise</TD>
#   <TD bgcolor="FF5000">mise</TD>
#   <TD bgcolor="FF5000">mis</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">en</TD>
#   <TD bgcolor="00FFFF">en</TD>
#   <TD bgcolor="00FFFF">en</TD>
#   <TD bgcolor="00FFFF">en</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">chevalerie</TD>
#   <TD bgcolor="FF5000">chevalier</TD>
#   <TD bgcolor="FF5000">chevalerie</TD>
#   <TD bgcolor="FF5000">chevalier</TD>
#  </TR>
# </TABLE>
# None

# %% [markdown]
# ## 2a. Dictionary (table)
#
# This method requires the manual creation of a dictionary, with original and normalized words. The dictionary here includes terms for all the example, so there is no need to change it from one example to the other.

# %%
import csv
import re

#create the dictionary (here: Dictionary.csv consisting in two columns, separated by a comma. The first Column 'Original' are the strings as found in the text, the second column 'Normalised' contains the strings you want to replace them with. No whitespaces behind the strings.) 
Normit = {}
with open('dictionary.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'],  dialect='excel')
    for row in reader:
        Normit[row['Original']]= row['Normalised']

#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()
#da lettere
#testimone_P4 = open( "lettere/T196-part1-clean-P4.txt", encoding='utf-8' ).read()
#testimone_S2 = open( "lettere/T196-part1-clean-S2.txt", encoding='utf-8' ).read()
#testimone_S4 = open( "lettere/T196-part1-clean-S4.txt", encoding='utf-8' ).read()

# build a function to tokenize and to normalize by replace keys to be found in the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

#collate
tokens_W1 = tokennormalizer(W1) 
tokens_W2 = tokennormalizer(W2) 
tokens_W3 = tokennormalizer(W3) 
tokens_W4 = tokennormalizer(W4) 

witness_W1 = { "id": "W1", "tokens":tokens_W1 }
witness_W2 = { "id": "W2", "tokens":tokens_W2 }
witness_W3 = { "id": "W3", "tokens":tokens_W3 }
witness_W4 = { "id": "W4", "tokens":tokens_W4 }


input = { "witnesses": [ witness_W1, witness_W2, witness_W3, witness_W4 ] }

table = collate(input, output='html2', segmentation=False)
# Out:
# <TABLE border="1" style="border: 1px solid #000000; border-collapse: collapse;" cellpadding="4">
#  <TR>
#   <TH>W1</TH>
#   <TH>W2</TH>
#   <TH>W3</TH>
#   <TH>W4</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">car</TD>
#   <TD bgcolor="00FFFF">car</TD>
#   <TD bgcolor="00FFFF">quar</TD>
#   <TD bgcolor="00FFFF">quar</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ou</TD>
#   <TD bgcolor="00FFFF">ou</TD>
#   <TD bgcolor="00FFFF">ou</TD>
#   <TD bgcolor="00FFFF">ou</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">vos</TD>
#   <TD bgcolor="00FFFF">vos</TD>
#   <TD bgcolor="00FFFF">vos</TD>
#   <TD bgcolor="00FFFF">vos</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">lairoiz</TD>
#   <TD bgcolor="00FFFF">lairoiz</TD>
#   <TD bgcolor="00FFFF">lesroiz</TD>
#   <TD bgcolor="00FFFF">lerroiz</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">les</TD>
#   <TD bgcolor="FF5000">les</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">autres</TD>
#   <TD bgcolor="FF5000">autres</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">a</TD>
#   <TD bgcolor="00FFFF">a</TD>
#   <TD bgcolor="00FFFF">a</TD>
#   <TD bgcolor="00FFFF">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">achever</TD>
#   <TD bgcolor="00FFFF">achever</TD>
#   <TD bgcolor="00FFFF">achever</TD>
#   <TD bgcolor="00FFFF">achever</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">les</TD>
#   <TD bgcolor="FF5000">les</TD>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">aventures</TD>
#   <TD bgcolor="00FFFF">aventures</TD>
#   <TD bgcolor="00FFFF">aventures</TD>
#   <TD bgcolor="00FFFF">aventures</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">par</TD>
#   <TD bgcolor="00FFFF">par</TD>
#   <TD bgcolor="00FFFF">par</TD>
#   <TD bgcolor="00FFFF">par</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">proesce</TD>
#   <TD bgcolor="00FFFF">proesce</TD>
#   <TD bgcolor="00FFFF">proece</TD>
#   <TD bgcolor="00FFFF">proece</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">que</TD>
#   <TD bgcolor="00FFFF">que</TD>
#   <TD bgcolor="00FFFF">que</TD>
#   <TD bgcolor="00FFFF">que</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">diex</TD>
#   <TD bgcolor="00FFFF">dex</TD>
#   <TD bgcolor="00FFFF">dex</TD>
#   <TD bgcolor="00FFFF">dex</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">a</TD>
#   <TD bgcolor="FF5000">ait</TD>
#   <TD bgcolor="FF5000">ait</TD>
#   <TD bgcolor="FF5000">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">mise</TD>
#   <TD bgcolor="FF5000">mise</TD>
#   <TD bgcolor="FF5000">mise</TD>
#   <TD bgcolor="FF5000">mis</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">en</TD>
#   <TD bgcolor="00FFFF">en</TD>
#   <TD bgcolor="00FFFF">en</TD>
#   <TD bgcolor="00FFFF">en</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">chevalerie</TD>
#   <TD bgcolor="FF5000">chevalier</TD>
#   <TD bgcolor="FF5000">chevalerie</TD>
#   <TD bgcolor="FF5000">chevalier</TD>
#  </TR>
# </TABLE>

# %% [markdown]
# ## 2a. Dictionary  (graph)

# %%
import csv
import re

#create the dictionary (here: Dictionary.csv consisting in two columns, separated by a comma. The first Column 'Original' are the strings as found in the text, the second column 'Normalised' contains the strings you want to replace them with. No whitespaces behind the strings.) 
Normit = {}
with open('dictionary.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'],  dialect='excel')
    for row in reader:
        Normit[row['Original']]= row['Normalised']

#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()
#da lettere
#testimone_P4 = open( "lettere/T196-part1-clean-P4.txt", encoding='utf-8' ).read()
#testimone_S2 = open( "lettere/T196-part1-clean-S2.txt", encoding='utf-8' ).read()
#testimone_S4 = open( "lettere/T196-part1-clean-S4.txt", encoding='utf-8' ).read()

# build a function to tokenize and to normalize by replace keys to be found in the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

#collate
tokens_W1 = tokennormalizer(W1) 
tokens_W2 = tokennormalizer(W2) 
tokens_W3 = tokennormalizer(W3) 
tokens_W4 = tokennormalizer(W4) 

witness_W1 = { "id": "W1", "tokens":tokens_W1 }
witness_W2 = { "id": "W2", "tokens":tokens_W2 }
witness_W3 = { "id": "W3", "tokens":tokens_W3 }
witness_W4 = { "id": "W4", "tokens":tokens_W4 }


input = { "witnesses": [ witness_W1, witness_W2, witness_W3, witness_W4 ] }

table = collate(input, output='svg', segmentation=False)

# %% [markdown]
# ## 2b. NLP (table)
#
# This method requires the dictionary 'pos_lemma.csv' ('pos_lemma_example2.csv'), that can be created using 'create_pos_lemma.py' ('create_pos_lemma_example2.py').

# %%
import csv
import re

Normit = {}
with open('pos_lemma_example2.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'],  dialect='excel')
    for row in reader:
        Normit[row['Original']]= row['Normalised']

#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()
#da lettere
#testimone_P4 = open( "lettere/T196-part1-clean-P4.txt", encoding='utf-8' ).read()
#testimone_S2 = open( "lettere/T196-part1-clean-S2.txt", encoding='utf-8' ).read()
#testimone_S4 = open( "lettere/T196-part1-clean-S4.txt", encoding='utf-8' ).read()

# build a function to tokenize and to normalize by replace keys to be found in the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

#collate
tokens_W1 = tokennormalizer(W1) 
tokens_W2 = tokennormalizer(W2) 
tokens_W3 = tokennormalizer(W3) 
tokens_W4 = tokennormalizer(W4) 

witness_W1 = { "id": "W1", "tokens":tokens_W1 }
witness_W2 = { "id": "W2", "tokens":tokens_W2 }
witness_W3 = { "id": "W3", "tokens":tokens_W3 }
witness_W4 = { "id": "W4", "tokens":tokens_W4 }


input = { "witnesses": [ witness_W1, witness_W2, witness_W3, witness_W4 ] }

table = collate(input, output='html2', segmentation=False)
print(table)
# Out:
# <TABLE border="1" style="border: 1px solid #000000; border-collapse: collapse;" cellpadding="4">
#  <TR>
#   <TH>W1</TH>
#   <TH>W2</TH>
#   <TH>W3</TH>
#   <TH>W4</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">car</TD>
#   <TD bgcolor="00FFFF">car</TD>
#   <TD bgcolor="00FFFF">quar</TD>
#   <TD bgcolor="00FFFF">quar</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ou</TD>
#   <TD bgcolor="00FFFF">ou</TD>
#   <TD bgcolor="00FFFF">ou</TD>
#   <TD bgcolor="00FFFF">ou</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">vos</TD>
#   <TD bgcolor="00FFFF">vos</TD>
#   <TD bgcolor="00FFFF">vos</TD>
#   <TD bgcolor="00FFFF">vos</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">lairoiz</TD>
#   <TD bgcolor="FF5000">lairoiz</TD>
#   <TD bgcolor="FF5000">lesroiz</TD>
#   <TD bgcolor="FF5000">lerroiz</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">les</TD>
#   <TD bgcolor="FF5000">les</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">autres</TD>
#   <TD bgcolor="FF5000">autres</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">a</TD>
#   <TD bgcolor="00FFFF">a</TD>
#   <TD bgcolor="00FFFF">a</TD>
#   <TD bgcolor="00FFFF">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">achever</TD>
#   <TD bgcolor="00FFFF">achever</TD>
#   <TD bgcolor="00FFFF">achever</TD>
#   <TD bgcolor="00FFFF">achever</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">les</TD>
#   <TD bgcolor="FF5000">les</TD>
#   <TD bgcolor="FF5000">-</TD>
#   <TD bgcolor="FF5000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">aventures</TD>
#   <TD bgcolor="00FFFF">aventures</TD>
#   <TD bgcolor="00FFFF">aventures</TD>
#   <TD bgcolor="00FFFF">aventures</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">par</TD>
#   <TD bgcolor="00FFFF">par</TD>
#   <TD bgcolor="00FFFF">par</TD>
#   <TD bgcolor="00FFFF">par</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">proesce</TD>
#   <TD bgcolor="00FFFF">proesce</TD>
#   <TD bgcolor="00FFFF">proece</TD>
#   <TD bgcolor="00FFFF">proece</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">que</TD>
#   <TD bgcolor="00FFFF">que</TD>
#   <TD bgcolor="00FFFF">que</TD>
#   <TD bgcolor="00FFFF">que</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">diex</TD>
#   <TD bgcolor="00FFFF">dex</TD>
#   <TD bgcolor="00FFFF">dex</TD>
#   <TD bgcolor="00FFFF">dex</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">a</TD>
#   <TD bgcolor="FF5000">ait</TD>
#   <TD bgcolor="FF5000">ait</TD>
#   <TD bgcolor="FF5000">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">mise</TD>
#   <TD bgcolor="FF5000">mise</TD>
#   <TD bgcolor="FF5000">mise</TD>
#   <TD bgcolor="FF5000">mis</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">en</TD>
#   <TD bgcolor="00FFFF">en</TD>
#   <TD bgcolor="00FFFF">en</TD>
#   <TD bgcolor="00FFFF">en</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF5000">chevalerie</TD>
#   <TD bgcolor="FF5000">chevalier</TD>
#   <TD bgcolor="FF5000">chevalerie</TD>
#   <TD bgcolor="FF5000">chevalier</TD>
#  </TR>
# </TABLE>
# None

# %% [markdown]
# ## 2b. NLP (graph)

# %%
import csv
import re

Normit = {}
with open('pos_lemma_example2.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'],  dialect='excel')
    for row in reader:
        Normit[row['Original']]= row['Normalised']

#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()
#da lettere
#testimone_P4 = open( "lettere/T196-part1-clean-P4.txt", encoding='utf-8' ).read()
#testimone_S2 = open( "lettere/T196-part1-clean-S2.txt", encoding='utf-8' ).read()
#testimone_S4 = open( "lettere/T196-part1-clean-S4.txt", encoding='utf-8' ).read()

# build a function to tokenize and to normalize by replace keys to be found in the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

#collate
tokens_W1 = tokennormalizer(W1) 
tokens_W2 = tokennormalizer(W2) 
tokens_W3 = tokennormalizer(W3) 
tokens_W4 = tokennormalizer(W4) 

witness_W1 = { "id": "W1", "tokens":tokens_W1 }
witness_W2 = { "id": "W2", "tokens":tokens_W2 }
witness_W3 = { "id": "W3", "tokens":tokens_W3 }
witness_W4 = { "id": "W4", "tokens":tokens_W4 }


input = { "witnesses": [ witness_W1, witness_W2, witness_W3, witness_W4 ] }

table = collate(input, output='svg', segmentation=False)
print(table)
# Out:
# None
