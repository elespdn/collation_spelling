# %%
from collatex import *
collation = Collation()
W1 = open( "data/test/W1.txt", encoding='utf-8' ).read()
W2 = open( "data/test/W2.txt", encoding='utf-8' ).read()
W3 = open( "data/test/W3.txt", encoding='utf-8' ).read()
collation.add_plain_witness( "W1", W1 )
collation.add_plain_witness( "W2", W2 )
collation.add_plain_witness( "W3", W3 )
table = collate(collation, output='html2', segmentation=False)
print(table)
# Out:
# <TABLE border="1" style="border: 1px solid #000000; border-collapse: collapse;" cellpadding="4">
#  <TR>
#   <TH>W1</TH>
#   <TH>W2</TH>
#   <TH>W3</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="#ffd700">Artus</TD>
#   <TD bgcolor="#ffd700">Et</TD>
#   <TD bgcolor="#ffd700">Et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ffd700">,</TD>
#   <TD bgcolor="#ffd700">alors</TD>
#   <TD bgcolor="#ffd700">quant</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ffd700">dist</TD>
#   <TD bgcolor="#ffd700">-</TD>
#   <TD bgcolor="#ffd700">ele</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ffd700">la</TD>
#   <TD bgcolor="#ffd700">la</TD>
#   <TD bgcolor="#ffd700">le</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ffd700">reine</TD>
#   <TD bgcolor="#ffd700">reine</TD>
#   <TD bgcolor="#ffd700">vit</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ffd700">-</TD>
#   <TD bgcolor="#ffd700">-</TD>
#   <TD bgcolor="#ffd700">,</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ffd700">-</TD>
#   <TD bgcolor="#ffd700">-</TD>
#   <TD bgcolor="#ffd700">si</TD>
# ...

# %%
from collatex import *
collation = Collation()
W1 = open( "data/test/novalis/aujourdhui.txt", encoding='utf-8' ).read()
W2 = open( "data/test/novalis/receuil.txt", encoding='utf-8' ).read()
collation.add_plain_witness( "Aujourd'hui", W1 )
collation.add_plain_witness( "Receuil", W2 )
table = collate(collation, output='html2', segmentation=False)
print(table)
# Out:
# <TABLE border="1" style="border: 1px solid #000000; border-collapse: collapse;" cellpadding="4">
#  <TR>
#   <TH>Aujourd'hui</TH>
#   <TH>Receuil</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="#cdcdcd">–</TD>
#   <TD bgcolor="#cdcdcd">–</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#cdcdcd">Ah</TD>
#   <TD bgcolor="#cdcdcd">Ah </TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ffd700">,</TD>
#   <TD bgcolor="#ffd700">!</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ffd700">de</TD>
#   <TD bgcolor="#ffd700">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#cdcdcd">qui</TD>
#   <TD bgcolor="#cdcdcd">qui</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ffd700">le</TD>
#   <TD bgcolor="#ffd700">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ffd700">cœur</TD>
#   <TD bgcolor="#ffd700">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#cdcdcd">ne</TD>
#   <TD bgcolor="#cdcdcd">ne</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ffd700">se</TD>
#   <TD bgcolor="#ffd700">sent</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ffd700">meut</TD>
# ...

# %%
from collatex import *
collation = Collation()
W1 = open( "data/test/novalis/aujourdhui.txt", encoding='utf-8' ).read()
W2 = open( "data/test/novalis/receuil.txt", encoding='utf-8' ).read()

collation.add_plain_witness( "Aujourd'hui", W1 )
collation.add_plain_witness( "Receuil", W2 )
table = collate(collation, output='html2', segmentation=False)
# Out:
# <TABLE border="1" style="border: 1px solid #000000; border-collapse: collapse;" cellpadding="4">
#  <TR>
#   <TH>Aujourd'hui</TH>
#   <TH>Receuil</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="#cdcdcd">–</TD>
#   <TD bgcolor="#cdcdcd">–</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#cdcdcd">Ah</TD>
#   <TD bgcolor="#cdcdcd">Ah </TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ffd700">,</TD>
#   <TD bgcolor="#ffd700">!</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ffd700">de</TD>
#   <TD bgcolor="#ffd700">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#cdcdcd">qui</TD>
#   <TD bgcolor="#cdcdcd">qui</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ffd700">le</TD>
#   <TD bgcolor="#ffd700">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ffd700">cœur</TD>
#   <TD bgcolor="#ffd700">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#cdcdcd">ne</TD>
#   <TD bgcolor="#cdcdcd">ne</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ffd700">se</TD>
#   <TD bgcolor="#ffd700">sent</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ffd700">meut</TD>
# ...

# %%
print(table)
# Out:
# None
