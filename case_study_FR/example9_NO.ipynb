# %% [markdown]
# # Example 9
#
# ToC:
# 0. Normal
# 1. Near match
# 3. Manual dictionary (table and graph)
# 4. Automatic dictionary (table and graph)

# %% [markdown]
# ## 1. Normal

# %%
from collatex import *
collation = Collation()
W1 = open( "data/example9/W1.txt", encoding='utf-8' ).read()
W2 = open( "data/example9/W2.txt", encoding='utf-8' ).read()
W3 = open( "data/example9/W3.txt", encoding='utf-8' ).read()
collation.add_plain_witness( "W1", W1 )
collation.add_plain_witness( "W2", W2 )
collation.add_plain_witness( "W3", W3 )
table = collate(collation, output='html2', segmentation=False)
print(table)
# Out:
# <TABLE border="1" style="border: 1px solid #000000; border-collapse: collapse;" cellpadding="4">
#  <TR>
#   <TH>W1</TH>
#   <TH>W2</TH>
#   <TH>W3</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">Grant</TD>
#   <TD bgcolor="#ece31d">Or</TD>
#   <TD bgcolor="#ece31d">Grans</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">dist</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">li</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">contes</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">que</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">grans</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">fu</TD>
#   <TD bgcolor="#d3d3d3">fu</TD>
#   <TD bgcolor="#d3d3d3">fu</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">la</TD>
#   <TD bgcolor="#ece31d">la</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">ioie</TD>
#   <TD bgcolor="#ece31d">joie</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">ce</TD>
#   <TD bgcolor="#ece31d">et</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">dit</TD>
#   <TD bgcolor="#ece31d">l</TD>
#   <TD bgcolor="#ece31d">l</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">li</TD>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">contes</TD>
#   <TD bgcolor="#ece31d">onors</TD>
#   <TD bgcolor="#ece31d">ouneurs</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">que</TD>
#   <TD bgcolor="#ece31d">que</TD>
#   <TD bgcolor="#ece31d">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">l</TD>
#   <TD bgcolor="#ece31d">l</TD>
#   <TD bgcolor="#ece31d">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">joie</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">en</TD>
#   <TD bgcolor="#ece31d">en</TD>
#   <TD bgcolor="#ece31d">ke</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">on</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">fist</TD>
#   <TD bgcolor="#d3d3d3">fist</TD>
#   <TD bgcolor="#d3d3d3">fist</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">de</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">Lanceloht</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">a</TD>
#   <TD bgcolor="#d3d3d3">a</TD>
#   <TD bgcolor="#d3d3d3">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">Acaron</TD>
#   <TD bgcolor="#ece31d">Lancelot</TD>
#   <TD bgcolor="#ece31d">Lancelot</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">le</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">Tenebrox</TD>
#   <TD bgcolor="#ece31d">Escalon</TD>
#   <TD bgcolor="#ece31d">Escalon</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">le</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">Tenebreus</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">la</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">ou</TD>
#   <TD bgcolor="#d3d3d3">ou</TD>
#   <TD bgcolor="#d3d3d3">ou</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">conquist</TD>
#   <TD bgcolor="#d3d3d3">conquist</TD>
#   <TD bgcolor="#d3d3d3">conquist</TD>
#  </TR>
# </TABLE>
# None

# %% [markdown]
# ## 2. Near match

# %% [markdown]
# In this method, the parameter 'near_match' of the function 'collate' is switched on, for allowing fuzzy matches in the alignment (or better, in a second round of alignment, which refines the first).

# %%
from collatex import *
collation = Collation()
W1 = open( "data/example9/W1.txt", encoding='utf-8' ).read()
W2 = open( "data/example9/W2.txt", encoding='utf-8' ).read()
W3 = open( "data/example9/W3.txt", encoding='utf-8' ).read()
collation.add_plain_witness( "W1", W1 )
collation.add_plain_witness( "W2", W2 )
collation.add_plain_witness( "W3", W3 )
table = collate(collation, output='html2', near_match=True, segmentation=False)
print(table)
# Out:
# <TABLE border="1" style="border: 1px solid #000000; border-collapse: collapse;" cellpadding="4">
#  <TR>
#   <TH>W1</TH>
#   <TH>W2</TH>
#   <TH>W3</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">Grant</TD>
#   <TD bgcolor="#ece31d">Or</TD>
#   <TD bgcolor="#ece31d">Grans</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">dist</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">li</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">contes</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">que</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">grans</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">fu</TD>
#   <TD bgcolor="#d3d3d3">fu</TD>
#   <TD bgcolor="#d3d3d3">fu</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">la</TD>
#   <TD bgcolor="#ece31d">la</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">ioie</TD>
#   <TD bgcolor="#ece31d">joie</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">ce</TD>
#   <TD bgcolor="#ece31d">et</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">dit</TD>
#   <TD bgcolor="#ece31d">l</TD>
#   <TD bgcolor="#ece31d">l</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">li</TD>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">contes</TD>
#   <TD bgcolor="#ece31d">onors</TD>
#   <TD bgcolor="#ece31d">ouneurs</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">que</TD>
#   <TD bgcolor="#ece31d">que</TD>
#   <TD bgcolor="#ece31d">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">l</TD>
#   <TD bgcolor="#ece31d">l</TD>
#   <TD bgcolor="#ece31d">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">joie</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">ke</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">en</TD>
#   <TD bgcolor="#ece31d">en</TD>
#   <TD bgcolor="#ece31d">on</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">fist</TD>
#   <TD bgcolor="#d3d3d3">fist</TD>
#   <TD bgcolor="#d3d3d3">fist</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">de</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">Lanceloht</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">a</TD>
#   <TD bgcolor="#d3d3d3">a</TD>
#   <TD bgcolor="#d3d3d3">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">Lancelot</TD>
#   <TD bgcolor="#ece31d">Lancelot</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">Acaron</TD>
#   <TD bgcolor="#ece31d">Escalon</TD>
#   <TD bgcolor="#ece31d">Escalon</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">le</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">le</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">Tenebrox</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">Tenebreus</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">la</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">ou</TD>
#   <TD bgcolor="#d3d3d3">ou</TD>
#   <TD bgcolor="#d3d3d3">ou</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">conquist</TD>
#   <TD bgcolor="#d3d3d3">conquist</TD>
#   <TD bgcolor="#d3d3d3">conquist</TD>
#  </TR>
# </TABLE>
# None

# %% [markdown]
# ## 3. Manual dictionary (table and graph)
#
# This method requires the manual creation of a dictionary, with original and normalised forms. The dictionary here includes terms for all the example, so there is no need to change it from one example to the other. It is stored in **dictionaries/manual_dictionary.csv**.
#
# The normalised forms are used for the alignment.
#
# This method produces three outputs:
# - a table and a graph, for which see below here;
# - an external table, where formal and substantive variants are separated.

# %%
from collatex import *
collation = Collation()
import csv
import re
from general_functions import table_manualDictionary, tokennormalizer


W1 = open( "data/example9/W1.txt", encoding='utf-8' ).read()
W2 = open( "data/example9/W2.txt", encoding='utf-8' ).read()
W3 = open( "data/example9/W3.txt", encoding='utf-8' ).read()

#create the dictionary consisting of two columns, separated by a comma.
# The first Column 'Original' are the strings as found in the text, 
# the second column 'Normalised' contains the strings you want to replace them with. 
# No whitespaces behind the strings.
Normit = {}
with open('dictionaries/manual_dictionary.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'])
    for row in reader:
        Normit[row['Original']]= row['Normalised']
#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()

# build a function to tokenize and to normalize by replace keys to be found in 
# the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

tokens_W1 = tokennormalizer(W1) 
tokens_W2 = tokennormalizer(W2) 
tokens_W3 = tokennormalizer(W3) 

witness_W1 = { "id": "W1", "tokens":tokens_W1 }
witness_W2 = { "id": "W2", "tokens":tokens_W2 }
witness_W3 = { "id": "W3", "tokens":tokens_W3 }


input = { "witnesses": [ witness_W1, witness_W2, witness_W3 ] }

table = collate(input, output='html2', segmentation=False)
print(table)
graphSvg = collate(input, output='svg', segmentation=False)
print(graphSvg)

graph_manualDictionary = collate(input, output='json', segmentation=False)
table_manualDictionary(graph_manualDictionary, 'example9')
print('external table created!')
# Out:
# <TABLE border="1" style="border: 1px solid #000000; border-collapse: collapse;" cellpadding="4">
#  <TR>
#   <TH>W1</TH>
#   <TH>W2</TH>
#   <TH>W3</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">Or</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">dist</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">li</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">contes</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">que</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">Grant</TD>
#   <TD bgcolor="#d3d3d3">grans</TD>
#   <TD bgcolor="#d3d3d3">Grans</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">fu</TD>
#   <TD bgcolor="#d3d3d3">fu</TD>
#   <TD bgcolor="#d3d3d3">fu</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">la</TD>
#   <TD bgcolor="#ece31d">la</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">ioie</TD>
#   <TD bgcolor="#ece31d">joie</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">ce</TD>
#   <TD bgcolor="#ece31d">et</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">dit</TD>
#   <TD bgcolor="#ece31d">l</TD>
#   <TD bgcolor="#ece31d">l</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">li</TD>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">contes</TD>
#   <TD bgcolor="#ece31d">onors</TD>
#   <TD bgcolor="#ece31d">ouneurs</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">que</TD>
#   <TD bgcolor="#ece31d">que</TD>
#   <TD bgcolor="#ece31d">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">l</TD>
#   <TD bgcolor="#ece31d">l</TD>
#   <TD bgcolor="#ece31d">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">joie</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">en</TD>
#   <TD bgcolor="#ece31d">en</TD>
#   <TD bgcolor="#ece31d">ke</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">on</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">fist</TD>
#   <TD bgcolor="#d3d3d3">fist</TD>
#   <TD bgcolor="#d3d3d3">fist</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">de</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">Lanceloht</TD>
#   <TD bgcolor="#d3d3d3">Lancelot</TD>
#   <TD bgcolor="#d3d3d3">Lancelot</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">a</TD>
#   <TD bgcolor="#d3d3d3">a</TD>
#   <TD bgcolor="#d3d3d3">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">Acaron</TD>
#   <TD bgcolor="#ece31d">Escalon</TD>
#   <TD bgcolor="#ece31d">Escalon</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">le</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">le</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">Tenebrox</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">Tenebreus</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">la</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">ou</TD>
#   <TD bgcolor="#d3d3d3">ou</TD>
#   <TD bgcolor="#d3d3d3">ou</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">conquist</TD>
#   <TD bgcolor="#d3d3d3">conquist</TD>
#   <TD bgcolor="#d3d3d3">conquist</TD>
#  </TR>
# </TABLE>
# None
# None
# external table created!

# %% [markdown]
# ## 4. Automatic dictionary (table and graph)

# %% [markdown]
# This method creates a dictionary, using the [TreeTagger](http://www.cis.uni-muenchen.de/~schmid/tools/TreeTagger/) parameters for old French:
# - the [Nouveau corpus d’Amsterdam](http://www.uni-stuttgart.de/lingrom/stein/corpus) parameter file provides POS annotation and lemma, here only lemma is used;
# - the [Base de français médiéval](http://txm.bfm-corpus.org) parameter file provides POS annotation, used here.
#
# The joint effort of the two équipes are now available in the Github repository [Medieval French Language Toolkit](https://github.com/sheiden/Medieval-French-Language-Toolkit).
#
# The tagged forms are used for the alignment.
#
# This method produces three outputs:
# - a table and a graph, for which see below here;
# - an external table, where formal and substantive variants are separated.

# %%
from collatex import *
collation = Collation()
import csv, re
from general_functions import tag_poslemma
from general_functions import table_automaticDictionary



tag_poslemma('example9')  # ex: create_poslemma('example1')
print("taggedAll and taggedDistinct created in folder Dictionaries/ !")


W1 = open( "data/example9/W1.txt", encoding='utf-8' ).read()
W2 = open( "data/example9/W2.txt", encoding='utf-8' ).read()
W3 = open( "data/example9/W3.txt", encoding='utf-8' ).read()

Normit = {}
with open('dictionaries/taggedDistinct_example9.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'])
    for row in reader:
        Normit[row['Original']]= row['Normalised']

#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()

# build a function to tokenize and to normalize by replace keys to be 
# found in the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

#collate
tokens_W1 = tokennormalizer(W1) 
tokens_W2 = tokennormalizer(W2) 
tokens_W3 = tokennormalizer(W3) 

witness_W1 = { "id": "W1", "tokens":tokens_W1 }
witness_W2 = { "id": "W2", "tokens":tokens_W2 }
witness_W3 = { "id": "W3", "tokens":tokens_W3 }


input = { "witnesses": [ witness_W1, witness_W2, witness_W3 ] }

table = collate(input, output='html2', segmentation=False)
print(table)
graphSvg = collate(input, output='svg', segmentation=False)
print(graphSvg)

graph_automaticDictionary = collate(input, output='json', segmentation=False)
print(graph_automaticDictionary)
table_automaticDictionary(graph_automaticDictionary, 'example9')
print('table created!')
# Out:
# taggedAll and taggedDistinct created in folder Dictionaries/ !
# <TABLE border="1" style="border: 1px solid #000000; border-collapse: collapse;" cellpadding="4">
#  <TR>
#   <TH>W1</TH>
#   <TH>W2</TH>
#   <TH>W3</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">Or</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">dist</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">li</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">contes</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">que</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">Grant</TD>
#   <TD bgcolor="#d3d3d3">grans</TD>
#   <TD bgcolor="#d3d3d3">Grans</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">fu</TD>
#   <TD bgcolor="#d3d3d3">fu</TD>
#   <TD bgcolor="#d3d3d3">fu</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">la</TD>
#   <TD bgcolor="#ece31d">la</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">ioie</TD>
#   <TD bgcolor="#ece31d">joie</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">ce</TD>
#   <TD bgcolor="#ece31d">et</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">dit</TD>
#   <TD bgcolor="#ece31d">l</TD>
#   <TD bgcolor="#ece31d">l</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">li</TD>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">contes</TD>
#   <TD bgcolor="#ece31d">onors</TD>
#   <TD bgcolor="#ece31d">ouneurs</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">que</TD>
#   <TD bgcolor="#ece31d">que</TD>
#   <TD bgcolor="#ece31d">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">l</TD>
#   <TD bgcolor="#ece31d">l</TD>
#   <TD bgcolor="#ece31d">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">joie</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">en</TD>
#   <TD bgcolor="#ece31d">en</TD>
#   <TD bgcolor="#ece31d">ke</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">on</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">fist</TD>
#   <TD bgcolor="#d3d3d3">fist</TD>
#   <TD bgcolor="#d3d3d3">fist</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">de</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">Lanceloht</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">a</TD>
#   <TD bgcolor="#d3d3d3">a</TD>
#   <TD bgcolor="#d3d3d3">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">Acaron</TD>
#   <TD bgcolor="#ece31d">Lancelot</TD>
#   <TD bgcolor="#ece31d">Lancelot</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">le</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">Tenebrox</TD>
#   <TD bgcolor="#ece31d">Escalon</TD>
#   <TD bgcolor="#ece31d">Escalon</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">le</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">Tenebreus</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">la</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">ou</TD>
#   <TD bgcolor="#d3d3d3">ou</TD>
#   <TD bgcolor="#d3d3d3">ou</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">conquist</TD>
#   <TD bgcolor="#d3d3d3">conquist</TD>
#   <TD bgcolor="#d3d3d3">conquist</TD>
#  </TR>
# </TABLE>
# None
# None
# {"table": [[null, null, null, null, null, [{"_sigil": "W1", "_token_array_position": 0, "n": "ADJqua_grant", "t": "Grant "}], [{"_sigil": "W1", "_token_array_position": 1, "n": "VERcjg_estre", "t": "fu "}], [{"_sigil": "W1", "_token_array_position": 2, "n": "DETdef_lö", "t": "la "}], [{"_sigil": "W1", "_token_array_position": 3, "n": "NOMcom_joie|joöe", "t": "ioie "}], [{"_sigil": "W1", "_token_array_position": 4, "n": "PROdem_ce", "t": "ce "}], [{"_sigil": "W1", "_token_array_position": 5, "n": "VERcjg_dire", "t": "dit "}], [{"_sigil": "W1", "_token_array_position": 6, "n": "DETdef_le", "t": "li "}], [{"_sigil": "W1", "_token_array_position": 7, "n": "NOMcom_conte", "t": "contes "}], [{"_sigil": "W1", "_token_array_position": 8, "n": "CONsub_que", "t": "que "}], [{"_sigil": "W1", "_token_array_position": 9, "n": "l", "t": "l"}], [{"_sigil": "W1", "_token_array_position": 10, "n": "'", "t": "'"}], [{"_sigil": "W1", "_token_array_position": 11, "n": "PROadv_en", "t": "en "}], null, [{"_sigil": "W1", "_token_array_position": 12, "n": "VERcjg_faire|feire|fere", "t": "fist "}], [{"_sigil": "W1", "_token_array_position": 13, "n": "PRE_de", "t": "de "}], [{"_sigil": "W1", "_token_array_position": 14, "n": "NOMpro_Lanceloht", "t": "Lanceloht "}], [{"_sigil": "W1", "_token_array_position": 15, "n": "PRE_a", "t": "a "}], [{"_sigil": "W1", "_token_array_position": 16, "n": "NOMpro_Acaron", "t": "Acaron "}], [{"_sigil": "W1", "_token_array_position": 17, "n": "DETdef_le", "t": "le "}], [{"_sigil": "W1", "_token_array_position": 18, "n": "NOMcom_Tenebrox", "t": "Tenebrox "}], null, null, [{"_sigil": "W1", "_token_array_position": 19, "n": "DETdef_lö", "t": "la "}], [{"_sigil": "W1", "_token_array_position": 20, "n": "PROrel_o|oö", "t": "ou "}], [{"_sigil": "W1", "_token_array_position": 21, "n": "PROper_il", "t": "il "}], [{"_sigil": "W1", "_token_array_position": 22, "n": "VERcjg_conquerre", "t": "conquist\n"}]], [[{"_sigil": "W2", "_token_array_position": 24, "n": "ADVgen_or", "t": "Or "}], [{"_sigil": "W2", "_token_array_position": 25, "n": "VERcjg_dire", "t": "dist "}], [{"_sigil": "W2", "_token_array_position": 26, "n": "DETdef_le", "t": "li "}], [{"_sigil": "W2", "_token_array_position": 27, "n": "NOMcom_conte", "t": "contes "}], [{"_sigil": "W2", "_token_array_position": 28, "n": "CONsub_que", "t": "que "}], [{"_sigil": "W2", "_token_array_position": 29, "n": "ADJqua_grant", "t": "grans "}], [{"_sigil": "W2", "_token_array_position": 30, "n": "VERcjg_estre", "t": "fu "}], [{"_sigil": "W2", "_token_array_position": 31, "n": "DETdef_lö", "t": "la "}], [{"_sigil": "W2", "_token_array_position": 32, "n": "NOMcom_joie|joöe", "t": "joie "}], [{"_sigil": "W2", "_token_array_position": 33, "n": "CONcoo_et", "t": "et "}], [{"_sigil": "W2", "_token_array_position": 34, "n": "l", "t": "l"}], [{"_sigil": "W2", "_token_array_position": 35, "n": "'", "t": "'"}], [{"_sigil": "W2", "_token_array_position": 36, "n": "NOMcom_onor", "t": "onors "}], [{"_sigil": "W2", "_token_array_position": 37, "n": "CONsub_que", "t": "que "}], [{"_sigil": "W2", "_token_array_position": 38, "n": "l", "t": "l"}], [{"_sigil": "W2", "_token_array_position": 39, "n": "'", "t": "'"}], [{"_sigil": "W2", "_token_array_position": 40, "n": "PROadv_en", "t": "en "}], null, [{"_sigil": "W2", "_token_array_position": 41, "n": "VERcjg_faire|feire|fere", "t": "fist "}], null, null, [{"_sigil": "W2", "_token_array_position": 42, "n": "PRE_a", "t": "a "}], [{"_sigil": "W2", "_token_array_position": 43, "n": "NOMpro_Lancelot", "t": "Lancelot "}], [{"_sigil": "W2", "_token_array_position": 44, "n": "PRE_a", "t": "a "}], [{"_sigil": "W2", "_token_array_position": 45, "n": "NOMpro_Escalon", "t": "Escalon "}], null, null, null, [{"_sigil": "W2", "_token_array_position": 46, "n": "PROrel_o|oö", "t": "ou "}], [{"_sigil": "W2", "_token_array_position": 47, "n": "PROper_il", "t": "il "}], [{"_sigil": "W2", "_token_array_position": 48, "n": "VERcjg_conquerre", "t": "conquist\n"}]], [null, nu ...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-86ff76aed245> in <module>()
#      55 graph_automaticDictionary = collate(input, output='json', segmentation=False)
#      56 print(graph_automaticDictionary)
# ---> 57 table_automaticDictionary(graph_automaticDictionary, 'example9')
#      58 print('table created!')
#
# ~/Github/elespdn/collation_spelling/case_study_FR/general_functions.py in table_automaticDictionary(graph, dirName)
#     114                 listTdPos.append(tdPos)    ## and put their pos in a list (listTdPos)
#     115
# --> 116                 tdLemma = td.get('ana').split('_')[1]
#     117                 listTdLemma.append(tdLemma)   ## and put their lemmas in a list (listTdLemma)
#     118
#
# IndexError: list index out of range
