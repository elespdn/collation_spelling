# %% [markdown]
# # Example 1
#
# ToC:
# 0. Normal
# 1. Near match
# 2. Prepare text
# 4. Automatic dictionary (table and graph)

# %% [markdown]
# ## 1. Normal (on tokenized texts)

# %%
from collatex import *
collation = Collation()
A = open( "data/example1/A.txt", encoding='utf-8' ).read()
F = open( "data/example1/F.txt", encoding='utf-8' ).read()
G = open( "data/example1/G.txt", encoding='utf-8' ).read()
H = open( "data/example1/H.txt", encoding='utf-8' ).read()
M = open( "data/example1/M.txt", encoding='utf-8' ).read()
P = open( "data/example1/P.txt", encoding='utf-8' ).read()
R = open( "data/example1/R.txt", encoding='utf-8' ).read()
S = open( "data/example1/S.txt", encoding='utf-8' ).read()
V = open( "data/example1/V.txt", encoding='utf-8' ).read()
collation.add_plain_witness( "A", A )
collation.add_plain_witness( "F", F )
collation.add_plain_witness( "G", G )
collation.add_plain_witness( "H", H )
collation.add_plain_witness( "M", F )
collation.add_plain_witness( "P", G )
collation.add_plain_witness( "R", H )
collation.add_plain_witness( "S", F )
collation.add_plain_witness( "V", G )
table = collate(collation, output='html2', segmentation=False)
print(table)
# Out:
# <TABLE border="1" style="border: 1px solid #000000; border-collapse: collapse;" cellpadding="4">
#  <TR>
#   <TH>A</TH>
#   <TH>F</TH>
#   <TH>G</TH>
#   <TH>H</TH>
#   <TH>M</TH>
#   <TH>P</TH>
#   <TH>R</TH>
#   <TH>S</TH>
#   <TH>V</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">a</TD>
#   <TD bgcolor="#d3d3d3">a</TD>
#   <TD bgcolor="#d3d3d3">a</TD>
#   <TD bgcolor="#d3d3d3">a</TD>
#   <TD bgcolor="#d3d3d3">a</TD>
#   <TD bgcolor="#d3d3d3">a</TD>
#   <TD bgcolor="#d3d3d3">a</TD>
#   <TD bgcolor="#d3d3d3">a</TD>
#   <TD bgcolor="#d3d3d3">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">lui</TD>
#   <TD bgcolor="#ece31d">li</TD>
#   <TD bgcolor="#ece31d">soi</TD>
#   <TD bgcolor="#ece31d">lui</TD>
#   <TD bgcolor="#ece31d">li</TD>
#   <TD bgcolor="#ece31d">soi</TD>
#   <TD bgcolor="#ece31d">lui</TD>
#   <TD bgcolor="#ece31d">li</TD>
#   <TD bgcolor="#ece31d">soi</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">meisme</TD>
#   <TD bgcolor="#ece31d">meisme</TD>
#   <TD bgcolor="#ece31d">meismes</TD>
#   <TD bgcolor="#ece31d">meismes</TD>
#   <TD bgcolor="#ece31d">meisme</TD>
#   <TD bgcolor="#ece31d">meismes</TD>
#   <TD bgcolor="#ece31d">meismes</TD>
#   <TD bgcolor="#ece31d">meisme</TD>
#   <TD bgcolor="#ece31d">meismes</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">consele</TD>
#   <TD bgcolor="#ece31d">conselle</TD>
#   <TD bgcolor="#ece31d">conseille</TD>
#   <TD bgcolor="#ece31d">consoille</TD>
#   <TD bgcolor="#ece31d">conselle</TD>
#   <TD bgcolor="#ece31d">conseille</TD>
#   <TD bgcolor="#ece31d">consoille</TD>
#   <TD bgcolor="#ece31d">conselle</TD>
#   <TD bgcolor="#ece31d">conseille</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">as</TD>
#   <TD bgcolor="#ece31d">alquel</TD>
#   <TD bgcolor="#ece31d">auquel</TD>
#   <TD bgcolor="#ece31d">auquel</TD>
#   <TD bgcolor="#ece31d">alquel</TD>
#   <TD bgcolor="#ece31d">auquel</TD>
#   <TD bgcolor="#ece31d">auquel</TD>
#   <TD bgcolor="#ece31d">alquel</TD>
#   <TD bgcolor="#ece31d">auquel</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">ques</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">d</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">d</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">aus</TD>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">aus</TD>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">des</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">dex</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">et</TD>
#   <TD bgcolor="#ece31d">lors</TD>
#   <TD bgcolor="#ece31d">lors</TD>
#   <TD bgcolor="#ece31d">et</TD>
#   <TD bgcolor="#ece31d">lors</TD>
#   <TD bgcolor="#ece31d">lors</TD>
#   <TD bgcolor="#ece31d">et</TD>
#   <TD bgcolor="#ece31d">lors</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">dist</TD>
#   <TD bgcolor="#ece31d">dist</TD>
#   <TD bgcolor="#ece31d">dit</TD>
#   <TD bgcolor="#ece31d">dit</TD>
#   <TD bgcolor="#ece31d">dist</TD>
#   <TD bgcolor="#ece31d">dit</TD>
#   <TD bgcolor="#ece31d">dit</TD>
#   <TD bgcolor="#ece31d">dist</TD>
#   <TD bgcolor="#ece31d">dit</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">que</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">qu</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">qu</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">au</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">lyon</TD>
#   <TD bgcolor="#ece31d">lyon</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">lyon</TD>
#   <TD bgcolor="#ece31d">lyon</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">lyon</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">le</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">le</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">le</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">le</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">lion</TD>
#   <TD bgcolor="#ece31d">lion</TD>
#   <TD bgcolor="#ece31d">fera</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">lion</TD>
#   <TD bgcolor="#ece31d">fera</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">lion</TD>
#   <TD bgcolor="#ece31d">fera</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">secoura</TD>
#   <TD bgcolor="#ece31d">se</TD>
#   <TD bgcolor="#ece31d">c</TD>
#   <TD bgcolor="#ece31d">se</TD>
#   <TD bgcolor="#ece31d">se</TD>
#   <TD bgcolor="#ece31d">c</TD>
#   <TD bgcolor="#ece31d">se</TD>
#   <TD bgcolor="#ece31d">se</TD>
#   <TD bgcolor="#ece31d">c</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">tendra</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">tanra</TD>
#   <TD bgcolor="#ece31d">tendra</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">tanra</TD>
#   <TD bgcolor="#ece31d">tendra</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">qu</TD>
#   <TD bgcolor="#ece31d">qu</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">qu</TD>
#   <TD bgcolor="#ece31d">qu</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">qu</TD>
#   <TD bgcolor="#ece31d">qu</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">as</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">venimeus</TD>
#   <TD bgcolor="#d3d3d3">venimeus</TD>
#   <TD bgcolor="#d3d3d3">venimeus</TD>
#   <TD bgcolor="#d3d3d3">venimeus</TD>
#   <TD bgcolor="#d3d3d3">venimeus</TD>
#   <TD bgcolor="#d3d3d3">venimeus</TD>
#   <TD bgcolor="#d3d3d3">venimeus</TD>
#   <TD bgcolor="#d3d3d3">venimeus</TD>
#   <TD bgcolor="#d3d3d3">venimeus</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">ne</TD>
#   <TD bgcolor="#ece31d">et</TD>
#   <TD bgcolor="#ece31d">et</TD>
#   <TD bgcolor="#ece31d">ne</TD>
#   <TD bgcolor="#ece31d">et</TD>
#   <TD bgcolor="#ece31d">et</TD>
#   <TD bgcolor="#ece31d">ne</TD>
#   <TD bgcolor="#ece31d">et</TD>
#   <TD bgcolor="#ece31d">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">as</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#  </TR>
# None

# %%
## 1. Normal (on not tokenized texts)

# %%
from collatex import *
collation = Collation()
A = open( "data/example1original/A.txt", encoding='utf-8' ).read()
F = open( "data/example1original/F.txt", encoding='utf-8' ).read()
G = open( "data/example1original/G.txt", encoding='utf-8' ).read()
H = open( "data/example1original/H.txt", encoding='utf-8' ).read()
M = open( "data/example1original/M.txt", encoding='utf-8' ).read()
P = open( "data/example1original/P.txt", encoding='utf-8' ).read()
R = open( "data/example1original/R.txt", encoding='utf-8' ).read()
S = open( "data/example1original/S.txt", encoding='utf-8' ).read()
V = open( "data/example1original/V.txt", encoding='utf-8' ).read()
collation.add_plain_witness( "A", A )
collation.add_plain_witness( "F", F )
collation.add_plain_witness( "G", G )
collation.add_plain_witness( "H", H )
collation.add_plain_witness( "M", F )
collation.add_plain_witness( "P", G )
collation.add_plain_witness( "R", H )
collation.add_plain_witness( "S", F )
collation.add_plain_witness( "V", G )
table = collate(collation, output='html2', segmentation=False)
print(table)
# Out:
# <TABLE border="1" style="border: 1px solid #000000; border-collapse: collapse;" cellpadding="4">
#  <TR>
#   <TH>A</TH>
#   <TH>F</TH>
#   <TH>G</TH>
#   <TH>H</TH>
#   <TH>M</TH>
#   <TH>P</TH>
#   <TH>R</TH>
#   <TH>S</TH>
#   <TH>V</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">lui</TD>
#   <TD bgcolor="#ece31d">li</TD>
#   <TD bgcolor="#ece31d">soi</TD>
#   <TD bgcolor="#ece31d">lui</TD>
#   <TD bgcolor="#ece31d">li</TD>
#   <TD bgcolor="#ece31d">soi</TD>
#   <TD bgcolor="#ece31d">lui</TD>
#   <TD bgcolor="#ece31d">li</TD>
#   <TD bgcolor="#ece31d">soi</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">meisme</TD>
#   <TD bgcolor="#ece31d">meisme</TD>
#   <TD bgcolor="#ece31d">meismes</TD>
#   <TD bgcolor="#ece31d">meismes</TD>
#   <TD bgcolor="#ece31d">meisme</TD>
#   <TD bgcolor="#ece31d">meismes</TD>
#   <TD bgcolor="#ece31d">meismes</TD>
#   <TD bgcolor="#ece31d">meisme</TD>
#   <TD bgcolor="#ece31d">meismes</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">consele</TD>
#   <TD bgcolor="#ece31d">conselle</TD>
#   <TD bgcolor="#ece31d">conseille</TD>
#   <TD bgcolor="#ece31d">consoille</TD>
#   <TD bgcolor="#ece31d">conselle</TD>
#   <TD bgcolor="#ece31d">conseille</TD>
#   <TD bgcolor="#ece31d">consoille</TD>
#   <TD bgcolor="#ece31d">conselle</TD>
#   <TD bgcolor="#ece31d">conseille</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">As</TD>
#   <TD bgcolor="#ece31d">Alquel</TD>
#   <TD bgcolor="#ece31d">Auquel</TD>
#   <TD bgcolor="#ece31d">Auquel</TD>
#   <TD bgcolor="#ece31d">Alquel</TD>
#   <TD bgcolor="#ece31d">Auquel</TD>
#   <TD bgcolor="#ece31d">Auquel</TD>
#   <TD bgcolor="#ece31d">Alquel</TD>
#   <TD bgcolor="#ece31d">Auquel</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">ques</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">d</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">d</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">des</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">dex</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">aus</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">aus</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">.</TD>
#   <TD bgcolor="#ece31d">.</TD>
#   <TD bgcolor="#ece31d">.</TD>
#   <TD bgcolor="#ece31d">.</TD>
#   <TD bgcolor="#ece31d">.</TD>
#   <TD bgcolor="#ece31d">.</TD>
#   <TD bgcolor="#ece31d">.</TD>
#   <TD bgcolor="#ece31d">.</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">.</TD>
#   <TD bgcolor="#ece31d">.</TD>
#   <TD bgcolor="#ece31d">.</TD>
#   <TD bgcolor="#ece31d">.</TD>
#   <TD bgcolor="#ece31d">.</TD>
#   <TD bgcolor="#ece31d">.</TD>
#   <TD bgcolor="#ece31d">.</TD>
#   <TD bgcolor="#ece31d">.</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">Dist</TD>
#   <TD bgcolor="#ece31d">Et</TD>
#   <TD bgcolor="#ece31d">Lors</TD>
#   <TD bgcolor="#ece31d">Lors</TD>
#   <TD bgcolor="#ece31d">Et</TD>
#   <TD bgcolor="#ece31d">Lors</TD>
#   <TD bgcolor="#ece31d">Lors</TD>
#   <TD bgcolor="#ece31d">Et</TD>
#   <TD bgcolor="#ece31d">Lors</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">que</TD>
#   <TD bgcolor="#ece31d">dist</TD>
#   <TD bgcolor="#ece31d">dit</TD>
#   <TD bgcolor="#ece31d">dit</TD>
#   <TD bgcolor="#ece31d">dist</TD>
#   <TD bgcolor="#ece31d">dit</TD>
#   <TD bgcolor="#ece31d">dit</TD>
#   <TD bgcolor="#ece31d">dist</TD>
#   <TD bgcolor="#ece31d">dit</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">le</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">qu</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">qu</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">au</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">lion</TD>
#   <TD bgcolor="#ece31d">lion</TD>
#   <TD bgcolor="#ece31d">lyon</TD>
#   <TD bgcolor="#ece31d">lyon</TD>
#   <TD bgcolor="#ece31d">lion</TD>
#   <TD bgcolor="#ece31d">lyon</TD>
#   <TD bgcolor="#ece31d">lyon</TD>
#   <TD bgcolor="#ece31d">lion</TD>
#   <TD bgcolor="#ece31d">lyon</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">secoura</TD>
#   <TD bgcolor="#ece31d">se</TD>
#   <TD bgcolor="#ece31d">le</TD>
#   <TD bgcolor="#ece31d">se</TD>
#   <TD bgcolor="#ece31d">se</TD>
#   <TD bgcolor="#ece31d">le</TD>
#   <TD bgcolor="#ece31d">se</TD>
#   <TD bgcolor="#ece31d">se</TD>
#   <TD bgcolor="#ece31d">le</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">tendra</TD>
#   <TD bgcolor="#ece31d">fera</TD>
#   <TD bgcolor="#ece31d">tanra</TD>
#   <TD bgcolor="#ece31d">tendra</TD>
#   <TD bgcolor="#ece31d">fera</TD>
#   <TD bgcolor="#ece31d">tanra</TD>
#   <TD bgcolor="#ece31d">tendra</TD>
#   <TD bgcolor="#ece31d">fera</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">Qu</TD>
#   <TD bgcolor="#ece31d">Qu</TD>
#   <TD bgcolor="#ece31d">C</TD>
#   <TD bgcolor="#ece31d">Qu</TD>
#   <TD bgcolor="#ece31d">Qu</TD>
#   <TD bgcolor="#ece31d">C</TD>
#   <TD bgcolor="#ece31d">Qu</TD>
#   <TD bgcolor="#ece31d">Qu</TD>
#   <TD bgcolor="#ece31d">C</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">'</TD>
#   <TD bgcolor="#d3d3d3">'</TD>
#   <TD bgcolor="#d3d3d3">'</TD>
#   <TD bgcolor="#d3d3d3">'</TD>
#   <TD bgcolor="#d3d3d3">'</TD>
#   <TD bgcolor="#d3d3d3">'</TD>
#   <TD bgcolor="#d3d3d3">'</TD>
#   <TD bgcolor="#d3d3d3">'</TD>
#   <TD bgcolor="#d3d3d3">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">as</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">venimeus</TD>
#   <TD bgcolor="#d3d3d3">venim
# None

# %% [markdown]
# ## 2. Near match

# %% [markdown]
# In this method, the parameter 'near_match' of the function 'collate' is switched on, for allowing fuzzy matches in the alignment (or better, in a second round of alignment, which refines the first).

# %%
from collatex import *
collation = Collation()
A = open( "data/example1/A.txt", encoding='utf-8' ).read()
F = open( "data/example1/F.txt", encoding='utf-8' ).read()
G = open( "data/example1/G.txt", encoding='utf-8' ).read()
H = open( "data/example1/H.txt", encoding='utf-8' ).read()
M = open( "data/example1/M.txt", encoding='utf-8' ).read()
P = open( "data/example1/P.txt", encoding='utf-8' ).read()
R = open( "data/example1/R.txt", encoding='utf-8' ).read()
S = open( "data/example1/S.txt", encoding='utf-8' ).read()
V = open( "data/example1/V.txt", encoding='utf-8' ).read()
collation.add_plain_witness( "A", A )
collation.add_plain_witness( "F", F )
collation.add_plain_witness( "G", G )
collation.add_plain_witness( "H", H )
collation.add_plain_witness( "M", F )
collation.add_plain_witness( "P", G )
collation.add_plain_witness( "R", H )
collation.add_plain_witness( "S", F )
collation.add_plain_witness( "V", G )
table = collate(collation, output='html2', near_match=True, segmentation=False)
print(table)

# %% [markdown]
# ## 3. Prepare text for next collation
# ### All to lower cases, strip punctuation and apostrophes

# %%
## All to lower cases and strip punctuation and apostrophes
## this goes file per file. To do: all files together

from itertools import chain
from glob import glob
import re

with open('data/example1original/V.txt', 'r') as file:
    file = file.read()
    
    file = re.sub('\.','',re.sub("'",' ',file))

lines = [line.lower() for line in file]

with open('data/example1/V.txt', 'w') as out:
     out.writelines(lines)

# %% [markdown]
# ## 4. Automatic dictionary (table and graph)

# %% [markdown]
# This method creates a dictionary, using the [TreeTagger](http://www.cis.uni-muenchen.de/~schmid/tools/TreeTagger/) parameters for old French:
# - the [Nouveau corpus d’Amsterdam](http://www.uni-stuttgart.de/lingrom/stein/corpus) parameter file provides POS annotation and lemma, here only lemma is used;
# - the [Base de français médiéval](http://txm.bfm-corpus.org) parameter file provides POS annotation, used here.
#
# The joint effort of the two équipes are now available in the Github repository [Medieval French Language Toolkit](https://github.com/sheiden/Medieval-French-Language-Toolkit).
#
# The tagged forms are used for the alignment.
#
# This method produces three outputs:
# - a table and a graph, for which see below here;
# - an external table, where formal and substantive variants are separated.

# %%
from collatex import *
collation = Collation()
import csv, re
from general_functions import tag_poslemma
from general_functions import table_automaticDictionary


tag_poslemma('example1')  # ex: create_poslemma('example1')
print("taggedAll and taggedDistinct created in folder Dictionaries/ !")


A = open( "data/example1/A.txt", encoding='utf-8' ).read()
F = open( "data/example1/F.txt", encoding='utf-8' ).read()
G = open( "data/example1/G.txt", encoding='utf-8' ).read()
H = open( "data/example1/H.txt", encoding='utf-8' ).read()
M = open( "data/example1/M.txt", encoding='utf-8' ).read()
P = open( "data/example1/P.txt", encoding='utf-8' ).read()
R = open( "data/example1/R.txt", encoding='utf-8' ).read()
S = open( "data/example1/S.txt", encoding='utf-8' ).read()
V = open( "data/example1/V.txt", encoding='utf-8' ).read()


#create the dictionary consisting of two columns, separated by a comma.
# The first Column 'Original' are the strings as found in the text, 
# the second column 'Normalised' contains the strings you want to replace them with. 
# No whitespaces behind the strings.
Normit = {}
with open('dictionaries/taggedDistinct_example1.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'])
    for row in reader:
        Normit[row['Original']]= row['Normalised']

#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()

# build a function to tokenize and to normalize by replace keys to be 
# found in the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

tokens_A = tokennormalizer(A) 
tokens_F = tokennormalizer(F) 
tokens_G = tokennormalizer(G) 
tokens_H = tokennormalizer(H) 
tokens_M = tokennormalizer(M) 
tokens_P = tokennormalizer(P) 
tokens_R = tokennormalizer(R) 
tokens_S = tokennormalizer(S) 
tokens_V = tokennormalizer(V) 

witness_A = { "id": "W1", "tokens":tokens_A }
witness_F = { "id": "W2", "tokens":tokens_F }
witness_G = { "id": "W3", "tokens":tokens_G }
witness_H = { "id": "W4", "tokens":tokens_H }
witness_M = { "id": "W5", "tokens":tokens_M }
witness_P = { "id": "W6", "tokens":tokens_P }
witness_R = { "id": "W7", "tokens":tokens_R }
witness_S = { "id": "W8", "tokens":tokens_S }
witness_V = { "id": "W9", "tokens":tokens_V }


input = { "witnesses": [ witness_A, witness_F, witness_G, witness_H, witness_M, witness_P, witness_R, witness_S, witness_V ] }



table = collate(input, output='html2', segmentation=False)
graphSvg = collate(input, output='svg', segmentation=False)

graph_automaticDictionary = collate(input, output='json', segmentation=False)
table_automaticDictionary(graph_automaticDictionary, 'example1')
print('external table created!')

# %%
from collatex import *
collation = Collation()
import csv, re
from general_functions import tag_poslemma
from general_functions import table_automaticDictionary


#tag_poslemma('example1original')  # ex: create_poslemma('example1')
#print("taggedAll and taggedDistinct created in folder Dictionaries/ !")


A = open( "data/example1original/A.txt", encoding='utf-8' ).read()
F = open( "data/example1original/F.txt", encoding='utf-8' ).read()
G = open( "data/example1original/G.txt", encoding='utf-8' ).read()
H = open( "data/example1original/H.txt", encoding='utf-8' ).read()
M = open( "data/example1original/M.txt", encoding='utf-8' ).read()
P = open( "data/example1original/P.txt", encoding='utf-8' ).read()
R = open( "data/example1original/R.txt", encoding='utf-8' ).read()
S = open( "data/example1original/S.txt", encoding='utf-8' ).read()
V = open( "data/example1original/V.txt", encoding='utf-8' ).read()


#create the dictionary consisting of two columns, separated by a comma.
# The first Column 'Original' are the strings as found in the text, 
# the second column 'Normalised' contains the strings you want to replace them with. 
# No whitespaces behind the strings.
Normit = {}
with open('dictionaries/taggedDistinct_example1original.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'])
    for row in reader:
        Normit[row['Original']]= row['Normalised']

#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()

# build a function to tokenize and to normalize by replace keys to be 
# found in the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

tokens_A = tokennormalizer(A) 
tokens_F = tokennormalizer(F) 
tokens_G = tokennormalizer(G) 
tokens_H = tokennormalizer(H) 
tokens_M = tokennormalizer(M) 
tokens_P = tokennormalizer(P) 
tokens_R = tokennormalizer(R) 
tokens_S = tokennormalizer(S) 
tokens_V = tokennormalizer(V) 

witness_A = { "id": "W1", "tokens":tokens_A }
witness_F = { "id": "W2", "tokens":tokens_F }
witness_G = { "id": "W3", "tokens":tokens_G }
witness_H = { "id": "W4", "tokens":tokens_H }
witness_M = { "id": "W5", "tokens":tokens_M }
witness_P = { "id": "W6", "tokens":tokens_P }
witness_R = { "id": "W7", "tokens":tokens_R }
witness_S = { "id": "W8", "tokens":tokens_S }
witness_V = { "id": "W9", "tokens":tokens_V }


input = { "witnesses": [ witness_A, witness_F, witness_G, witness_H, witness_M, witness_P, witness_R, witness_S, witness_V ] }



table = collate(input, output='html2', segmentation=False)
graphSvg = collate(input, output='svg', segmentation=False)

graph_automaticDictionary = collate(input, output='json', segmentation=False)
table_automaticDictionary(graph_automaticDictionary, 'example1')
print('external table created!')
# Out:
# <TABLE border="1" style="border: 1px solid #000000; border-collapse: collapse;" cellpadding="4">
#  <TR>
#   <TH>W1</TH>
#   <TH>W2</TH>
#   <TH>W3</TH>
#   <TH>W4</TH>
#   <TH>W5</TH>
#   <TH>W6</TH>
#   <TH>W7</TH>
#   <TH>W8</TH>
#   <TH>W9</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">lui</TD>
#   <TD bgcolor="#ece31d">li</TD>
#   <TD bgcolor="#ece31d">soi</TD>
#   <TD bgcolor="#ece31d">lui</TD>
#   <TD bgcolor="#ece31d">lui</TD>
#   <TD bgcolor="#ece31d">lui</TD>
#   <TD bgcolor="#ece31d">soi</TD>
#   <TD bgcolor="#ece31d">lui</TD>
#   <TD bgcolor="#ece31d">lui</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">meisme</TD>
#   <TD bgcolor="#ece31d">meisme</TD>
#   <TD bgcolor="#ece31d">meismes</TD>
#   <TD bgcolor="#ece31d">meismes</TD>
#   <TD bgcolor="#ece31d">meismes</TD>
#   <TD bgcolor="#ece31d">meismes</TD>
#   <TD bgcolor="#ece31d">meisme</TD>
#   <TD bgcolor="#ece31d">meisme</TD>
#   <TD bgcolor="#ece31d">meismes</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">consele</TD>
#   <TD bgcolor="#ece31d">conselle</TD>
#   <TD bgcolor="#ece31d">conseille</TD>
#   <TD bgcolor="#ece31d">consoille</TD>
#   <TD bgcolor="#ece31d">conseille</TD>
#   <TD bgcolor="#ece31d">conseille</TD>
#   <TD bgcolor="#ece31d">conselle</TD>
#   <TD bgcolor="#ece31d">conseille</TD>
#   <TD bgcolor="#ece31d">conselle</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">As</TD>
#   <TD bgcolor="#ece31d">Alquel</TD>
#   <TD bgcolor="#ece31d">Auquel</TD>
#   <TD bgcolor="#ece31d">Auquel</TD>
#   <TD bgcolor="#ece31d">Auquel</TD>
#   <TD bgcolor="#ece31d">Auquel</TD>
#   <TD bgcolor="#ece31d">Alquel</TD>
#   <TD bgcolor="#ece31d">Auquel</TD>
#   <TD bgcolor="#ece31d">Auquel</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">ques</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">d</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">de</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">des</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">dex</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">aus</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">deuz</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">.</TD>
#   <TD bgcolor="#ece31d">.</TD>
#   <TD bgcolor="#ece31d">.</TD>
#   <TD bgcolor="#ece31d">.</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">.</TD>
#   <TD bgcolor="#ece31d">.</TD>
#   <TD bgcolor="#ece31d">.</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">.</TD>
#   <TD bgcolor="#ece31d">.</TD>
#   <TD bgcolor="#ece31d">.</TD>
#   <TD bgcolor="#ece31d">.</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">.</TD>
#   <TD bgcolor="#ece31d">.</TD>
#   <TD bgcolor="#ece31d">.</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">il</TD>
#   <TD bgcolor="#ece31d">il</TD>
#   <TD bgcolor="#ece31d">il</TD>
#   <TD bgcolor="#ece31d">il</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">il</TD>
#   <TD bgcolor="#ece31d">il</TD>
#   <TD bgcolor="#ece31d">il</TD>
#   <TD bgcolor="#ece31d">il</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">Et</TD>
#   <TD bgcolor="#ece31d">Lors</TD>
#   <TD bgcolor="#ece31d">Lors</TD>
#   <TD bgcolor="#ece31d">De</TD>
#   <TD bgcolor="#ece31d">Lor</TD>
#   <TD bgcolor="#ece31d">Lors</TD>
#   <TD bgcolor="#ece31d">Il</TD>
#   <TD bgcolor="#ece31d">Et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">Dist</TD>
#   <TD bgcolor="#ece31d">dist</TD>
#   <TD bgcolor="#ece31d">dit</TD>
#   <TD bgcolor="#ece31d">dit</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">dist</TD>
#   <TD bgcolor="#ece31d">dist</TD>
#   <TD bgcolor="#ece31d">dist</TD>
#   <TD bgcolor="#ece31d">dit</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">que</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">qu</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">c</TD>
#   <TD bgcolor="#ece31d">c</TD>
#   <TD bgcolor="#ece31d">c</TD>
#   <TD bgcolor="#ece31d">q</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">le</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">la</TD>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">part</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">al</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">au</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">lion</TD>
#   <TD bgcolor="#d3d3d3">lion</TD>
#   <TD bgcolor="#d3d3d3">lyon</TD>
#   <TD bgcolor="#d3d3d3">lyon</TD>
#   <TD bgcolor="#d3d3d3">lyon</TD>
#   <TD bgcolor="#d3d3d3">lyon</TD>
#   <TD bgcolor="#d3d3d3">lion</TD>
#   <TD bgcolor="#d3d3d3">lion</TD>
#   <TD bgcolor="#d3d3d3">leon</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">secoura</TD>
#   <TD bgcolor="#ece31d">se</TD>
#   <TD bgcolor="#ece31d">le</TD>
#   <TD bgcolor="#ece31d">se</TD>
#   <TD bgcolor="#ece31d">sera</TD>
#   <TD bgcolor="#ece31d">aidera</TD>
#   <TD bgcolor="#ece31d">secolra</TD>
#   <TD bgcolor="#ece31d">secourra</TD>
#   <TD bgcolor="#ece31d">secorra</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">tendra</TD>
#   <TD bgcolor="#ece31d">fera</TD>
#   <TD bgcolor="#ece31d">tanra</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">Car</TD>
#   <TD bgcolor="#ece31d">Q</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">Qu</TD>
#   <TD bgcolor="#ece31d">Qu</TD>
#   <TD bgcolor="#ece31d">C</TD>
#   <TD bgcolor="#ece31d">Qu</TD>
#   <TD bgcolor="#ece31d">Qu</TD>
#   <TD bgcolor="#ece31d">Qu</TD>
#   <TD bgcolor="#ece31d">C</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">'</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">'</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">as</TD>
#   <TD bgcolor="#ece31d"
# A
# PRE
# astop
# A
# PRE
# astop
# A
# PRE
# astop
# A
# PRE
# astop
# A
# PRE
# astop
# A
# PRE
# astop
# A
# PRE
# astop
# A
# PRE
# astop
# A
# PRE
# astop
# lui
# PROper
# il|loistop
# li
# PROper
# lestop
# soi
# PROper
# soistop
# lui
# PROper
# il|loistop
# lui
# PROper
# il|loistop
# lui
# PROper
# il|loistop
# soi
# PROper
# soistop
# lui
# PROper
# il|loistop
# lui
# PROper
# il|loistop
# meisme
# ADJind
# meisme|möismestop
# meisme
# ADJind
# meisme|möismestop
# meismes
# ADJind
# möismesstop
# meismes
# ADJind
# möismesstop
# meismes
# ADJind
# möismesstop
# meismes
# ADJind
# möismesstop
# meisme
# ADJind
# meisme|möismestop
# meisme
# ADJind
# meisme|möismestop
# meismes
# ADJind
# möismesstop
# se
# CONsub
# sestop
# se
# CONsub
# sestop
# se
# CONsub
# sestop
# se
# CONsub
# sestop
# se
# CONsub
# sestop
# se
# CONsub
# sestop
# se
# CONsub
# sestop
# se
# CONsub
# sestop
# se
# CONsub
# sestop
# consele
# NOMcom
# consulestop
# conselle
# VERcjg
# conseillier|consellierstop
# conseille
# VERcjg
# conseilier|conseiller|conseillierstop
# consoille
# VERcjg
# conseillierstop
# conseille
# VERcjg
# conseilier|conseiller|conseillierstop
# conseille
# VERcjg
# conseilier|conseiller|conseillierstop
# conselle
# VERcjg
# conseillier|consellierstop
# conseille
# VERcjg
# conseilier|conseiller|conseillierstop
# conselle
# VERcjg
# conseillier|consellierstop
# As
# VERcjg
# avoirstop
# Alquel
# NOMpro
# Alquelstop
# Auquel
# PRE.PROrel
# Auquelstop
# Auquel
# PRE.PROrel
# Auquelstop
# Auquel
# PRE.PROrel
# Auquelstop
# Auquel
# PRE.PROrel
# Auquelstop
# Alquel
# NOMpro
# Alquelstop
# Auquel
# PRE.PROrel
# Auquelstop
# Auquel
# PRE.PROrel
# Auquelstop
# ques
# PROrel.PROper
# quelstop
#  -
#
# stop
#  -
#
# stop
# d
# d
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-1bdf60eaf3e4> in <module>()
#      75
#      76 graph_automaticDictionary = collate(input, output='json', segmentation=False)
# ---> 77 table_automaticDictionary(graph_automaticDictionary, 'example1')
#      78 print('external table created!')
#
# ~/Github/elespdn/collation_spelling/workshopCondorcet/general_functions.py in table_automaticDictionary(graph, dirName)
#     134                 listTdPos.append(tdPos)    ## and put their pos in a list (listTdPos)
#     135
# --> 136                 tdLemma = td.get('ana').split('_')[1]
#     137                 print(tdLemma+"stop")
#     138                 listTdLemma.append(tdLemma)   ## and put their lemmas in a list (listTdLemma)
#
# IndexError: list index out of range
