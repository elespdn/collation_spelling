# %% [markdown]
# # Example 3

# %% [markdown]
# ## Create the dictionary
#
# #### Create taggedDistinct from xml tagged with Pandora (only taking the element 'w') [sources provided by JBC]

# %%
from xml.etree import ElementTree as ET
import csv
import os

with open('dictionaries/taggedAll_example3.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    
    # for all the xml files in the dir
    path = 'data/example3'
    for filename in os.listdir(path):
        if not filename.endswith('.xml'): continue
        fullname = os.path.join(path, filename)
        
        # open them
        xmldata = open(fullname, encoding='utf-8' ).read()
        
        #parse them
        root = ET.fromstring(xmldata)
        body = root[1][0]
        for l in body:
            
            # for all child of l, if they are w
            for w in l:
                #if (w.tag == '{http://www.tei-c.org/ns/1.0}w'):
                    
                wtext = w.text
                wtype = w.get('type')
                wlemma = w.get('lemma')
                wtypelemma = wtype + '_' + wlemma

                writer.writerow([wtext,wtypelemma])
f.close


# from taggedAll to taggedDistinct                  
reader=csv.reader(open('dictionaries/taggedAll_example3.csv', 'r'), delimiter=',')
with open('dictionaries/taggedDistinct_example3.csv', 'w', newline='') as o:
    writer = csv.writer(o)
    entries = set()
    writer.writerow(['Original', 'Normalised'])
    for row in reader:
        key = (row[0], row[1]) 
        if key not in entries:
            writer.writerow(row)
            entries.add(key)
o.close

print("taggedDistinct created!")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-a81456355c82> in <module>()
#      27                 wtype = w.get('type')
#      28                 wlemma = w.get('lemma')
# ---> 29                 wtypelemma = wtype + '_' + wlemma
#      30
#      31                 writer.writerow([wtext,wtypelemma])
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %% [markdown]
# ## Sources for collation in txt
# #### Extract text from XML and create corresponding TXT file

# %%
import csv
import os

path = 'data/example3'
for filename in os.listdir(path):
    if not filename.endswith('.xml'): continue
    xmlfile = os.path.join(path, filename)
    
    txtfile = xmlfile.split(".")[0]+".txt"
    
    xmldata = open(xmlfile, encoding='utf-8' ).read()
    
    root = ET.fromstring(xmldata)
    body = root[1][0]
    listw = []
    
    for l in body:
        # for each child of l, if it is w
        for w in l:
            if (w.tag == '{http://www.tei-c.org/ns/1.0}w'):
                wtext = w.text
                listw.append(wtext)
    text = " ".join(listw)
                
    with open (txtfile, 'w') as o:
        o.write(text)

# %% [markdown]
# ## Collation, using the dictionary

# %%
from collatex import *
collation = Collation()
import csv, re
from general_functions import tag_poslemma
from general_functions import table_automaticDictionary


A = open( "data/example3/A.txt", encoding='utf-8' ).read()
F = open( "data/example3/F.txt", encoding='utf-8' ).read()
G = open( "data/example3/G.txt", encoding='utf-8' ).read()
H = open( "data/example3/H.txt", encoding='utf-8' ).read()
M = open( "data/example3/M.txt", encoding='utf-8' ).read()
P = open( "data/example3/P.txt", encoding='utf-8' ).read()
R = open( "data/example3/R.txt", encoding='utf-8' ).read()
S = open( "data/example3/S.txt", encoding='utf-8' ).read()
V = open( "data/example3/V.txt", encoding='utf-8' ).read()

#create the dictionary consisting of two columns, separated by a comma.
# The first Column 'Original' are the strings as found in the text, 
# the second column 'Normalised' contains the strings you want to replace them with. 
# No whitespaces behind the strings.
Normit = {}
with open('dictionaries/taggedDistinct_example3.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'])
    for row in reader:
        Normit[row['Original']]= row['Normalised']

#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()

# build a function to tokenize and to normalize by replace keys to be 
# found in the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

#collate
tokens_A = tokennormalizer(A) 
tokens_F = tokennormalizer(F) 
tokens_G = tokennormalizer(G) 
tokens_H = tokennormalizer(H) 
tokens_M = tokennormalizer(M) 
tokens_P = tokennormalizer(P) 
tokens_R = tokennormalizer(R) 
tokens_S = tokennormalizer(S) 
tokens_V = tokennormalizer(V) 

witness_A = { "id": "W1", "tokens":tokens_A }
witness_F = { "id": "W2", "tokens":tokens_F }
witness_G = { "id": "W3", "tokens":tokens_G }
witness_H = { "id": "W4", "tokens":tokens_H }
witness_M = { "id": "W5", "tokens":tokens_M }
witness_P = { "id": "W6", "tokens":tokens_P }
witness_R = { "id": "W7", "tokens":tokens_R }
witness_S = { "id": "W8", "tokens":tokens_S }
witness_V = { "id": "W9", "tokens":tokens_V }


input = { "witnesses": [ witness_A, witness_F, witness_G, witness_H, witness_M, witness_P, witness_R, witness_S, witness_V ] }


table = collate(input, output='html2', segmentation=False)
graphSvg = collate(input, output='svg', segmentation=False)

graph_automaticDictionary = collate(input, output='json', segmentation=False)
table_automaticDictionary(graph_automaticDictionary, 'example3')
print('external table created!')
# Out:
# <TABLE border="1" style="border: 1px solid #000000; border-collapse: collapse;" cellpadding="4">
#  <TR>
#   <TH>W1</TH>
#   <TH>W2</TH>
#   <TH>W3</TH>
#   <TH>W4</TH>
#   <TH>W5</TH>
#   <TH>W6</TH>
#   <TH>W7</TH>
#   <TH>W8</TH>
#   <TH>W9</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">lui</TD>
#   <TD bgcolor="#ece31d">li</TD>
#   <TD bgcolor="#ece31d">soi</TD>
#   <TD bgcolor="#ece31d">lui</TD>
#   <TD bgcolor="#ece31d">lui</TD>
#   <TD bgcolor="#ece31d">lui</TD>
#   <TD bgcolor="#ece31d">soi</TD>
#   <TD bgcolor="#ece31d">lui</TD>
#   <TD bgcolor="#ece31d">lui</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">meisme</TD>
#   <TD bgcolor="#d3d3d3">meisme</TD>
#   <TD bgcolor="#d3d3d3">meismes</TD>
#   <TD bgcolor="#d3d3d3">meismes</TD>
#   <TD bgcolor="#d3d3d3">meismes</TD>
#   <TD bgcolor="#d3d3d3">meismes</TD>
#   <TD bgcolor="#d3d3d3">meisme</TD>
#   <TD bgcolor="#d3d3d3">meisme</TD>
#   <TD bgcolor="#d3d3d3">meismes</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">consele</TD>
#   <TD bgcolor="#d3d3d3">conselle</TD>
#   <TD bgcolor="#d3d3d3">conseille</TD>
#   <TD bgcolor="#d3d3d3">consoille</TD>
#   <TD bgcolor="#d3d3d3">conseille</TD>
#   <TD bgcolor="#d3d3d3">conseille</TD>
#   <TD bgcolor="#d3d3d3">conselle</TD>
#   <TD bgcolor="#d3d3d3">conseille</TD>
#   <TD bgcolor="#d3d3d3">conselle</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">As</TD>
#   <TD bgcolor="#ece31d">Alquel</TD>
#   <TD bgcolor="#ece31d">Auquel</TD>
#   <TD bgcolor="#ece31d">Auquel</TD>
#   <TD bgcolor="#ece31d">Auquel</TD>
#   <TD bgcolor="#ece31d">Auquel</TD>
#   <TD bgcolor="#ece31d">Alquel</TD>
#   <TD bgcolor="#ece31d">Auquel</TD>
#   <TD bgcolor="#ece31d">Auquel</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">ques</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">d</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">de</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">aus</TD>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">des</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">dex</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">deuz</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">il</TD>
#   <TD bgcolor="#ece31d">il</TD>
#   <TD bgcolor="#ece31d">il</TD>
#   <TD bgcolor="#ece31d">il</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">il</TD>
#   <TD bgcolor="#ece31d">il</TD>
#   <TD bgcolor="#ece31d">il</TD>
#   <TD bgcolor="#ece31d">il</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">Et</TD>
#   <TD bgcolor="#ece31d">Lors</TD>
#   <TD bgcolor="#ece31d">Lors</TD>
#   <TD bgcolor="#ece31d">De</TD>
#   <TD bgcolor="#ece31d">Lor</TD>
#   <TD bgcolor="#ece31d">Lors</TD>
#   <TD bgcolor="#ece31d">Il</TD>
#   <TD bgcolor="#ece31d">Et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">Dist</TD>
#   <TD bgcolor="#ece31d">dist</TD>
#   <TD bgcolor="#ece31d">dit</TD>
#   <TD bgcolor="#ece31d">dit</TD>
#   <TD bgcolor="#ece31d">la</TD>
#   <TD bgcolor="#ece31d">dist</TD>
#   <TD bgcolor="#ece31d">dist</TD>
#   <TD bgcolor="#ece31d">dist</TD>
#   <TD bgcolor="#ece31d">dit</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">que</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">qu</TD>
#   <TD bgcolor="#ece31d">part</TD>
#   <TD bgcolor="#ece31d">c</TD>
#   <TD bgcolor="#ece31d">c</TD>
#   <TD bgcolor="#ece31d">c</TD>
#   <TD bgcolor="#ece31d">q</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">al</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">au</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">lyon</TD>
#   <TD bgcolor="#ece31d">lyon</TD>
#   <TD bgcolor="#ece31d">lyon</TD>
#   <TD bgcolor="#ece31d">lyon</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">leon</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">le</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">le</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">sera</TD>
#   <TD bgcolor="#ece31d">aidera</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">lion</TD>
#   <TD bgcolor="#ece31d">lion</TD>
#   <TD bgcolor="#ece31d">fera</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">lion</TD>
#   <TD bgcolor="#ece31d">lion</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">secoura</TD>
#   <TD bgcolor="#ece31d">se</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">se</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">secolra</TD>
#   <TD bgcolor="#ece31d">secourra</TD>
#   <TD bgcolor="#ece31d">secorra</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">tendra</TD>
#   <TD bgcolor="#ece31d">C</TD>
#   <TD bgcolor="#ece31d">tanra</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">C</TD>
#   <TD bgcolor="#ece31d">Car</TD>
#   <TD bgcolor="#ece31d">Q</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">Qu</TD>
#   <TD bgcolor="#ece31d">Qu</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">Qu</TD>
#   <TD bgcolor="#ece31d">Qu</TD>
#   <TD bgcolor="#ece31d">Qu</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">as</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">venimeus</TD>
#   <TD bgcolor="#ece31d">venimeus</TD>
#   <TD bgcolor="#ece31d">venimeus</TD>
#   <TD bgcolor="#ece31d">venimeus</TD>
#   <TD bgcolor="#ece31d">nul</TD>
#   <TD bgcolor="#ece31d">enuious</TD>
#   <TD bgcolor="#ece31d">venimex</TD>
#   <TD bgcolor="#ece31d">vrinmeus</TD>
#   <TD bgcolor="#ece31d">venimeus</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">et</TD>
#   <TD bgcolor="#ece31d">et</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">mauves</TD>
#   <TD bgcolor="#ece31d">et</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">ne</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">ne</TD>
#   <TD bgcolor="#ece31d">ne</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">ne</TD>
#   <TD bgcolor="#ece31d">n</TD>
#   <TD bgcolor="#ece31d">-</TD
# A
# PRE|MORPH=empty
# a3stop
# A
# PRE|MORPH=empty
# a3stop
# A
# PRE|MORPH=empty
# a3stop
# A
# PRE|MORPH=empty
# a3stop
# A
# PRE|MORPH=empty
# a3stop
# A
# PRE|MORPH=empty
# a3stop
# A
# PRE|MORPH=empty
# a3stop
# A
# PRE|MORPH=empty
# a3stop
# A
# PRE|MORPH=empty
# a3stop
# lui
# PROper|PERS.=3|NOMB.=s|GENRE=m|CAS=i
# ilstop
# li
# DETdef|PERS.=3|NOMB.=s|GENRE=m|CAS=i
# lestop
# soi
# PROper|PERS.=3|NOMB.=s|GENRE=m|CAS=i
# soi1stop
# lui
# PROper|PERS.=3|NOMB.=s|GENRE=m|CAS=i
# ilstop
# lui
# PROper|PERS.=3|NOMB.=s|GENRE=m|CAS=i
# ilstop
# lui
# PROper|PERS.=3|NOMB.=s|GENRE=m|CAS=i
# ilstop
# soi
# PROper|PERS.=3|NOMB.=s|GENRE=m|CAS=i
# soi1stop
# lui
# PROper|PERS.=3|NOMB.=s|GENRE=m|CAS=i
# ilstop
# lui
# PROper|PERS.=3|NOMB.=s|GENRE=m|CAS=i
# ilstop
# meisme
# ADJind|NOMB.=s|GENRE=m|CAS=r
# mëismestop
# meisme
# ADJind|NOMB.=s|GENRE=m|CAS=r
# mëismestop
# meismes
# ADJind|NOMB.=s|GENRE=m|CAS=r
# mëismestop
# meismes
# ADJind|NOMB.=s|GENRE=m|CAS=r
# mëismestop
# meismes
# ADJind|NOMB.=s|GENRE=m|CAS=r
# mëismestop
# meismes
# ADJind|NOMB.=s|GENRE=m|CAS=r
# mëismestop
# meisme
# ADJind|NOMB.=s|GENRE=m|CAS=r
# mëismestop
# meisme
# ADJind|NOMB.=s|GENRE=m|CAS=r
# mëismestop
# meismes
# ADJind|NOMB.=s|GENRE=m|CAS=r
# mëismestop
# se
# PROper|NOMB.=s|GENRE=m|CAS=r
# sestop
# se
# PROper|NOMB.=s|GENRE=m|CAS=r
# sestop
# se
# PROper|NOMB.=s|GENRE=m|CAS=r
# sestop
# se
# PROper|NOMB.=s|GENRE=m|CAS=r
# sestop
# se
# PROper|NOMB.=s|GENRE=m|CAS=r
# sestop
# se
# PROper|NOMB.=s|GENRE=m|CAS=r
# sestop
# se
# PROper|NOMB.=s|GENRE=m|CAS=r
# sestop
# se
# PROper|NOMB.=s|GENRE=m|CAS=r
# sestop
# se
# PROper|NOMB.=s|GENRE=m|CAS=r
# sestop
# consele
# VERcjg|MODE=ind|TEMPS=pst|PERS.=3|NOMB.=s
# conseillier1stop
# conselle
# VERcjg|MODE=ind|TEMPS=pst|PERS.=3|NOMB.=s
# conseillier1stop
# conseille
# VERcjg|MODE=ind|TEMPS=pst|PERS.=3|NOMB.=s
# conseillier1stop
# consoille
# VERcjg|MODE=ind|TEMPS=pst|PERS.=3|NOMB.=s
# conseillier1stop
# conseille
# VERcjg|MODE=ind|TEMPS=pst|PERS.=3|NOMB.=s
# conseillier1stop
# conseille
# VERcjg|MODE=ind|TEMPS=pst|PERS.=3|NOMB.=s
# conseillier1stop
# conselle
# VERcjg|MODE=ind|TEMPS=pst|PERS.=3|NOMB.=s
# conseillier1stop
# conseille
# VERcjg|MODE=ind|TEMPS=pst|PERS.=3|NOMB.=s
# conseillier1stop
# conselle
# VERcjg|MODE=ind|TEMPS=pst|PERS.=3|NOMB.=s
# conseillier1stop
# As
# PRE.DETdef|NOMB.=p|GENRE=m|CAS=r
# a3+lestop
# Alquel
# PROind|NOMB.=s|GENRE=m|CAS=r
# auquesstop
# Auquel
# ADVgen|NOMB.=s|GENRE=m|CAS=r
# auquesstop
# Auquel
# ADVgen|NOMB.=s|GENRE=m|CAS=r
# auquesstop
# Auquel
# ADVgen|NOMB.=s|GENRE=m|CAS=r
# auquesstop
# Auquel
# ADVgen|NOMB.=s|GENRE=m|CAS=r
# auquesstop
# Alquel
# PROind|NOMB.=s|GENRE=m|CAS=r
# auquesstop
# Auquel
# ADVgen|NOMB.=s|GENRE=m|CAS=r
# auquesstop
# Auquel
# ADVgen|NOMB.=s|GENRE=m|CAS=r
# auquesstop
# ques
# PROrel|NOMB.=p|GENRE=m|CAS=r
# quel1stop
#  -
#
# stop
#  -
#
# stop
# d
# PRE|MORPH=empty
# destop
#  -
#
# stop
#  -
#
# stop
#  -
#
# stop
# de
# PRE|MORPH=empty
# destop
#  -
#
# stop
# des
# PRE.DETdef|NOMB.=p|GENRE=m|CAS=r
# de+lestop
# des
# PRE.DETdef|NOMB.=p|GENRE=m|CAS=r
# de+lestop
# des
# PRE.DETdef|NOMB.=p|GENRE=m|CAS=r
# de+lestop
# aus
# PRE.PROper|NOMB.=p|GENRE=m|CAS=r
# a3+lestop
# des
# PRE.DETdef|NOMB.=p|GENRE=m|CAS=r
# de+lestop
# des
# PRE.DETdef|NOMB.=p|GENRE=m|CAS=r
# de+lestop
# des
# PRE.DETdef|NOMB.=p|GENRE=m|CAS=r
# de+lestop
#  -
#
# stop
# des
# PRE.DETdef|NOMB.=p|GENRE=m|CAS=r
# de+lestop
# dex
# PROcar|NOMB.=p|GENRE=m|CAS=r
# deusstop
# ii
# PROcar|NOMB.=p|GENRE=m|CAS=r
# dosstop
# ii
# PROcar|NOMB.=p|GENRE=m|CAS=r
# dosstop
# ii
# PROcar|NOMB.=p|GENRE=m|CAS=r
# dosstop
# ii
# PROcar|NOMB.=p|GENRE=m|CAS=r
# dosstop
# deuz
# PROcar|NOMB.=p|GENRE=m|CAS=r
# dosstop
# ii
# PROcar|NOMB.=p|GENRE=m|CAS=r
# dosstop
# ii
# PROcar|NOMB.=p|GENRE=m|CAS=r
# dosstop
# ii
# PROcar|NOMB.=p|GENRE=m|CAS=r
# dosstop
# il
# PROper|PERS.=3|NOMB.=s|GENRE=m|CAS=n
# ilstop
# il
# PROper|PERS.=3|NOMB.=s|GENRE=m|CAS=n
# ilstop
# il
# PROper|PERS.=3|NOMB.=s|GENRE=m|CAS=n
# ilstop
# il
# PROper|PERS.=3|NOMB.=s|GENRE=m|CAS=n
# ilstop
#  -
#
# stop
# il
# PROper|PERS.=3|NOMB.=s|GENRE=m|CAS=n
# ilstop
# il
# PROper|PERS.=3|NOMB.=s|GENRE=m|CAS=n
# ilstop
# il
# PROper|PERS.=3|NOMB.=s|GENRE=m|CAS=n
# ilstop
# il
# PROper|PERS.=3|NOMB.=s|GENRE=m|CAS=n
# ilstop
# aidera
# VERcjg|NOMB.=s|GENRE=f|CAS=r
# aidierstop
# aidera
# VERcjg|NOMB.=s|GENRE=f|CAS=r
# aidierstop
# aidera
# VERcjg|NOMB.=s|GENRE=f|CAS=r
# aidierstop
# aidera
# VERcjg|NOMB.=s|GENRE=f|CAS=r
# aidierstop
# aidera
# VERcjg|NOMB.=s|GENRE=f|CAS=r
# aidierstop
# aidera
# VERcjg|NOMB.=s|GENRE=f|CAS=r
# aidierstop
# aidera
# VERcjg|NOMB.=s|GENRE=f|CAS=r
# aidierstop
# aidera
# VERcjg|NOMB.=s|GENRE=f|CAS=r
# aidierstop
# aidera
# VERcjg|NOMB.=s|GENRE=f|CAS=r
# aidierstop
#  -
#
# stop
# Et
# CONcoo|MORPH=empty
# etstop
# Lors
# ADVgen|DEGRE=-
# lorsstop
# Lors
# ADVgen|DEGRE=-
# lorsstop
# De
# PRE|MORPH=empty
# destop
# Lor
# ADVgen|DEGRE=-
# ilstop
# Lors
# ADVgen|DEGRE=-
# lorsstop
# Il
# PROper|NOMB.=s|GENRE=m|CAS=n
# ilstop
# Et
# CONcoo|MORPH=empty
# etstop
# Dist
# VERcjg|MODE=ind|TEMPS=pst|PERS.=3|NOMB.=s
# direstop
# dist
# VERcjg|MODE=ind|TEMPS=pst|PERS.=3|NOMB.=s
# direstop
# dit
# VERcjg|MODE=ind|TEMPS=pst|PERS.=3|NOMB.=s
# direstop
# dit
# VERcjg|MODE=ind|TEMPS=pst|PERS.=3|NOMB.=s
# direstop
# la
# DETdef|NOMB.=s|GENRE=f|CAS=r
# lestop
# dist
# VERcjg|MODE=ind|TEMPS=pst|PERS.=3|NOMB.=s
# direstop
# dist
# VERcjg|MODE=ind|TEMPS=pst|PERS.=3|NOMB.=s
# direstop
# dist
# VERcjg|MODE=ind|TEMPS=pst|PERS.=3|NOMB.=s
# direstop
# dit
# VERcjg|MODE=ind|TEMPS=pst|PERS.=3|NOMB.=s
# direstop
# que
# CONsub|MORPH=empty
# que4stop
#  -
#
# stop
#  -
#
# stop
# qu
# CONsub|MORPH=empty
# que4stop
# part
# NOMcom|NOMB.=s|GENRE=f|CAS=r
# part1stop
# c
# CONsub|MORPH=empty
# que4stop
# c
# CONsub|MORPH=empty
# que4stop
# c
# CONsub|MORPH=empty
# que4stop
# q
# CONsub|MORPH=empty
# que4stop
#  -
#
# stop
# au
# PRE.DETdef|NOMB.=s|GENRE=m|CAS=r
# a3+lestop
# au
# PRE.DETdef|NOMB.=s|GENRE=m|CAS=r
# a3+lestop
# au
# PRE.DETdef|NOMB.=s|GENRE=m|CAS=r
# a3+lestop
# au
# PRE.DETdef|NOMB.=s|GENRE=m|CAS=r
# a3+lestop
# au
# PRE.DETdef|NOMB.=s|GENRE=m|CAS=r
# a3+lestop
# al
# PRE.DETdef|NOMB.=s|GENRE=m|CAS=r
# a3+lestop
# au
# PRE.DETdef|NOMB.=s|GENRE=m|CAS=r
# a3+lestop
# au
# PRE.DETdef|NOMB.=s|GENRE=m|CAS=r
# a3+lestop
#  -
#
# stop
#  -
#
# stop
# lyon
# NOMcom|NOMB.=s|GENRE=m|CAS=r
# lïonstop
# lyon
# NOMcom|NOMB.=s|GENRE=m|CAS=r
# lïonstop
# lyon
# NOMcom|NOMB.=s|GENRE=m|CAS=r
# lïonstop
# lyon
# NOMcom|NOMB.=s|GENRE=m|CAS=r
# lïonstop
#  -
#
# stop
#  -
#
# stop
# leon
# NOMcom|NOMB.=s|GENRE=m|CAS=r
# lïonstop
# le
# DETdef|NOMB.=s|GENRE=m|CAS=r
# lestop
#  -
#
# stop
# le
# DETdef|NOMB.=s|GENRE=m|CAS=r
# lestop
#  -
#
# stop
# sera
# VERcjg|MODE=ind|TEMPS=fut|PERS.=3|NOMB.=s
# estre1stop
# aidera
# VERcjg|NOMB.=s|GENRE=f|CAS=r
# aidierstop
#  -
#
# stop
#  -
#
# stop
#  -
#
# stop
# lion
# NOMpro|NOMB.=s|GENRE=m|CAS=r
# lïonstop
# lion
# NOMpro|NOMB.=s|GENRE=m|CAS=r
# lïonstop
# fera
# VERcjg|MODE=ind|TEMPS=fut|PERS.=3|NOMB.=s
# fairestop
#  -
#
# stop
#  -
#
# stop
#  -
#
# stop
# lion
# NOMpro|NOMB.=s|GENRE=m|CAS=r
# lïonstop
# lion
# NOMpro|NOMB.=s|GENRE=m|CAS=r
# lïonstop
#  -
#
# stop
# secoura
# VERcjg|MODE=ind|TEMPS=fut|PERS.=3|NOMB.=s
# secorre1stop
# se
# PROper|NOMB.=s|GENRE=m|CAS=r
# sestop
#  -
#
# stop
# se
# PROper|NOMB.=s|GENRE=m|CAS=r
# sestop
#  -
#
# stop
#  -
#
# stop
# secolra
# VERcjg|MODE=ind|TEMPS=fut|PERS.=3|NOMB.=s
# secorre1stop
# secourra
# VERcjg|MODE=ind|TEMPS=fut|PERS.=3|NOMB.=s
# secorre1stop
# secorra
# VERcjg|MODE=ind|TEMPS=fut|PERS.=3|NOMB.=s
# secorre1stop
#  -
#
# stop
# tendra
# VERcjg|MODE=ind|TEMPS=fut|PERS.=3|NOMB.=s
# tenir1stop
# C
# CONsub|MORPH=empty
# que4stop
# tanra
# VERcjg|MODE=ind|TEMPS=fut|PERS.=3|NOMB.=s
# tenir1stop
#  -
#
# stop
#  -
#
# stop
# C
# CONsub|MORPH=empty
# que4stop
# Car
# CONcoo|MORPH=empty
# carstop
# Q
# CONsub|MORPH=empty
# que4stop
# Qu
# CONsub|NOMB.=s|GENRE=m|CAS=n
# que4stop
# Qu
# CONsub|NOMB.=s|GENRE=m|CAS=n
# que4stop
#  -
#
# stop
# Qu
# CONsub|NOMB.=s|GENRE=m|CAS=n
# que4stop
# Qu
# CONsub|NOMB.=s|GENRE=m|CAS=n
# que4stop
# Qu
# CONsub|NOMB.=s|GENRE=m|CAS=n
# que4stop
#  -
#
# stop
#  -
#
# stop
#  -
#
# stop
# as
# VERcjg|NOMB.=p|GENRE=m|CAS=r
# a3+lestop
# a
# NOMcom|MORPH=empty
# a3stop
# a
# NOMcom|MORPH=empty
# a3stop
# a
# NOMcom|MORPH=empty
# a3stop
# a
# NOMcom|MORPH=empty
# a3stop
# a
# NOMcom|MORPH=empty
# a3stop
# a
# NOMcom|MORPH=empty
# a3stop
# a
# NOMcom|MORPH=empty
# a3stop
# a
# NOMcom|MORPH=empty
# a3stop
# venimeus
# NOMcom|NOMB.=p|GENRE=m|CAS=r
# venimosstop
# venimeus
# NOMcom|NOMB.=p|GENRE=m|CAS=r
# venimosstop
# venimeus
# NOMcom|NOMB.=p|GENRE=m|CAS=r
# venimosstop
# venimeus
# NOMcom|NOMB.=p|GENRE=m|CAS=r
# venimosstop
# nul
# PROind|NOMB.=s|GENRE=m|CAS=r
# nulstop
# enuious
# VERppe|NOMB.=p|GENRE=m|CAS=r
# enoiosstop
# venimex
# NOMcom|NOMB.=s|GENRE=m|CAS=r
# venimosstop
# vrinmeus
# NOMcom|NOMB.=s|GENRE=m|CAS=r
# venimosstop
# venimeus
# NOMcom|NOMB.=p|GENRE=m|CAS=r
# venimosstop
#  -
#
# stop
# et
# CONcoo|MORPH=empty
# etstop
# et
# CONcoo|MORPH=empty
# etstop
#  -
#
# stop
# mauves
# NOMcom|NOMB.=s|GENRE=m|CAS=r
# mauvaisstop
# et
# CONcoo|MORPH=empty
# etstop
#  -
#
# stop
#  -
#
# stop
# et
# CONcoo|MORPH=empty
# etstop
# ne
# CONcoo|MORPH=empty
# ne2stop
#  -
#
# stop
#  -
#
# stop
# ne
# CONcoo|MORPH=empty
# ne2stop
# ne
# CONcoo|MORPH=empty
# ne2stop
#  -
#
# stop
# ne
# CONcoo|MORPH=empty
# ne2stop
# n
# CONcoo|MORPH=empty
# ne2stop
#  -
#
# stop
# as
# VERcjg|NOMB.=p|GENRE=m|CAS=r
# a3+lestop
# a
# NOMcom|MORPH=empty
# a3stop
# a
# NOMcom|MORPH=empty
# a3stop
# a
# NOMcom|MORPH=empty
# a3stop
# a
# NOMcom|MORPH=empty
# a3stop
# a
# NOMcom|MORPH=empty
# a3stop
# a
# NOMcom|MORPH=empty
# a3stop
# a
# NOMcom|MORPH=empty
# a3stop
# a
# NOMcom|MORPH=empty
# a3stop
# felons
# NOMcom|NOMB.=p|GENRE=m|CAS=r
# felonstop
# felon
# NOMcom|NOMB.=s|GENRE=m|CAS=r
# felonstop
# felon
# NOMcom|NOMB.=s|GENRE=m|CAS=r
# felonstop
# felon
# NOMcom|NOMB.=s|GENRE=m|CAS=r
# felonstop
# felon
# NOMcom|NOMB.=s|GENRE=m|CAS=r
# felonstop
# felon
# NOMcom|NOMB.=s|GENRE=m|CAS=r
# felonstop
# felon
# NOMcom|NOMB.=s|GENRE=m|CAS=r
# felonstop
# felon
# NOMcom|NOMB.=s|GENRE=m|CAS=r
# felonstop
# felon
# NOMcom|NOMB.=s|GENRE=m|CAS=r
# felonstop
# Ne
# ADVneg|MORPH=empty
# ne1stop
# Ne
# ADVneg|MORPH=empty
# ne1stop
# Ne
# ADVneg|MORPH=empty
# ne1stop
# Ne
# ADVneg|MORPH=empty
# ne1stop
# Ne
# ADVneg|MORPH=empty
# ne1stop
# Ne
# ADVneg|MORPH=empty
# ne1stop
# Ne
# ADVneg|MORPH=empty
# ne1stop
# Ne
# ADVneg|MORPH=empty
# ne1stop
# Ne
# ADVneg|MORPH=empty
# ne1stop
# doit
# VERcjg|MODE=ind|TEMPS=pst|PERS.=3|NOMB.=s
# devoirstop
# doit
# VERcjg|MODE=ind|TEMPS=pst|PERS.=3|NOMB.=s
# devoirstop
# doit
# VERcjg|MODE=ind|TEMPS=pst|PERS.=3|NOMB.=s
# devoirstop
# doit
# VERcjg|MODE=ind|TEMPS=pst|PERS.=3|NOMB.=s
# devoirstop
# doit
# VERcjg|MODE=ind|TEMPS=pst|PERS.=3|NOMB.=s
# devoirstop
# doit
# VERcjg|MODE=ind|TEMPS=pst|PERS.=3|NOMB.=s
# devoirstop
# doit
# VERcjg|MODE=ind|TEMPS=pst|PERS.=3|NOMB.=s
# devoirstop
# doit
# VERcjg|MODE=ind|TEMPS=pst|PERS.=3|NOMB.=s
# devoirstop
# doit
# VERcjg|MODE=ind|TEMPS=pst|PERS.=3|NOMB.=s
# devoirstop
#  -
#
# stop
# l
# DETdef|NOMB.=s|GENRE=n|CAS=n
# lestop
# l
# DETdef|NOMB.=s|GENRE=n|CAS=n
# lestop
#  -
#
# stop
#  -
#
# stop
#  -
#
# stop
#  -
#
# stop
#  -
#
# stop
# l
# DETdef|NOMB.=s|GENRE=n|CAS=n
# lestop
# on
# PROind|NOMB.=s|GENRE=n|CAS=n
# onstop
# on
# PROind|NOMB.=s|GENRE=n|CAS=n
# onstop
# en
# PROind|NOMB.=s|GENRE=n|CAS=n
# onstop
# an
# PROind|NOMB.=s|GENRE=n|CAS=n
# onstop
# on
# PROind|NOMB.=s|GENRE=n|CAS=n
# onstop
# on
# PROind|NOMB.=s|GENRE=n|CAS=n
# onstop
# on
# PROind|NOMB.=s|GENRE=n|CAS=n
# onstop
# on
# PROind|NOMB.=s|GENRE=n|CAS=n
# onstop
# en
# PROind|NOMB.=s|GENRE=n|CAS=n
# onstop
# faire
# VERinf|MORPH=empty
# fairestop
# faire
# VERinf|MORPH=empty
# fairestop
# fere
# VERinf|MORPH=empty
# fairestop
# feire
# VERinf|MORPH=empty
# fairestop
# fere
# VERinf|MORPH=empty
# fairestop
# faire
# VERinf|MORPH=empty
# fairestop
# faire
# VERinf|MORPH=empty
# fairestop
# faire
# VERinf|MORPH=empty
# fairestop
# fere
# VERinf|MORPH=empty
# fairestop
# se
# PROper|NOMB.=s|GENRE=m|CAS=r
# sestop
# se
# PROper|NOMB.=s|GENRE=m|CAS=r
# sestop
# se
# PROper|NOMB.=s|GENRE=m|CAS=r
# sestop
# se
# PROper|NOMB.=s|GENRE=m|CAS=r
# sestop
# se
# PROper|NOMB.=s|GENRE=m|CAS=r
# sestop
# se
# PROper|NOMB.=s|GENRE=m|CAS=r
# sestop
# se
# PROper|NOMB.=s|GENRE=m|CAS=r
# sestop
# se
# PROper|NOMB.=s|GENRE=m|CAS=r
# sestop
# se
# PROper|NOMB.=s|GENRE=m|CAS=r
# sestop
# mal
# NOMcom|NOMB.=s|GENRE=m|CAS=r
# mal1stop
# mal
# NOMcom|NOMB.=s|GENRE=m|CAS=r
# mal1stop
# mal
# NOMcom|NOMB.=s|GENRE=m|CAS=r
# mal1stop
# mal
# NOMcom|NOMB.=s|GENRE=m|CAS=r
# mal1stop
# mal
# NOMcom|NOMB.=s|GENRE=m|CAS=r
# mal1stop
# mal
# NOMcom|NOMB.=s|GENRE=m|CAS=r
# mal1stop
# mal
# NOMcom|NOMB.=s|GENRE=m|CAS=r
# mal1stop
# mal
# NOMcom|NOMB.=s|GENRE=m|CAS=r
# mal1stop
# mal
# NOMcom|NOMB.=s|GENRE=m|CAS=r
# mal1stop
# non
# ADVneg|MORPH=empty
# nonstop
# non
# ADVneg|MORPH=empty
# nonstop
# non
# ADVneg|MORPH=empty
# nonstop
# non
# ADVneg|MORPH=empty
# nonstop
# non
# ADVneg|MORPH=empty
# nonstop
# non
# ADVneg|MORPH=empty
# nonstop
# non
# ADVneg|MORPH=empty
# nonstop
# non
# ADVneg|MORPH=empty
# nonstop
# non
# ADVneg|MORPH=empty
# nonstop
# external table created!
