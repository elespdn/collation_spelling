# %% [markdown]
# #### Create taggedDistinct from xml

# %%
from xml.etree import ElementTree as ET
import csv
import os

with open('dictionaries/taggedAll_example2.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    
    # for all the xml files in the dir
    path = 'data/example2'
    for filename in os.listdir(path):
        if not filename.endswith('.xml'): continue
        fullname = os.path.join(path, filename)
        
        # open them
        xmldata = open(fullname, encoding='utf-8' ).read()
        
        #parse them
        root = ET.fromstring(xmldata)
        body = root[1][0]
        for l in body:
            
            # for all chilf of l, if they are w
            for w in l:
                if (w.tag == '{http://www.tei-c.org/ns/1.0}w'):
                    
                    wtext = w.text
                    wtype = w.get('type')
                    wlemma = w.get('lemma')
                    wtypelemma = wtype + '_' + wlemma

                    writer.writerow([wtext,wtypelemma])
f.close


# from taggedAll to taggedDistinct                  
reader=csv.reader(open('dictionaries/taggedAll_example2.csv', 'r'), delimiter=',')
with open('dictionaries/taggedDistinct_example2.csv', 'w', newline='') as o:
    writer = csv.writer(o)
    entries = set()
    writer.writerow(['Original', 'Normalised'])
    for row in reader:
        key = (row[0], row[1]) 
        if key not in entries:
            writer.writerow(row)
            entries.add(key)
o.close

print("taggedDistinct created!")
# Out:
# taggedDistinct created!

# %% [markdown]
# #### Extract text from XML and create corresponding TXT file

# %%
import csv
import os

path = 'data/example2'
for filename in os.listdir(path):
    if not filename.endswith('.xml'): continue
    xmlfile = os.path.join(path, filename)
    
    txtfile = xmlfile.split(".")[0]+".txt"
    
    xmldata = open(xmlfile, encoding='utf-8' ).read()
    
    root = ET.fromstring(xmldata)
    body = root[1][0]
    listw = []
    
    for l in body:
        # for each child of l, if it is w
        for w in l:
            if (w.tag == '{http://www.tei-c.org/ns/1.0}w'):
                wtext = w.text
                listw.append(wtext)
    text = " ".join(listw)
                
    with open (txtfile, 'w') as o:
        o.write(text)

# %% [markdown]
# ### Collation, using automatic dictionary

# %%
from collatex import *
collation = Collation()
import csv, re
from general_functions import tag_poslemma
from general_functions import table_automaticDictionary


tag_poslemma('example2')  # ex: create_poslemma('example2')
print("taggedAll and taggedDistinct created in folder Dictionaries/ !")


A = open( "data/example2/A.txt", encoding='utf-8' ).read()
F = open( "data/example2/F.txt", encoding='utf-8' ).read()
G = open( "data/example2/G.txt", encoding='utf-8' ).read()
H = open( "data/example2/H.txt", encoding='utf-8' ).read()

#create the dictionary consisting of two columns, separated by a comma.
# The first Column 'Original' are the strings as found in the text, 
# the second column 'Normalised' contains the strings you want to replace them with. 
# No whitespaces behind the strings.
Normit = {}
with open('dictionaries/taggedDistinct_example2.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'])
    for row in reader:
        Normit[row['Original']]= row['Normalised']

#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()

# build a function to tokenize and to normalize by replace keys to be 
# found in the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

#collate
tokens_A = tokennormalizer(A) 
tokens_F = tokennormalizer(F) 
tokens_G = tokennormalizer(G) 
tokens_H = tokennormalizer(H) 

witness_A = { "id": "W1", "tokens":tokens_A }
witness_F = { "id": "W2", "tokens":tokens_F }
witness_G = { "id": "W3", "tokens":tokens_G }
witness_H = { "id": "W4", "tokens":tokens_H }


input = { "witnesses": [ witness_A, witness_F, witness_G, witness_H ] }


table = collate(input, output='html2', segmentation=False)
graphSvg = collate(input, output='svg', segmentation=False)

graph_automaticDictionary = collate(input, output='json', segmentation=False)
table_automaticDictionary(graph_automaticDictionary, 'example2')
print('external table created!')
# Out:
# taggedAll and taggedDistinct created in folder Dictionaries/ !
# <TABLE border="1" style="border: 1px solid #000000; border-collapse: collapse;" cellpadding="4">
#  <TR>
#   <TH>W1</TH>
#   <TH>W2</TH>
#   <TH>W3</TH>
#   <TH>W4</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">lui</TD>
#   <TD bgcolor="#ece31d">li</TD>
#   <TD bgcolor="#ece31d">soi</TD>
#   <TD bgcolor="#ece31d">lui</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">meisme</TD>
#   <TD bgcolor="#ece31d">meisme</TD>
#   <TD bgcolor="#ece31d">meismes</TD>
#   <TD bgcolor="#ece31d">meismes</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">consele</TD>
#   <TD bgcolor="#ece31d">conselle</TD>
#   <TD bgcolor="#ece31d">conseille</TD>
#   <TD bgcolor="#ece31d">consoille</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">As</TD>
#   <TD bgcolor="#ece31d">Alquel</TD>
#   <TD bgcolor="#ece31d">Auquel</TD>
#   <TD bgcolor="#ece31d">Auquel</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">ques</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">d</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">aus</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">dex</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#   <TD bgcolor="#d3d3d3">il</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">Et</TD>
#   <TD bgcolor="#ece31d">Lors</TD>
#   <TD bgcolor="#ece31d">Lors</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">Dist</TD>
#   <TD bgcolor="#d3d3d3">dist</TD>
#   <TD bgcolor="#d3d3d3">dit</TD>
#   <TD bgcolor="#d3d3d3">dit</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">que</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">qu</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">le</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">au</TD>
#   <TD bgcolor="#ece31d">au</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">lion</TD>
#   <TD bgcolor="#d3d3d3">lion</TD>
#   <TD bgcolor="#d3d3d3">lyon</TD>
#   <TD bgcolor="#d3d3d3">lyon</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">secoura</TD>
#   <TD bgcolor="#ece31d">se</TD>
#   <TD bgcolor="#ece31d">le</TD>
#   <TD bgcolor="#ece31d">se</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">tendra</TD>
#   <TD bgcolor="#ece31d">fera</TD>
#   <TD bgcolor="#ece31d">tanra</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">Qu</TD>
#   <TD bgcolor="#ece31d">Qu</TD>
#   <TD bgcolor="#ece31d">C</TD>
#   <TD bgcolor="#ece31d">Qu</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">as</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">venimeus</TD>
#   <TD bgcolor="#d3d3d3">venimeus</TD>
#   <TD bgcolor="#d3d3d3">venimeus</TD>
#   <TD bgcolor="#d3d3d3">venimeus</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">ne</TD>
#   <TD bgcolor="#ece31d">et</TD>
#   <TD bgcolor="#ece31d">et</TD>
#   <TD bgcolor="#ece31d">ne</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">as</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#   <TD bgcolor="#ece31d">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">felons</TD>
#   <TD bgcolor="#d3d3d3">felon</TD>
#   <TD bgcolor="#d3d3d3">felon</TD>
#   <TD bgcolor="#d3d3d3">felon</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">Ne</TD>
#   <TD bgcolor="#d3d3d3">Ne</TD>
#   <TD bgcolor="#d3d3d3">Ne</TD>
#   <TD bgcolor="#d3d3d3">Ne</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">doit</TD>
#   <TD bgcolor="#d3d3d3">doit</TD>
#   <TD bgcolor="#d3d3d3">doit</TD>
#   <TD bgcolor="#d3d3d3">doit</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">l</TD>
#   <TD bgcolor="#ece31d">l</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">on</TD>
#   <TD bgcolor="#ece31d">on</TD>
#   <TD bgcolor="#ece31d">en</TD>
#   <TD bgcolor="#ece31d">an</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">faire</TD>
#   <TD bgcolor="#ece31d">faire</TD>
#   <TD bgcolor="#ece31d">fere</TD>
#   <TD bgcolor="#ece31d">feire</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">mal</TD>
#   <TD bgcolor="#d3d3d3">mal</TD>
#   <TD bgcolor="#d3d3d3">mal</TD>
#   <TD bgcolor="#d3d3d3">mal</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">non</TD>
#   <TD bgcolor="#d3d3d3">non</TD>
#   <TD bgcolor="#d3d3d3">non</TD>
#   <TD bgcolor="#d3d3d3">non</TD>
#  </TR>
# </TABLE>
# external table created!

# %%
from collatex import *
collation = Collation()
import csv, re
from general_functions import tag_poslemma
from general_functions import table_automaticDictionary


tag_poslemma('example2')  # ex: create_poslemma('example2')
print("taggedAll and taggedDistinct created in folder Dictionaries/ !")

M = open( "data/example2/M.txt", encoding='utf-8' ).read()
P = open( "data/example2/P.txt", encoding='utf-8' ).read()
R = open( "data/example2/R.txt", encoding='utf-8' ).read()
S = open( "data/example2/S.txt", encoding='utf-8' ).read()


#create the dictionary consisting of two columns, separated by a comma.
# The first Column 'Original' are the strings as found in the text, 
# the second column 'Normalised' contains the strings you want to replace them with. 
# No whitespaces behind the strings.
Normit = {}
with open('dictionaries/taggedDistinct_example2.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'])
    for row in reader:
        Normit[row['Original']]= row['Normalised']

#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()

# build a function to tokenize and to normalize by replace keys to be 
# found in the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

#collate
tokens_M = tokennormalizer(M) 
tokens_P = tokennormalizer(P) 
tokens_R = tokennormalizer(R) 
tokens_S = tokennormalizer(S) 

witness_M = { "id": "W1", "tokens":tokens_M }
witness_P = { "id": "W2", "tokens":tokens_P }
witness_R = { "id": "W3", "tokens":tokens_R }
witness_S = { "id": "W4", "tokens":tokens_S }


input = { "witnesses": [ witness_M, witness_P, witness_R, witness_S ] }



table = collate(input, output='html2', segmentation=False)
graphSvg = collate(input, output='svg', segmentation=False)

graph_automaticDictionary = collate(input, output='json', segmentation=False)
table_automaticDictionary(graph_automaticDictionary, 'example2')
print('external table created!')
# Out:
# taggedAll and taggedDistinct created in folder Dictionaries/ !
# <TABLE border="1" style="border: 1px solid #000000; border-collapse: collapse;" cellpadding="4">
#  <TR>
#   <TH>W1</TH>
#   <TH>W2</TH>
#   <TH>W3</TH>
#   <TH>W4</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#   <TD bgcolor="#d3d3d3">A</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">lui</TD>
#   <TD bgcolor="#ece31d">lui</TD>
#   <TD bgcolor="#ece31d">soi</TD>
#   <TD bgcolor="#ece31d">lui</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">meismes</TD>
#   <TD bgcolor="#ece31d">meismes</TD>
#   <TD bgcolor="#ece31d">meisme</TD>
#   <TD bgcolor="#ece31d">meisme</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">conseille</TD>
#   <TD bgcolor="#ece31d">conseille</TD>
#   <TD bgcolor="#ece31d">conselle</TD>
#   <TD bgcolor="#ece31d">conseille</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">Auquel</TD>
#   <TD bgcolor="#ece31d">Auquel</TD>
#   <TD bgcolor="#ece31d">Alquel</TD>
#   <TD bgcolor="#ece31d">Auquel</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">des</TD>
#   <TD bgcolor="#ece31d">de</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">deuz</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#   <TD bgcolor="#ece31d">ii</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">il</TD>
#   <TD bgcolor="#ece31d">il</TD>
#   <TD bgcolor="#ece31d">il</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#   <TD bgcolor="#d3d3d3">aidera</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">De</TD>
#   <TD bgcolor="#ece31d">Lor</TD>
#   <TD bgcolor="#ece31d">Lors</TD>
#   <TD bgcolor="#ece31d">Il</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">la</TD>
#   <TD bgcolor="#ece31d">dist</TD>
#   <TD bgcolor="#ece31d">dist</TD>
#   <TD bgcolor="#ece31d">dist</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">part</TD>
#   <TD bgcolor="#ece31d">c</TD>
#   <TD bgcolor="#ece31d">c</TD>
#   <TD bgcolor="#ece31d">c</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">au</TD>
#   <TD bgcolor="#d3d3d3">au</TD>
#   <TD bgcolor="#d3d3d3">al</TD>
#   <TD bgcolor="#d3d3d3">au</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">lyon</TD>
#   <TD bgcolor="#d3d3d3">lyon</TD>
#   <TD bgcolor="#d3d3d3">lion</TD>
#   <TD bgcolor="#d3d3d3">lion</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">sera</TD>
#   <TD bgcolor="#ece31d">aidera</TD>
#   <TD bgcolor="#ece31d">secolra</TD>
#   <TD bgcolor="#ece31d">secourra</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">Qu</TD>
#   <TD bgcolor="#ece31d">Qu</TD>
#   <TD bgcolor="#ece31d">C</TD>
#   <TD bgcolor="#ece31d">Car</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">a</TD>
#   <TD bgcolor="#d3d3d3">a</TD>
#   <TD bgcolor="#d3d3d3">a</TD>
#   <TD bgcolor="#d3d3d3">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">nul</TD>
#   <TD bgcolor="#ece31d">enuious</TD>
#   <TD bgcolor="#ece31d">venimex</TD>
#   <TD bgcolor="#ece31d">vrinmeus</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">mauves</TD>
#   <TD bgcolor="#ece31d">et</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">n</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">ne</TD>
#   <TD bgcolor="#ece31d">-</TD>
#   <TD bgcolor="#ece31d">ne</TD>
#   <TD bgcolor="#ece31d">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">a</TD>
#   <TD bgcolor="#d3d3d3">a</TD>
#   <TD bgcolor="#d3d3d3">a</TD>
#   <TD bgcolor="#d3d3d3">a</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">felon</TD>
#   <TD bgcolor="#d3d3d3">felon</TD>
#   <TD bgcolor="#d3d3d3">felon</TD>
#   <TD bgcolor="#d3d3d3">felon</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">Ne</TD>
#   <TD bgcolor="#d3d3d3">Ne</TD>
#   <TD bgcolor="#d3d3d3">Ne</TD>
#   <TD bgcolor="#d3d3d3">Ne</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">doit</TD>
#   <TD bgcolor="#d3d3d3">doit</TD>
#   <TD bgcolor="#d3d3d3">doit</TD>
#   <TD bgcolor="#d3d3d3">doit</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">on</TD>
#   <TD bgcolor="#d3d3d3">on</TD>
#   <TD bgcolor="#d3d3d3">on</TD>
#   <TD bgcolor="#d3d3d3">on</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#ece31d">fere</TD>
#   <TD bgcolor="#ece31d">faire</TD>
#   <TD bgcolor="#ece31d">faire</TD>
#   <TD bgcolor="#ece31d">faire</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#   <TD bgcolor="#d3d3d3">se</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">mal</TD>
#   <TD bgcolor="#d3d3d3">mal</TD>
#   <TD bgcolor="#d3d3d3">mal</TD>
#   <TD bgcolor="#d3d3d3">mal</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="#d3d3d3">non</TD>
#   <TD bgcolor="#d3d3d3">non</TD>
#   <TD bgcolor="#d3d3d3">non</TD>
#   <TD bgcolor="#d3d3d3">non</TD>
#  </TR>
# </TABLE>
# external table created!

# %%
from collatex import *
collation = Collation()
import csv, re
from general_functions import tag_poslemma
from general_functions import table_automaticDictionary


tag_poslemma('example2')  # ex: create_poslemma('example2')
print("taggedAll and taggedDistinct created in folder Dictionaries/ !")


A = open( "data/example2/A.txt", encoding='utf-8' ).read()
F = open( "data/example2/F.txt", encoding='utf-8' ).read()
G = open( "data/example2/G.txt", encoding='utf-8' ).read()
H = open( "data/example2/H.txt", encoding='utf-8' ).read()
M = open( "data/example2/M.txt", encoding='utf-8' ).read()
P = open( "data/example2/P.txt", encoding='utf-8' ).read()
R = open( "data/example2/R.txt", encoding='utf-8' ).read()
S = open( "data/example2/S.txt", encoding='utf-8' ).read()
V = open( "data/example2/V.txt", encoding='utf-8' ).read()


#create the dictionary consisting of two columns, separated by a comma.
# The first Column 'Original' are the strings as found in the text, 
# the second column 'Normalised' contains the strings you want to replace them with. 
# No whitespaces behind the strings.
Normit = {}
with open('dictionaries/taggedDistinct_example2.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'])
    for row in reader:
        Normit[row['Original']]= row['Normalised']

#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()

# build a function to tokenize and to normalize by replace keys to be 
# found in the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

tokens_A = tokennormalizer(A) 
tokens_F = tokennormalizer(F) 
tokens_G = tokennormalizer(G) 
tokens_H = tokennormalizer(H) 
tokens_M = tokennormalizer(M) 
tokens_P = tokennormalizer(P) 
tokens_R = tokennormalizer(R) 
tokens_S = tokennormalizer(S) 
tokens_V = tokennormalizer(V) 

witness_A = { "id": "W1", "tokens":tokens_A }
witness_F = { "id": "W2", "tokens":tokens_F }
witness_G = { "id": "W3", "tokens":tokens_G }
witness_H = { "id": "W4", "tokens":tokens_H }
witness_M = { "id": "W1", "tokens":tokens_M }
witness_P = { "id": "W2", "tokens":tokens_P }
witness_R = { "id": "W3", "tokens":tokens_R }
witness_S = { "id": "W4", "tokens":tokens_S }
witness_V = { "id": "W1", "tokens":tokens_V }


input = { "witnesses": [ witness_A, witness_F, witness_G, witness_H, witness_M, witness_P, witness_R, witness_S, witness_V ] }



table = collate(input, output='html2', segmentation=False)
graphSvg = collate(input, output='svg', segmentation=False)

graph_automaticDictionary = collate(input, output='json', segmentation=False)
table_automaticDictionary(graph_automaticDictionary, 'example2')
print('external table created!')
# Out:
# taggedAll and taggedDistinct created in folder Dictionaries/ !
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-667b5d9f3cf2> in <module>()
#      71
#      72
# ---> 73 table = collate(input, output='html2', segmentation=False)
#      74 graphSvg = collate(input, output='svg', segmentation=False)
#      75
#
# ~/anaconda3/lib/python3.6/site-packages/collatex/core_functions.py in collate(collation, output, layout, segmentation, near_match, astar, detect_transpositions, debug_scores, properties_filter, indent, scheduler)
#      45     # build graph
#      46     graph = VariantGraph()
# ---> 47     algorithm.collate(graph)
#      48     ranking = VariantGraphRanking.of(graph)
#      49     if near_match:
#
# ~/anaconda3/lib/python3.6/site-packages/collatex/edit_graph_aligner.py in collate(self, graph)
#     208         # print("> token_to_vertex=", token_to_vertex)
#     209         self.update_token_position_to_vertex(token_to_vertex)
# --> 210         self.update_token_to_vertex_array(tokens, first_witness, self.token_position_to_vertex)
#     211
#     212         # align witness 2 - n
#
# ~/anaconda3/lib/python3.6/site-packages/collatex/edit_graph_aligner.py in update_token_to_vertex_array(self, tokens, witness, witness_token_position_to_vertex)
#     344         for token_position in self.token_index.get_range_for_witness(witness.sigil):
#     345             # print("> token_position =", token_position)
# --> 346             vertex = witness_token_position_to_vertex[token_position]
#     347             self.vertex_array[token_position] = vertex
#     348
#
# KeyError: 244
