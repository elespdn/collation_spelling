# %% [markdown]
# ## 0. Normal

# %%
from collatex import *
collation = Collation()
W1 = open( "text/conte4mss/W1.txt", encoding='utf-8' ).read()
W2 = open( "text/conte4mss/W2.txt", encoding='utf-8' ).read()
W3 = open( "text/conte4mss/W3.txt", encoding='utf-8' ).read()
W4 = open( "text/conte4mss/W4.txt", encoding='utf-8' ).read()
collation.add_plain_witness( "W1", W1 )
collation.add_plain_witness( "W2", W2 )
collation.add_plain_witness( "W3", W3 )
collation.add_plain_witness( "W4", W4 )
table = collate(collation, output='html2', segmentation=False)
print(table)
# Out:
# <TABLE style="border: 1px solid #000000; border-collapse: collapse;" cellpadding="4" border="1">
#  <TR>
#   <TH>W1</TH>
#   <TH>W2</TH>
#   <TH>W3</TH>
#   <TH>W4</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">Lors</TD>
#   <TD bgcolor="FF0000">Lors</TD>
#   <TD bgcolor="FF0000">Lors</TD>
#   <TD bgcolor="FF0000">Adonc</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">li</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">conte</TD>
#   <TD bgcolor="00FFFF">conte</TD>
#   <TD bgcolor="00FFFF">conte</TD>
#   <TD bgcolor="00FFFF">conte</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">rois</TD>
#   <TD bgcolor="00FFFF">rois</TD>
#   <TD bgcolor="00FFFF">rois</TD>
#   <TD bgcolor="00FFFF">rois</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">meismes</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">a</TD>
#   <TD bgcolor="FF0000">a</TD>
#   <TD bgcolor="FF0000">a</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">la</TD>
#   <TD bgcolor="FF0000">la</TD>
#   <TD bgcolor="FF0000">la</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">reine</TD>
#   <TD bgcolor="FF0000">reine</TD>
#   <TD bgcolor="FF0000">roine</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">coment</TD>
#   <TD bgcolor="FF0000">comment</TD>
#   <TD bgcolor="FF0000">coment</TD>
#   <TD bgcolor="FF0000">comment</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">il</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">avoit</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">este</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">requis</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">de</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">dame</TD>
#   <TD bgcolor="00FFFF">dame</TD>
#   <TD bgcolor="00FFFF">dame</TD>
#   <TD bgcolor="00FFFF">dame</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">del</TD>
#   <TD bgcolor="FF0000">del</TD>
#   <TD bgcolor="FF0000">del</TD>
#   <TD bgcolor="FF0000">du</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">lac</TD>
#   <TD bgcolor="00FFFF">lac</TD>
#   <TD bgcolor="00FFFF">lac</TD>
#   <TD bgcolor="00FFFF">lac</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">li</TD>
#   <TD bgcolor="FF0000">li</TD>
#   <TD bgcolor="FF0000">li</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">avoit</TD>
#   <TD bgcolor="FF0000">avoit</TD>
#   <TD bgcolor="FF0000">pria</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">requis</TD>
#   <TD bgcolor="FF0000">requis</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">qu</TD>
#   <TD bgcolor="00FFFF">qu</TD>
#   <TD bgcolor="00FFFF">qu</TD>
#   <TD bgcolor="00FFFF">qu</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">il</TD>
#   <TD bgcolor="00FFFF">il</TD>
#   <TD bgcolor="00FFFF">il</TD>
#   <TD bgcolor="00FFFF">il</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ne</TD>
#   <TD bgcolor="00FFFF">ne</TD>
#   <TD bgcolor="00FFFF">ne</TD>
#   <TD bgcolor="00FFFF">ne</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">l</TD>
#   <TD bgcolor="FF0000">lo</TD>
#   <TD bgcolor="FF0000">le</TD>
#   <TD bgcolor="FF0000">l</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">feist</TD>
#   <TD bgcolor="00FFFF">feist</TD>
#   <TD bgcolor="00FFFF">feist</TD>
#   <TD bgcolor="00FFFF">feist</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">chevalier</TD>
#   <TD bgcolor="00FFFF">chevalier</TD>
#   <TD bgcolor="00FFFF">chevalier</TD>
#   <TD bgcolor="00FFFF">chevalier</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">se</TD>
#   <TD bgcolor="00FFFF">se</TD>
#   <TD bgcolor="00FFFF">se</TD>
#   <TD bgcolor="00FFFF">se</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">de</TD>
#   <TD bgcolor="FF0000">des</TD>
#   <TD bgcolor="FF0000">des</TD>
#   <TD bgcolor="FF0000">de</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">ses</TD>
#   <TD bgcolor="FF0000">soes</TD>
#   <TD bgcolor="FF0000">ses</TD>
#   <TD bgcolor="FF0000">ses</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">armes</TD>
#   <TD bgcolor="00FFFF">armes</TD>
#   <TD bgcolor="00FFFF">armes</TD>
#   <TD bgcolor="00FFFF">armes</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">non</TD>
#   <TD bgcolor="00FFFF">non</TD>
#   <TD bgcolor="00FFFF">non</TD>
#   <TD bgcolor="00FFFF">non</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">de</TD>
#   <TD bgcolor="00FFFF">de</TD>
#   <TD bgcolor="00FFFF">de</TD>
#   <TD bgcolor="00FFFF">de</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ses</TD>
#   <TD bgcolor="00FFFF">ses</TD>
#   <TD bgcolor="00FFFF">ses</TD>
#   <TD bgcolor="00FFFF">ses</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">robes</TD>
#   <TD bgcolor="00FFFF">robes</TD>
#   <TD bgcolor="00FFFF">robes</TD>
#   <TD bgcolor="00FFFF">robes</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">la</TD>
#   <TD bgcolor="FF0000">que</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">reine</TD>
#   <TD bgcolor="FF0000">ele</TD>
#   <TD bgcolor="FF0000">ele</TD>
#   <TD bgcolor="FF0000">reine</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">se</TD>
#   <TD bgcolor="FF0000">estoit</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">merveille</TD>
#   <TD bgcolor="FF0000">apelee</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">mult</TD>
#   <TD bgcolor="FF0000">la</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">dame</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">del</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">lac</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">et</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">ele</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">s</TD>
#   <TD bgcolor="FF0000">s</TD>
#   <TD bgcolor="FF0000">s</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">an</TD>
#   <TD bgcolor="FF0000">en</TD>
#   <TD bgcolor="FF0000">en</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">mervoille</TD>
#   <TD bgcolor="FF0000">merveille</TD>
#   <TD bgcolor="FF0000">mervelle</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">mout</TD>
#   <TD bgcolor="FF0000">mult</TD>
#   <TD bgcolor="FF0000">mult</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">trop</TD>
#   <TD bgcolor="FF0000">trop</TD>
#   <TD bgcolor="FF0000">mult</TD>
#   <TD bgcolor="FF0000">mult</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">tarde</TD>
#   <TD bgcolor="00FFFF">tarde</TD>
#   <TD bgcolor="00FFFF">tarde</TD>
#   <TD bg
# None

# %% [markdown]
# ## 1. Near match

# %%
from collatex import *
collation = Collation()
W1 = open( "text/conte4mss/W1.txt", encoding='utf-8' ).read()
W2 = open( "text/conte4mss/W2.txt", encoding='utf-8' ).read()
W3 = open( "text/conte4mss/W3.txt", encoding='utf-8' ).read()
W4 = open( "text/conte4mss/W4.txt", encoding='utf-8' ).read()
collation.add_plain_witness( "W1", W1 )
collation.add_plain_witness( "W2", W2 )
collation.add_plain_witness( "W3", W3 )
collation.add_plain_witness( "W4", W4 )
table = collate(collation, output='html2', near_match=True, segmentation=False)
print(table)
# Out:
# <TABLE style="border: 1px solid #000000; border-collapse: collapse;" cellpadding="4" border="1">
#  <TR>
#   <TH>W1</TH>
#   <TH>W2</TH>
#   <TH>W3</TH>
#   <TH>W4</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">Lors</TD>
#   <TD bgcolor="FF0000">Lors</TD>
#   <TD bgcolor="FF0000">Lors</TD>
#   <TD bgcolor="FF0000">Adonc</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">li</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">conte</TD>
#   <TD bgcolor="00FFFF">conte</TD>
#   <TD bgcolor="00FFFF">conte</TD>
#   <TD bgcolor="00FFFF">conte</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">rois</TD>
#   <TD bgcolor="00FFFF">rois</TD>
#   <TD bgcolor="00FFFF">rois</TD>
#   <TD bgcolor="00FFFF">rois</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">meismes</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">a</TD>
#   <TD bgcolor="FF0000">a</TD>
#   <TD bgcolor="FF0000">a</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">la</TD>
#   <TD bgcolor="FF0000">la</TD>
#   <TD bgcolor="FF0000">la</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">reine</TD>
#   <TD bgcolor="FF0000">reine</TD>
#   <TD bgcolor="FF0000">roine</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">coment</TD>
#   <TD bgcolor="FF0000">comment</TD>
#   <TD bgcolor="FF0000">coment</TD>
#   <TD bgcolor="FF0000">comment</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">il</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">avoit</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">este</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">requis</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">de</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">dame</TD>
#   <TD bgcolor="00FFFF">dame</TD>
#   <TD bgcolor="00FFFF">dame</TD>
#   <TD bgcolor="00FFFF">dame</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">del</TD>
#   <TD bgcolor="FF0000">del</TD>
#   <TD bgcolor="FF0000">del</TD>
#   <TD bgcolor="FF0000">du</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">lac</TD>
#   <TD bgcolor="00FFFF">lac</TD>
#   <TD bgcolor="00FFFF">lac</TD>
#   <TD bgcolor="00FFFF">lac</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">li</TD>
#   <TD bgcolor="FF0000">li</TD>
#   <TD bgcolor="FF0000">li</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">avoit</TD>
#   <TD bgcolor="FF0000">avoit</TD>
#   <TD bgcolor="FF0000">pria</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">requis</TD>
#   <TD bgcolor="FF0000">requis</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">qu</TD>
#   <TD bgcolor="00FFFF">qu</TD>
#   <TD bgcolor="00FFFF">qu</TD>
#   <TD bgcolor="00FFFF">qu</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">il</TD>
#   <TD bgcolor="00FFFF">il</TD>
#   <TD bgcolor="00FFFF">il</TD>
#   <TD bgcolor="00FFFF">il</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ne</TD>
#   <TD bgcolor="00FFFF">ne</TD>
#   <TD bgcolor="00FFFF">ne</TD>
#   <TD bgcolor="00FFFF">ne</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">l</TD>
#   <TD bgcolor="FF0000">lo</TD>
#   <TD bgcolor="FF0000">le</TD>
#   <TD bgcolor="FF0000">l</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">feist</TD>
#   <TD bgcolor="00FFFF">feist</TD>
#   <TD bgcolor="00FFFF">feist</TD>
#   <TD bgcolor="00FFFF">feist</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">chevalier</TD>
#   <TD bgcolor="00FFFF">chevalier</TD>
#   <TD bgcolor="00FFFF">chevalier</TD>
#   <TD bgcolor="00FFFF">chevalier</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">se</TD>
#   <TD bgcolor="00FFFF">se</TD>
#   <TD bgcolor="00FFFF">se</TD>
#   <TD bgcolor="00FFFF">se</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">de</TD>
#   <TD bgcolor="FF0000">des</TD>
#   <TD bgcolor="FF0000">des</TD>
#   <TD bgcolor="FF0000">de</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">ses</TD>
#   <TD bgcolor="FF0000">soes</TD>
#   <TD bgcolor="FF0000">ses</TD>
#   <TD bgcolor="FF0000">ses</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">armes</TD>
#   <TD bgcolor="00FFFF">armes</TD>
#   <TD bgcolor="00FFFF">armes</TD>
#   <TD bgcolor="00FFFF">armes</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">non</TD>
#   <TD bgcolor="00FFFF">non</TD>
#   <TD bgcolor="00FFFF">non</TD>
#   <TD bgcolor="00FFFF">non</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">de</TD>
#   <TD bgcolor="00FFFF">de</TD>
#   <TD bgcolor="00FFFF">de</TD>
#   <TD bgcolor="00FFFF">de</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ses</TD>
#   <TD bgcolor="00FFFF">ses</TD>
#   <TD bgcolor="00FFFF">ses</TD>
#   <TD bgcolor="00FFFF">ses</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">robes</TD>
#   <TD bgcolor="00FFFF">robes</TD>
#   <TD bgcolor="00FFFF">robes</TD>
#   <TD bgcolor="00FFFF">robes</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">la</TD>
#   <TD bgcolor="FF0000">que</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">reine</TD>
#   <TD bgcolor="FF0000">ele</TD>
#   <TD bgcolor="FF0000">ele</TD>
#   <TD bgcolor="FF0000">reine</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">estoit</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">apelee</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">la</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">dame</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">del</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">lac</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">et</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">ele</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">se</TD>
#   <TD bgcolor="FF0000">s</TD>
#   <TD bgcolor="FF0000">s</TD>
#   <TD bgcolor="FF0000">s</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">an</TD>
#   <TD bgcolor="FF0000">en</TD>
#   <TD bgcolor="FF0000">en</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">merveille</TD>
#   <TD bgcolor="FF0000">mervoille</TD>
#   <TD bgcolor="FF0000">merveille</TD>
#   <TD bgcolor="FF0000">mervelle</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">mult</TD>
#   <TD bgcolor="FF0000">mout</TD>
#   <TD bgcolor="FF0000">mult</TD>
#   <TD bgcolor="FF0000">mult</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">trop</TD>
#   <TD bgcolor="FF0000">trop</TD>
#   <TD bgcolor="FF0000">mult</TD>
#   <TD bgcolor="FF0000">mult</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">tarde</TD>
#   <TD bgcolor="00FFFF">tarde</TD>
#   <TD bgcolor="00FFFF">tarde</TD>
#   <TD bg
# None

# %% [markdown]
# ## 2a. Dictionary (table)

# %%
import csv
import re

#create the dictionary (here: Dictionary.csv consisting in two columns, separated by a comma. The first Column 'Original' are the strings as found in the text, the second column 'Normalised' contains the strings you want to replace them with. No whitespaces behind the strings.) 
Normit = {}
with open('dictionary.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'],  dialect='excel')
    for row in reader:
        Normit[row['Original']]= row['Normalised']

#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()
#da lettere
#testimone_P4 = open( "lettere/T196-part1-clean-P4.txt", encoding='utf-8' ).read()
#testimone_S2 = open( "lettere/T196-part1-clean-S2.txt", encoding='utf-8' ).read()
#testimone_S4 = open( "lettere/T196-part1-clean-S4.txt", encoding='utf-8' ).read()

# build a function to tokenize and to normalize by replace keys to be found in the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

#collate
tokens_W1 = tokennormalizer(W1) 
tokens_W2 = tokennormalizer(W2) 
tokens_W3 = tokennormalizer(W3) 
tokens_W4 = tokennormalizer(W4) 

witness_W1 = { "id": "W1", "tokens":tokens_W1 }
witness_W2 = { "id": "W2", "tokens":tokens_W2 }
witness_W3 = { "id": "W3", "tokens":tokens_W3 }
witness_W4 = { "id": "W4", "tokens":tokens_W4 }


input = { "witnesses": [ witness_W1, witness_W2, witness_W3, witness_W4 ] }

table = collate(input, output='html2', segmentation=False)
# Out:
# <TABLE style="border: 1px solid #000000; border-collapse: collapse;" cellpadding="4" border="1">
#  <TR>
#   <TH>W1</TH>
#   <TH>W2</TH>
#   <TH>W3</TH>
#   <TH>W4</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">Lors</TD>
#   <TD bgcolor="FF0000">Lors</TD>
#   <TD bgcolor="FF0000">Lors</TD>
#   <TD bgcolor="FF0000">Adonc</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">li</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">conte</TD>
#   <TD bgcolor="00FFFF">conte</TD>
#   <TD bgcolor="00FFFF">conte</TD>
#   <TD bgcolor="00FFFF">conte</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">rois</TD>
#   <TD bgcolor="00FFFF">rois</TD>
#   <TD bgcolor="00FFFF">rois</TD>
#   <TD bgcolor="00FFFF">rois</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">meismes</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">a</TD>
#   <TD bgcolor="FF0000">a</TD>
#   <TD bgcolor="FF0000">a</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">la</TD>
#   <TD bgcolor="FF0000">la</TD>
#   <TD bgcolor="FF0000">la</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">reine</TD>
#   <TD bgcolor="FF0000">reine</TD>
#   <TD bgcolor="FF0000">roine</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">coment</TD>
#   <TD bgcolor="00FFFF">comment</TD>
#   <TD bgcolor="00FFFF">coment</TD>
#   <TD bgcolor="00FFFF">comment</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">il</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">avoit</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">este</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">requis</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">de</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">dame</TD>
#   <TD bgcolor="00FFFF">dame</TD>
#   <TD bgcolor="00FFFF">dame</TD>
#   <TD bgcolor="00FFFF">dame</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">du</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">lac</TD>
#   <TD bgcolor="00FFFF">lac</TD>
#   <TD bgcolor="00FFFF">lac</TD>
#   <TD bgcolor="00FFFF">lac</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">li</TD>
#   <TD bgcolor="FF0000">li</TD>
#   <TD bgcolor="FF0000">li</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">avoit</TD>
#   <TD bgcolor="FF0000">avoit</TD>
#   <TD bgcolor="FF0000">pria</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">requis</TD>
#   <TD bgcolor="FF0000">requis</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">qu</TD>
#   <TD bgcolor="00FFFF">qu</TD>
#   <TD bgcolor="00FFFF">qu</TD>
#   <TD bgcolor="00FFFF">qu</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">il</TD>
#   <TD bgcolor="00FFFF">il</TD>
#   <TD bgcolor="00FFFF">il</TD>
#   <TD bgcolor="00FFFF">il</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ne</TD>
#   <TD bgcolor="00FFFF">ne</TD>
#   <TD bgcolor="00FFFF">ne</TD>
#   <TD bgcolor="00FFFF">ne</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">l</TD>
#   <TD bgcolor="00FFFF">lo</TD>
#   <TD bgcolor="00FFFF">le</TD>
#   <TD bgcolor="00FFFF">l</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">feist</TD>
#   <TD bgcolor="00FFFF">feist</TD>
#   <TD bgcolor="00FFFF">feist</TD>
#   <TD bgcolor="00FFFF">feist</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">chevalier</TD>
#   <TD bgcolor="00FFFF">chevalier</TD>
#   <TD bgcolor="00FFFF">chevalier</TD>
#   <TD bgcolor="00FFFF">chevalier</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">se</TD>
#   <TD bgcolor="00FFFF">se</TD>
#   <TD bgcolor="00FFFF">se</TD>
#   <TD bgcolor="00FFFF">se</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">de</TD>
#   <TD bgcolor="00FFFF">des</TD>
#   <TD bgcolor="00FFFF">des</TD>
#   <TD bgcolor="00FFFF">de</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ses</TD>
#   <TD bgcolor="00FFFF">soes</TD>
#   <TD bgcolor="00FFFF">ses</TD>
#   <TD bgcolor="00FFFF">ses</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">armes</TD>
#   <TD bgcolor="00FFFF">armes</TD>
#   <TD bgcolor="00FFFF">armes</TD>
#   <TD bgcolor="00FFFF">armes</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">non</TD>
#   <TD bgcolor="00FFFF">non</TD>
#   <TD bgcolor="00FFFF">non</TD>
#   <TD bgcolor="00FFFF">non</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">de</TD>
#   <TD bgcolor="00FFFF">de</TD>
#   <TD bgcolor="00FFFF">de</TD>
#   <TD bgcolor="00FFFF">de</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ses</TD>
#   <TD bgcolor="00FFFF">ses</TD>
#   <TD bgcolor="00FFFF">ses</TD>
#   <TD bgcolor="00FFFF">ses</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">robes</TD>
#   <TD bgcolor="00FFFF">robes</TD>
#   <TD bgcolor="00FFFF">robes</TD>
#   <TD bgcolor="00FFFF">robes</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">la</TD>
#   <TD bgcolor="FF0000">que</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">reine</TD>
#   <TD bgcolor="FF0000">ele</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">reine</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">se</TD>
#   <TD bgcolor="FF0000">estoit</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">apelee</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">la</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">dame</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">del</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">lac</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">et</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">ele</TD>
#   <TD bgcolor="FF0000">ele</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">s</TD>
#   <TD bgcolor="FF0000">s</TD>
#   <TD bgcolor="FF0000">s</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">an</TD>
#   <TD bgcolor="FF0000">en</TD>
#   <TD bgcolor="FF0000">en</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">merveille</TD>
#   <TD bgcolor="00FFFF">mervoille</TD>
#   <TD bgcolor="00FFFF">merveille</TD>
#   <TD bgcolor="00FFFF">mervelle</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">mult</TD>
#   <TD bgcolor="00FFFF">mout</TD>
#   <TD bgcolor="00FFFF">mult</TD>
#   <TD bgcolor="00FFFF">mult</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">trop</TD>
#   <TD bgcolor="FF0000">trop</TD>
#   <TD bgcolor="FF0000">mult</TD>
#   <TD bgcolor="FF0000">mult</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">tarde</TD>
#   <TD bgcolor="00FFFF">tarde</TD>
#   <TD bgcolor="00FFFF">tarde</TD>
#   <TD bg

# %% [markdown]
# ## 2a. Dictionary  (graph)

# %%
import csv
import re

#create the dictionary (here: Dictionary.csv consisting in two columns, separated by a comma. The first Column 'Original' are the strings as found in the text, the second column 'Normalised' contains the strings you want to replace them with. No whitespaces behind the strings.) 
Normit = {}
with open('dictionary.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'],  dialect='excel')
    for row in reader:
        Normit[row['Original']]= row['Normalised']

#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()
#da lettere
#testimone_P4 = open( "lettere/T196-part1-clean-P4.txt", encoding='utf-8' ).read()
#testimone_S2 = open( "lettere/T196-part1-clean-S2.txt", encoding='utf-8' ).read()
#testimone_S4 = open( "lettere/T196-part1-clean-S4.txt", encoding='utf-8' ).read()

# build a function to tokenize and to normalize by replace keys to be found in the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

#collate
tokens_W1 = tokennormalizer(W1) 
tokens_W2 = tokennormalizer(W2) 
tokens_W3 = tokennormalizer(W3) 
tokens_W4 = tokennormalizer(W4) 

witness_W1 = { "id": "W1", "tokens":tokens_W1 }
witness_W2 = { "id": "W2", "tokens":tokens_W2 }
witness_W3 = { "id": "W3", "tokens":tokens_W3 }
witness_W4 = { "id": "W4", "tokens":tokens_W4 }


input = { "witnesses": [ witness_W1, witness_W2, witness_W3, witness_W4 ] }

graph = collate(input, output='svg', segmentation=False)
print(graph)
# Out:
# None

# %% [markdown]
# ## 2b. NLP (table)

# %%
import csv
import re

#create the dictionary (here: Dictionary.csv consisting in two columns, separated by a comma. The first Column 'Original' are the strings as found in the text, the second column 'Normalised' contains the strings you want to replace them with. No whitespaces behind the strings.) 
Normit = {}
with open('pos_lemma.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'],  dialect='excel')
    for row in reader:
        Normit[row['Original']]= row['Normalised']

#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()
#da lettere
#testimone_P4 = open( "lettere/T196-part1-clean-P4.txt", encoding='utf-8' ).read()
#testimone_S2 = open( "lettere/T196-part1-clean-S2.txt", encoding='utf-8' ).read()
#testimone_S4 = open( "lettere/T196-part1-clean-S4.txt", encoding='utf-8' ).read()

# build a function to tokenize and to normalize by replace keys to be found in the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

#collate
tokens_W1 = tokennormalizer(W1) 
tokens_W2 = tokennormalizer(W2) 
tokens_W3 = tokennormalizer(W3) 
tokens_W4 = tokennormalizer(W4) 

witness_W1 = { "id": "W1", "tokens":tokens_W1 }
witness_W2 = { "id": "W2", "tokens":tokens_W2 }
witness_W3 = { "id": "W3", "tokens":tokens_W3 }
witness_W4 = { "id": "W4", "tokens":tokens_W4 }


input = { "witnesses": [ witness_W1, witness_W2, witness_W3, witness_W4 ] }

table = collate(input, output='html2', segmentation=False)
print(table)
# Out:
# <TABLE style="border: 1px solid #000000; border-collapse: collapse;" cellpadding="4" border="1">
#  <TR>
#   <TH>W1</TH>
#   <TH>W2</TH>
#   <TH>W3</TH>
#   <TH>W4</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">Lors</TD>
#   <TD bgcolor="FF0000">Lors</TD>
#   <TD bgcolor="FF0000">Lors</TD>
#   <TD bgcolor="FF0000">Adonc</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">li</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">conte</TD>
#   <TD bgcolor="00FFFF">conte</TD>
#   <TD bgcolor="00FFFF">conte</TD>
#   <TD bgcolor="00FFFF">conte</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">rois</TD>
#   <TD bgcolor="00FFFF">rois</TD>
#   <TD bgcolor="00FFFF">rois</TD>
#   <TD bgcolor="00FFFF">rois</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">meismes</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">a</TD>
#   <TD bgcolor="FF0000">a</TD>
#   <TD bgcolor="FF0000">a</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">la</TD>
#   <TD bgcolor="FF0000">la</TD>
#   <TD bgcolor="FF0000">la</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">reine</TD>
#   <TD bgcolor="FF0000">reine</TD>
#   <TD bgcolor="FF0000">roine</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">coment</TD>
#   <TD bgcolor="00FFFF">comment</TD>
#   <TD bgcolor="00FFFF">coment</TD>
#   <TD bgcolor="00FFFF">comment</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">il</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">avoit</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">este</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">requis</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">de</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#   <TD bgcolor="00FFFF">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">dame</TD>
#   <TD bgcolor="00FFFF">dame</TD>
#   <TD bgcolor="00FFFF">dame</TD>
#   <TD bgcolor="00FFFF">dame</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">del</TD>
#   <TD bgcolor="00FFFF">du</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">lac</TD>
#   <TD bgcolor="00FFFF">lac</TD>
#   <TD bgcolor="00FFFF">lac</TD>
#   <TD bgcolor="00FFFF">lac</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">li</TD>
#   <TD bgcolor="FF0000">li</TD>
#   <TD bgcolor="FF0000">li</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">avoit</TD>
#   <TD bgcolor="FF0000">avoit</TD>
#   <TD bgcolor="FF0000">pria</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">requis</TD>
#   <TD bgcolor="FF0000">requis</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">qu</TD>
#   <TD bgcolor="00FFFF">qu</TD>
#   <TD bgcolor="00FFFF">qu</TD>
#   <TD bgcolor="00FFFF">qu</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">il</TD>
#   <TD bgcolor="00FFFF">il</TD>
#   <TD bgcolor="00FFFF">il</TD>
#   <TD bgcolor="00FFFF">il</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ne</TD>
#   <TD bgcolor="00FFFF">ne</TD>
#   <TD bgcolor="00FFFF">ne</TD>
#   <TD bgcolor="00FFFF">ne</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">l</TD>
#   <TD bgcolor="00FFFF">lo</TD>
#   <TD bgcolor="00FFFF">le</TD>
#   <TD bgcolor="00FFFF">l</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">feist</TD>
#   <TD bgcolor="00FFFF">feist</TD>
#   <TD bgcolor="00FFFF">feist</TD>
#   <TD bgcolor="00FFFF">feist</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">chevalier</TD>
#   <TD bgcolor="00FFFF">chevalier</TD>
#   <TD bgcolor="00FFFF">chevalier</TD>
#   <TD bgcolor="00FFFF">chevalier</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">se</TD>
#   <TD bgcolor="00FFFF">se</TD>
#   <TD bgcolor="00FFFF">se</TD>
#   <TD bgcolor="00FFFF">se</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">de</TD>
#   <TD bgcolor="FF0000">des</TD>
#   <TD bgcolor="FF0000">des</TD>
#   <TD bgcolor="FF0000">de</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ses</TD>
#   <TD bgcolor="00FFFF">soes</TD>
#   <TD bgcolor="00FFFF">ses</TD>
#   <TD bgcolor="00FFFF">ses</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">armes</TD>
#   <TD bgcolor="00FFFF">armes</TD>
#   <TD bgcolor="00FFFF">armes</TD>
#   <TD bgcolor="00FFFF">armes</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">non</TD>
#   <TD bgcolor="00FFFF">non</TD>
#   <TD bgcolor="00FFFF">non</TD>
#   <TD bgcolor="00FFFF">non</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">de</TD>
#   <TD bgcolor="00FFFF">de</TD>
#   <TD bgcolor="00FFFF">de</TD>
#   <TD bgcolor="00FFFF">de</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">ses</TD>
#   <TD bgcolor="00FFFF">ses</TD>
#   <TD bgcolor="00FFFF">ses</TD>
#   <TD bgcolor="00FFFF">ses</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">robes</TD>
#   <TD bgcolor="00FFFF">robes</TD>
#   <TD bgcolor="00FFFF">robes</TD>
#   <TD bgcolor="00FFFF">robes</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">la</TD>
#   <TD bgcolor="FF0000">que</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">la</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">reine</TD>
#   <TD bgcolor="FF0000">ele</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">reine</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">estoit</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">apelee</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">la</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">dame</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">del</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">lac</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">et</TD>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">ele</TD>
#   <TD bgcolor="FF0000">ele</TD>
#   <TD bgcolor="FF0000">-</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">se</TD>
#   <TD bgcolor="FF0000">s</TD>
#   <TD bgcolor="FF0000">s</TD>
#   <TD bgcolor="FF0000">s</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">-</TD>
#   <TD bgcolor="FF0000">an</TD>
#   <TD bgcolor="FF0000">en</TD>
#   <TD bgcolor="FF0000">en</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">merveille</TD>
#   <TD bgcolor="00FFFF">mervoille</TD>
#   <TD bgcolor="00FFFF">merveille</TD>
#   <TD bgcolor="00FFFF">mervelle</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">mult</TD>
#   <TD bgcolor="00FFFF">mout</TD>
#   <TD bgcolor="00FFFF">mult</TD>
#   <TD bgcolor="00FFFF">mult</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#   <TD bgcolor="00FFFF">et</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">trop</TD>
#   <TD bgcolor="FF0000">trop</TD>
#   <TD bgcolor="FF0000">mult</TD>
#   <TD bgcolor="FF0000">mult</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#   <TD bgcolor="00FFFF">li</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">tarde</TD>
#   <TD bgcolor="00FFFF">tarde</TD>
#   <TD bgcolor="00FFFF">tarde</TD>
#   <TD bg
# None

# %% [markdown]
# ## 2b. NLP (graph)

# %%
import csv
import re

#create the dictionary (here: Dictionary.csv consisting in two columns, separated by a comma. The first Column 'Original' are the strings as found in the text, the second column 'Normalised' contains the strings you want to replace them with. No whitespaces behind the strings.) 
Normit = {}
with open('pos_lemma.csv') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=['Original', 'Normalised'],  dialect='excel')
    for row in reader:
        Normit[row['Original']]= row['Normalised']

#read in the witnesses  from your file system 
from collatex.core_classes import WordPunctuationTokenizer
tokenizer = WordPunctuationTokenizer()
#da lettere
#testimone_P4 = open( "lettere/T196-part1-clean-P4.txt", encoding='utf-8' ).read()
#testimone_S2 = open( "lettere/T196-part1-clean-S2.txt", encoding='utf-8' ).read()
#testimone_S4 = open( "lettere/T196-part1-clean-S4.txt", encoding='utf-8' ).read()

# build a function to tokenize and to normalize by replace keys to be found in the dictionary by the corresponding values 
def tokennormalizer(witness) :
    tokens_as_strings = tokenizer.tokenize(witness)
    list = []
    for token_string in tokens_as_strings:
        normversion = re.sub(r'\s+$',"", token_string)
        replaceversion = Normit.get(normversion,normversion)
        list.append({'t':token_string, 'n':replaceversion})
    return(list)

#collate
tokens_W1 = tokennormalizer(W1) 
tokens_W2 = tokennormalizer(W2) 
tokens_W3 = tokennormalizer(W3) 
tokens_W4 = tokennormalizer(W4) 

witness_W1 = { "id": "W1", "tokens":tokens_W1 }
witness_W2 = { "id": "W2", "tokens":tokens_W2 }
witness_W3 = { "id": "W3", "tokens":tokens_W3 }
witness_W4 = { "id": "W4", "tokens":tokens_W4 }


input = { "witnesses": [ witness_W1, witness_W2, witness_W3, witness_W4 ] }

graph = collate(input, output='svg', segmentation=False)
print(graph)
# Out:
# None
